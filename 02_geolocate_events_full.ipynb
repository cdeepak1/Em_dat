# %%
import xarray as xr
import numpy as np
import geopandas as gpd
import pandas as pd
import re

# %% [markdown]
# This notebook (script) is to geolocate the EM-DAT events from 1 to 2023 based on the cleaned GAUL geometries from script 1 (clean_gaul.ipynb(py)).
#
# The first part is locating the events that have the geocodes to the GAUL geometries.
#
# The second part is locating the events  based on the names of the geometries. For this, the names of the locations and geometries will be matched by a fuzzy algorithm, and then only the geometries that pass a certain threshold and which names exist fully in the location column of the event are kept.
# In the case where geometries with similar names at admin levels 1 and 2 are found, the geometries of level 1 are favored and kept over the level 2.
#
# At the end, all geodataframes are concatenated together and columns are created to enable their integration with the GDIS database.

# %%
emdat = pd.read_excel('/net/projects/xaida/raw_data/emdat_data/public_emdat_1990_2023.xlsx')

# %%
emdat
# Out:
#               DisNo. Historic Classification Key Disaster Group  \
# 0      1990-0001-LKA      Yes    nat-hyd-flo-riv        Natural
# 1      1990-0002-TUN      Yes    nat-hyd-flo-riv        Natural
# 2      1990-0003-WSM      Yes    nat-met-sto-tro        Natural
# 3      1990-0004-FRA      Yes    nat-hyd-mmw-ava        Natural
# 4      1990-0005-IDN      Yes    nat-hyd-flo-riv        Natural
# ...              ...      ...                ...            ...
# 20613  2023-9868-USA       No    nat-cli-dro-dro        Natural
# 20614  2023-9872-CHN       No    nat-cli-dro-dro        Natural
# 20615  2023-9873-FSM       No    nat-cli-dro-dro        Natural
# 20616  2023-9878-MOZ       No    nat-cli-dro-dro        Natural
# 20617  2023-9879-BWA       No    nat-cli-dro-dro        Natural
#
#       Disaster Subgroup        Disaster Type  Disaster Subtype  \
# 0          Hydrological                Flood    Riverine flood
# 1          Hydrological                Flood    Riverine flood
# 2        Meteorological                Storm  Tropical cyclone
# 3          Hydrological  Mass movement (wet)   Avalanche (wet)
# 4          Hydrological                Flood    Riverine flood
# ...                 ...                  ...               ...
# 20613    Climatological              Drought           Drought
# 20614    Climatological              Drought           Drought
# 20615    Climatological              Drought           Drought
# 20616    Climatological              Drought           Drought
# 20617    Climatological              Drought           Drought
#
#                External IDs Event Name  ISO  ...  \
# 0                       NaN        NaN  LKA  ...
# 1                       NaN        NaN  TUN  ...
# 2                       NaN        Ofa  WSM  ...
# 3                       NaN        NaN  FRA  ...
# 4                       NaN        NaN  IDN  ...
# ...                     ...        ...  ...  ...
# 20613                   NaN        NaN  USA  ...
# 20614                   NaN        NaN  CHN  ...
# 20615  GLIDE:DR-2023-000130        NaN  FSM  ...
# 20616  GLIDE:DR-2024-000073        NaN  MOZ  ...
# 20617                   NaN        NaN  BWA  ...
#
#       Reconstruction Costs ('000 US$)  \
# 0                                 NaN
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN
# ...                               ...
# 20613                             NaN
# 20614                             NaN
# 20615                             NaN
# 20616                             NaN
# 20617                             NaN
#
#       Reconstruction Costs, Adjusted ('000 US$) Insured Damage ('000 US$)  \
# 0                                           NaN                       NaN
# 1                                           NaN                       NaN
# 2                                           NaN                       NaN
# 3                                           NaN                       NaN
# 4                                           NaN                       NaN
# ...                                         ...                       ...
# 20613                                       NaN                       NaN
# 20614                                       NaN                       NaN
# 20615                                       NaN                       NaN
# 20616                                       NaN                       NaN
# 20617                                       NaN                       NaN
#
#       Insured Damage, Adjusted ('000 US$) Total Damage ('000 US$)  \
# 0                                     NaN                     NaN
# 1                                     NaN                242800.0
# 2                                     NaN                200000.0
# 3                                     NaN                     NaN
# 4                                     NaN                  4800.0
# ...                                   ...                     ...
# 20613                                 NaN              14500000.0
# 20614                                 NaN               2700000.0
# 20615                                 NaN                     NaN
# 20616                                 NaN                     NaN
# 20617                                 NaN                     NaN
#
#       Total Damage, Adjusted ('000 US$)         CPI Admin Units  Entry Date  \
# 0                                   NaN   42.880732         NaN  2005-12-20
# 1                              566222.0   42.880732         NaN  2006-07-19
# 2                              466410.0   42.880732         NaN  2005-12-20
# 3                                   NaN   42.880732         NaN  2005-12-21
# 4                               11194.0   42.880732         NaN  2006-07-19
# ...                                 ...         ...         ...         ...
# 20613                        14500000.0  100.000000         NaN  2024-01-17
# 20614                         2700000.0  100.000000         NaN  2024-02-12
# 20615                               NaN  100.000000         NaN  2024-02-13
# 20616                               NaN  100.000000         NaN  2024-06-07
# 20617                               NaN  100.000000         NaN  2024-06-12
#
#        Last Update
# 0       2023-09-25
# 1       2023-09-25
# 2       2023-09-25
# 3       2023-09-25
# 4       2023-09-25
# ...            ...
# 20613   2024-02-27
# 20614   2024-03-04
# 20615   2024-04-03
# 20616   2024-06-14
# 20617   2024-06-12
#
# [20618 rows x 46 columns]

# %%
import pandas as pd

# Read the Excel file into emdat DataFrame and set 'DisNo.' as index
emdat = pd.read_excel('/net/projects/xaida/raw_data/emdat_data/public_emdat_1990_2023.xlsx')
emdat = emdat.set_index('DisNo.')

# Select only 'Location' and 'Admin Units' columns and drop rows where both are NaN
emdat = emdat[['Location', 'Admin Units']].dropna(how='all')

# Sort 'Location' column alphabetically
emdat['Location'] = emdat['Location'].apply(lambda x: ', '.join(sorted(str(x).split(', '))))

# Process 'Admin Units' column to get Admin1 Code, Admin2 Code, and Geo Locations
def process_admin_units(units):
    if pd.isna(units):
        return pd.Series([None, None, None])
    
    admin1_units = []
    admin2_units = []

    # Extract Admin1 and Admin2 information
    for unit in eval(units):
        if 'adm1_code' in unit:
            admin1_units.append((unit['adm1_code'], unit['adm1_name']))
        if 'adm2_code' in unit:
            admin2_units.append((unit['adm2_code'], unit['adm2_name']))
    
    # Sort admin units alphabetically
    admin1_units.sort(key=lambda x: x[1])  # Sort by adm1_name
    admin2_units.sort(key=lambda x: x[1])  # Sort by adm2_name

    admin1_codes = [str(unit[0]) for unit in admin1_units]
    admin1_names_list = [unit[1] for unit in admin1_units]
    
    admin2_codes = [str(unit[0]) for unit in admin2_units]
    admin2_names_list = [unit[1] for unit in admin2_units]
    
    # Construct Geo Locations string
    geo_location_str = ', '.join(admin1_names_list) + (' (Adm1).' if admin1_names_list else '')
    if admin2_names_list:
        geo_location_str += ' ' + ', '.join(admin2_names_list) + ' (Adm2).'
    
    return pd.Series([';'.join(admin1_codes), ';'.join(admin2_codes), geo_location_str])

# Apply the process_admin_units function to 'Admin Units' column and assign the result to Emdata
Emdata = emdat['Admin Units'].apply(process_admin_units)
Emdata.columns = ['Admin1 Code', 'Admin2 Code', 'Geo Locations']

# Merge 'Location' column from emdat into Emdata DataFrame
Emdata['Location'] = emdat['Location']

# Print the DataFrame
print(Emdata)

# Access a specific DisNo.
print(Emdata.loc['2021-0003-IDN'])
# Out:
#               Admin1 Code Admin2 Code Geo Locations  \
# DisNo.
# 1990-0001-LKA        None        None          None
# 1990-0002-TUN        None        None          None
# 1990-0003-WSM        None        None          None
# 1990-0004-FRA        None        None          None
# 1990-0005-IDN        None        None          None
# ...                   ...         ...           ...
# 2023-9651-BRA        None        None          None
# 2023-9706-BOL        None        None          None
# 2023-9868-USA        None        None          None
# 2023-9873-FSM        None        None          None
# 2023-9879-BWA        None        None          None
#
#                                                         Location
# DisNo.
# 1990-0001-LKA  Ampara, Badulla, Eliya, Kandy, Kurunegala, Mat...
# 1990-0002-TUN  Gabes, Gafsa, Kairouan, Kasserine, Nefta, Sfax...
# 1990-0003-WSM                                      Sawali, Upolu
# 1990-0004-FRA                                Tignes, Val d'Isere
# 1990-0005-IDN  Banyumas municipalities (Central Java), Batang...
# ...                                                          ...
# 2023-9651-BRA                                     Amazonas state
# 2023-9706-BOL  Chuquisaca, Cochabamba, La Paz, Oruro, Santa Cruz
# 2023-9868-USA  Illinois, Kansas, Louisiana, Missouri, Montana...
# 2023-9873-FSM                        Chuuk, Kosrae, Pohnpei, Yap
# 2023-9879-BWA                               North East, Southern
#
# [19393 rows x 4 columns]
# Admin1 Code
# Admin2 Code                                      18177;73786;73828
# Geo Locations               Majene, Mamuju, Polewalimamasa (Adm2).
# Location         Majene, Mamuju, Polewali Mandar districts (Wes...
# Name: 2021-0003-IDN, dtype: object

# %%
common_nans = emdat[ emdat['Location'].notna() &  emdat['Admin Units'].isna()]

# Print the result
print("Rows with common NaNs in 'Location' and 'Admin Units':")
print(common_nans)
# Out:
# Rows with common NaNs in 'Location' and 'Admin Units':
#                                                         Location Admin Units
# DisNo.
# 1990-0001-LKA  Ampara, Badulla, Eliya, Kandy, Kurunegala, Mat...         NaN
# 1990-0002-TUN  Gabes, Gafsa, Kairouan, Kasserine, Nefta, Sfax...         NaN
# 1990-0003-WSM                                      Sawali, Upolu         NaN
# 1990-0004-FRA                                Tignes, Val d'Isere         NaN
# 1990-0005-IDN  Banyumas municipalities (Central Java), Batang...         NaN
# ...                                                          ...         ...
# 2023-9651-BRA                                     Amazonas state         NaN
# 2023-9706-BOL  Chuquisaca, Cochabamba, La Paz, Oruro, Santa Cruz         NaN
# 2023-9868-USA  Illinois, Kansas, Louisiana, Missouri, Montana...         NaN
# 2023-9873-FSM                        Chuuk, Kosrae, Pohnpei, Yap         NaN
# 2023-9879-BWA                               North East, Southern         NaN
#
# [10887 rows x 2 columns]

# %%
#get the entires that only have location name indiction (not the geolocation name and code)
Emdata_loconly = Emdata[Emdata['Admin1 Code'].isna() & Emdata['Admin2 Code'].isna()]
#get the geocoded entries
Emdata_geocode = Emdata.drop(Emdata_loconly.index)

# %% [markdown]
# ## 1) Matching events with geolocations (from 2021 onwards)

# %% [markdown]
# ### geometries at Admin 1 level

# %%
####Administrative level 1 geometries
#Extract Adm1 locations
emdat_geocode_adm1 = Emdata_geocode.loc[Emdata_geocode['Geo Locations'].str.contains("(Adm1)")]
emdat_geocode_adm1["Geo Locations"] = emdat_geocode_adm1["Geo Locations"].str.split(" \(Adm1",expand=True)[0]
#Shape Adm1 locations: 1 row = 1 geolocation
emdat_geocode_adm1_stacked = pd.DataFrame(emdat_geocode_adm1["Admin1 Code"].str.split(';', expand=True).stack()).rename(columns={0:'ADM1_CODE'})
emdat_geocode_adm1_stacked['location'] = pd.DataFrame(emdat_geocode_adm1["Location"].str.split(',', expand=True).stack())
emdat_geocode_adm1_stacked['geolocation'] = pd.DataFrame(emdat_geocode_adm1["Geo Locations"].str.split(',', expand=True).stack())
emdat_geocode_adm1_identified = emdat_geocode_adm1_stacked.reset_index().drop(columns={'level_1'})

emdat_geocode_adm1_identified
# Out:
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
#               DisNo. ADM1_CODE            location              geolocation
# 0      1997-0331-EGY     61515      Cairo province                    Cairo
# 1      1999-9388-BDI     40546            Bugabira                  Cankuzo
# 2      1999-9388-BDI     40548             Buganda                   Gitega
# 3      1999-9388-BDI     40549              Busoni                   Karuzi
# 4      1999-9388-BDI     40552   Cankuzo provinces                  Makamba
# ...              ...       ...                 ...                      ...
# 26204  2023-9167-HND      1438           Jacaleapa                     Yoro
# 26205  2023-9234-ESP      2716           Andalusia                Andalucía
# 26206  2023-9234-ESP      2724            Asturias       Cataluña/Catalunya
# 26207  2023-9234-ESP      2718          Catalognia   Principado de Asturias
# 26208  2023-9494-IDN     73617                Bali                    Papua
#
# [26209 rows x 4 columns]

# %%
emdat_geocode_adm1
# Out:
#                                              Admin1 Code  \
# DisNo.
# 1997-0331-EGY                                      61515
# 1999-9388-BDI  40546;40548;40549;40552;40554;40557;40558
# 1999-9388-DJI                   1093;1094;1095;1096;1097
# 1999-9388-ERI                             1205;1208;1211
# 1999-9388-ETH                 1230;1232;47678;1236;47679
# ...                                                  ...
# 2023-0539-CHL                             889;892;149630
# 2023-0548-IND                                       1502
# 2023-9167-HND                        1420;1421;1433;1438
# 2023-9234-ESP                             2716;2724;2718
# 2023-9494-IDN                                      73617
#
#                                                    Admin2 Code  \
# DisNo.
# 1997-0331-EGY
# 1999-9388-BDI  40638;40605;40639;48356;40642;40643;40610;40596
# 1999-9388-DJI
# 1999-9388-ERI
# 1999-9388-ETH                  40799;40800;149281;149298;40803
# ...                                                        ...
# 2023-0539-CHL                                      12971;12947
# 2023-0548-IND
# 2023-9167-HND                    17413;17439;17335;17287;17313
# 2023-9234-ESP
# 2023-9494-IDN
#
#                                                    Geo Locations  \
# DisNo.
# 1997-0331-EGY                                              Cairo
# 1999-9388-BDI  Cankuzo, Gitega, Karuzi, Makamba, Muyinga, Rut...
# 1999-9388-DJI     Ali Sabieh, Dikhil, Djibouti, Obock, Tadjourah
# 1999-9388-ERI   Anseba, Debubawi Keih Bahri, Semenawi Keih Bahri
# 1999-9388-ETH   Beneshangul Gumu, Gambela, Oromia, SNNPR, Somali
# ...                                                          ...
# 2023-0539-CHL  Libertador Gral. Bernardo O'Higgins, Maule, Va...
# 2023-0548-IND                                            Mizoram
# 2023-9167-HND             Atlantida, Choluteca, Ocotepeque, Yoro
# 2023-9234-ESP  Andalucía, Cataluña/Catalunya, Principado de A...
# 2023-9494-IDN                                              Papua
#
#                                                         Location
# DisNo.
# 1997-0331-EGY                                     Cairo province
# 1999-9388-BDI  Bugabira, Buganda, Busoni, Cankuzo provinces, ...
# 1999-9388-DJI  Ali Sabieh, Dikhil, Djibouti, Obock, Tadjourah...
# 1999-9388-ERI  Anseba, Debubawi Keih Bahri, Semenawi Keih Bah...
# 1999-9388-ETH  Beneshangul Gumu, Gambela, North Wollo, Oromia...
# ...                                                          ...
# 2023-0539-CHL  Biobío Regions, Maule, O’Higgins, Santiago Met...
# 2023-0548-IND                                      Mizoram State
# 2023-9167-HND  Catacamas, Choculeta, Flores, Jacaleapa, La Es...
# 2023-9234-ESP                    Andalusia, Asturias, Catalognia
# 2023-9494-IDN  Bali, Bangka Belitung, Banten, Bengkulu, Daera...
#
# [5045 rows x 4 columns]

# %%
emdat_geocode_adm1['Location'].astype(str).str.split(',').apply(len).sum()
# Out:
# 30562

# %%
(emdat_geocode_adm1['Admin1 Code'].astype(str).str.split(';').apply(len) + (emdat_geocode_adm1['Admin2 Code'].astype(str).str.split(';').apply(len) - emdat_geocode_adm1['Admin2 Code'].isna())).sum()
# Out:
# 34655

# %%
emdat_geocode_adm1_identified
# Out:
#               DisNo. ADM1_CODE            location              geolocation
# 0      1997-0331-EGY     61515      Cairo province                    Cairo
# 1      1999-9388-BDI     40546            Bugabira                  Cankuzo
# 2      1999-9388-BDI     40548             Buganda                   Gitega
# 3      1999-9388-BDI     40549              Busoni                   Karuzi
# 4      1999-9388-BDI     40552   Cankuzo provinces                  Makamba
# ...              ...       ...                 ...                      ...
# 26204  2023-9167-HND      1438           Jacaleapa                     Yoro
# 26205  2023-9234-ESP      2716           Andalusia                Andalucía
# 26206  2023-9234-ESP      2724            Asturias       Cataluña/Catalunya
# 26207  2023-9234-ESP      2718          Catalognia   Principado de Asturias
# 26208  2023-9494-IDN     73617                Bali                    Papua
#
# [26209 rows x 4 columns]

# %%
gaul_1 = gpd.read_file('/net/projects/xaida/raw_data/gaul_maps/gaul_admin1_clean.gpkg')

# %%
gaul_1.columns
# Out:
# Index(['ADM0_CODE', 'ADM0_NAME', 'ADM1_CODE', 'ADM1_NAME', 'DISP_AREA',
#        'EXP1_YEAR', 'STATUS', 'STR1_YEAR', 'Shape_Area', 'Shape_Leng',
#        'official_name', 'iso3', 'geometry'],
#       dtype='object')

# %%
gaul_1_loc = gaul_1[['ADM1_CODE','ADM1_NAME']]

# %%
gaul_1_loc.dtypes
# Out:
# ADM1_CODE     int64
# ADM1_NAME    object
# dtype: object

# %%
emdat_geocode_adm1_identified.dtypes
# Out:
# DisNo.         object
# ADM1_CODE      object
# location       object
# geolocation    object
# dtype: object

# %%
emdat_geocode_adm1_identified['ADM1_CODE'] = emdat_geocode_adm1_identified['ADM1_CODE'].astype(int)

# %%
emdat_geocode_adm1_identified_merged = emdat_geocode_adm1_identified.merge(gaul_1_loc, on = 'ADM1_CODE',how = 'left')

# %%
emdat_geocode_adm1_identified_merged
# Out:
#               DisNo.  ADM1_CODE            location              geolocation  \
# 0      1997-0331-EGY      61515      Cairo province                    Cairo
# 1      1999-9388-BDI      40546            Bugabira                  Cankuzo
# 2      1999-9388-BDI      40548             Buganda                   Gitega
# 3      1999-9388-BDI      40549              Busoni                   Karuzi
# 4      1999-9388-BDI      40552   Cankuzo provinces                  Makamba
# ...              ...        ...                 ...                      ...
# 26214  2023-9167-HND       1438           Jacaleapa                     Yoro
# 26215  2023-9234-ESP       2716           Andalusia                Andalucía
# 26216  2023-9234-ESP       2724            Asturias       Cataluña/Catalunya
# 26217  2023-9234-ESP       2718          Catalognia   Principado de Asturias
# 26218  2023-9494-IDN      73617                Bali                    Papua
#
#                     ADM1_NAME
# 0                       Cairo
# 1                     Cankuzo
# 2                      Gitega
# 3                      Karuzi
# 4                     Makamba
# ...                       ...
# 26214                    Yoro
# 26215               Andaluc�a
# 26216      Catalu�a/Catalunya
# 26217  Principado de Asturias
# 26218                   Papua
#
# [26219 rows x 5 columns]

# %%
emdat_geocode_adm1_identified_merged["geolocation"] = emdat_geocode_adm1_identified_merged["geolocation"].str.lstrip()
emdat_geocode_adm1_identified_merged["geolocation"] = emdat_geocode_adm1_identified_merged["geolocation"].str.rstrip()

# %%
emdat_geocode_adm1_identified_merged["ADM1_NAME"] = emdat_geocode_adm1_identified_merged["ADM1_NAME"].str.lstrip()
emdat_geocode_adm1_identified_merged["ADM1_NAME"] = emdat_geocode_adm1_identified_merged["ADM1_NAME"].str.rstrip()

# %%
emdat_geocode_adm1_identified_merged['comparison'] = emdat_geocode_adm1_identified_merged.apply(lambda x: x['geolocation'] == x['ADM1_NAME'], axis=1)

# %%
emdat_geocode_adm1_identified_merged[emdat_geocode_adm1_identified_merged.comparison == False]
# Out:
#               DisNo.  ADM1_CODE                             location  \
# 307    2000-0299-GTM      64834                               Jalapa
# 308    2000-0299-GTM      64828                               Quiché
# 322    2000-0335-ISL       1474    Hella city (Rangarvalla province)
# 353    2000-0359-ESP       2717                               Aragón
# 354    2000-0359-ESP       2724                   Cataluña/Catalunya
# ...              ...        ...                                  ...
# 26089  2023-0280-CAN        835                               Québec
# 26145  2023-0365-GTM      64830                        Suchitepéques
# 26146  2023-0365-GTM      64828   Zacapa and Totonicapán Departments
# 26215  2023-9234-ESP       2716                            Andalusia
# 26216  2023-9234-ESP       2724                             Asturias
#
#               geolocation           ADM1_NAME  comparison
# 307                Quiché              Quich�       False
# 308           Totonicapán         Totonicap�n       False
# 322           Rangárvalla         Rang�rvalla       False
# 353                Aragón              Arag�n       False
# 354    Cataluña/Catalunya  Catalu�a/Catalunya       False
# ...                   ...                 ...         ...
# 26089     Quebec / Québec     Quebec / Qu�bec       False
# 26145       Suchitepéquez       Suchitep�quez       False
# 26146         Totonicapán         Totonicap�n       False
# 26215           Andalucía           Andaluc�a       False
# 26216  Cataluña/Catalunya  Catalu�a/Catalunya       False
#
# [398 rows x 6 columns]

# %%
gaul_1[gaul_1.ADM1_CODE == 2754]
# Out:
#     ADM0_CODE    ADM0_NAME  ADM1_CODE                ADM1_NAME DISP_AREA  \
# 22         74  South Sudan       2754  Northern Bahr El Ghazal        NO
#
#     EXP1_YEAR        STATUS  STR1_YEAR  Shape_Area  Shape_Leng  \
# 22       3000  Member State       1994    2.494846    7.052428
#
#               official_name iso3  \
# 22  Republic of South Sudan  SSD
#
#                                              geometry
# 22  POLYGON ((26.13292 9.08244, 26.13530 9.10099, ...

# %%
gaul_1[gaul_1.ADM0_NAME == 'South Sudan']
# Out:
#     ADM0_CODE    ADM0_NAME  ADM1_CODE                          ADM1_NAME  \
# 17         74  South Sudan       2746                        El Buheyrat
# 18         74  South Sudan       2747                              Unity
# 19         74  South Sudan       2748                  Central Equatoria
# 20         74  South Sudan       2750                  Eastern Equatoria
# 21         74  South Sudan       2751                            Jonglei
# 22         74  South Sudan       2754            Northern Bahr El Ghazal
# 23         74  South Sudan       2765                              Warab
# 24         74  South Sudan       2766             Western Bahr El Ghazal
# 25         74  South Sudan       2768                  Western Equatoria
# 26         74  South Sudan      37021                         Upper Nile
# 61        102  South Sudan        124  Administrative unit not available
#
#    DISP_AREA  EXP1_YEAR                 STATUS  STR1_YEAR  Shape_Area  \
# 17        NO       3000           Member State       1994    3.503620
# 18        NO       3000           Member State       1994    3.011566
# 19        NO       3000           Member State       1994    3.595255
# 20        NO       3000           Member State       1994    5.769396
# 21        NO       3000           Member State       1994    9.907790
# 22        NO       3000           Member State       1994    2.494846
# 23        NO       3000           Member State       1994    3.105859
# 24        NO       3000           Member State       1994    7.362645
# 25        NO       3000           Member State       1994    6.400287
# 26        NO       3000           Member State       1994    6.447897
# 61       YES       3000  Sovereignty unsettled       2011    0.818949
#
#     Shape_Leng            official_name iso3  \
# 17   11.235001  Republic of South Sudan  SSD
# 18   11.096973  Republic of South Sudan  SSD
# 19   11.441561  Republic of South Sudan  SSD
# 20   13.566082  Republic of South Sudan  SSD
# 21   17.315025  Republic of South Sudan  SSD
# 22    7.052428  Republic of South Sudan  SSD
# 23    9.675830  Republic of South Sudan  SSD
# 24   15.653986  Republic of South Sudan  SSD
# 25   15.338082  Republic of South Sudan  SSD
# 26   15.496584  Republic of South Sudan  SSD
# 61    3.608281  Republic of South Sudan  SSD
#
#                                              geometry
# 17  POLYGON ((28.46691 6.47376, 28.46786 6.47947, ...
# 18  POLYGON ((28.71832 9.04250, 28.71832 9.04375, ...
# 19  POLYGON ((29.79232 4.50914, 29.79785 4.51991, ...
# 20  POLYGON ((31.69433 3.95444, 31.70147 3.96158, ...
# 21  POLYGON ((30.21263 8.91872, 30.21501 8.92348, ...
# 22  POLYGON ((26.13292 9.08244, 26.13530 9.10099, ...
# 23  POLYGON ((27.62626 8.28199, 27.62715 8.28258, ...
# 24  POLYGON ((24.15070 8.39634, 24.15072 8.39642, ...
# 25  POLYGON ((26.28462 6.45896, 26.29016 6.47718, ...
# 26  POLYGON ((30.74803 9.46688, 30.74923 9.53971, ...
# 61  POLYGON ((27.81417 9.80064, 27.81453 9.80080, ...

# %% [markdown]
# ### geometries at Admin 2 level

# %%
####Administrative level 2 geometries
#Extract Adm2 locations
emdat_geocode_adm2 = Emdata_geocode[Emdata_geocode['Geo Locations'].str.contains("(Adm2)")]
#In the Geo Locations column, some rows still have admin1 geometry locations that need to be removed
#clean Adm1 mention for the admin2 locations
emdat_geocode_adm2_cadm1 = emdat_geocode_adm2[emdat_geocode_adm2['Geo Locations'].str.contains("(Adm1)")]#location 2 with location 1 mentions still
#emdat_geocode_adm2_cadm1 = emdat_geocode_adm2_cadm1.reset_index().iloc[:,1::]
emdat_geocode_adm2_cadm1["Geo Locations"] = emdat_geocode_adm2_cadm1["Geo Locations"].str.split(" \(Adm1\).",expand=True)[1].str.replace(" \(Adm2\).","")
emdat_geocode_adm2_wtadm1 = emdat_geocode_adm2[~emdat_geocode_adm2['Geo Locations'].str.contains("(Adm1)")]
emdat_geocode_adm2_wtadm1["Geo Locations"] = emdat_geocode_adm2_wtadm1["Geo Locations"].str.replace(" \(Adm2\).","")

emdat_geocode_adm2 = pd.concat([emdat_geocode_adm2_cadm1,emdat_geocode_adm2_wtadm1])
# Out:
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:6: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:8: FutureWarning: The default value of regex will change from True to False in a future version.
#
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:9: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   if __name__ == "__main__":
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:10: FutureWarning: The default value of regex will change from True to False in a future version.
#   # Remove the CWD from sys.path while we load stuff.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.

# %%
emdat_geocode_adm2
# Out:
#                                              Admin1 Code  \
# DisNo.
# 1999-9388-BDI  40546;40548;40549;40552;40554;40557;40558
# 1999-9388-ETH                 1230;1232;47678;1236;47679
# 1999-9388-RWA                                      21970
# 1999-9388-SOM                                  2691;2695
# 2000-0012-MOZ                        2114;2115;2120;2121
# ...                                                  ...
# 2023-0391-VEN
# 2023-0451-COL
# 2023-0458-ITA
# 2023-0459-IND
# 2023-0529-FRA
#
#                                                    Admin2 Code  \
# DisNo.
# 1999-9388-BDI  40638;40605;40639;48356;40642;40643;40610;40596
# 1999-9388-ETH                  40799;40800;149281;149298;40803
# 1999-9388-RWA                    21981;21987;21989;21993;21998
# 1999-9388-SOM              25678;25657;25682;25658;25659;25661
# 2000-0012-MOZ  21850;21853;21855;21883;41375;41376;21885;21886
# ...                                                        ...
# 2023-0391-VEN                                            31914
# 2023-0451-COL                                            13906
# 2023-0458-ITA                                18415;18417;18420
# 2023-0459-IND                                            17777
# 2023-0529-FRA                                            16289
#
#                                                    Geo Locations  \
# DisNo.
# 1999-9388-BDI   Bugabira, Buganda, Busoni, Gihanga, Kirundo, ...
# 1999-9388-ETH   North Wollo, Oromia, South Wollo, Southern, W...
# 1999-9388-RWA            Huye, Muhanga, Ngoma, Nyamagabe, Rubavu
# 1999-9388-SOM   Baardheere, Ceel Barde, Garbahaarey, Rab Dhuu...
# 2000-0012-MOZ   Chibuto, Chokwe, Mabalane, Magude, Manhica, M...
# ...                                                          ...
# 2023-0391-VEN                                          El Callao
# 2023-0451-COL                                            Quetame
# 2023-0458-ITA                           Padova, Treviso, Vicenza
# 2023-0459-IND                                            Raigarh
# 2023-0529-FRA                                Pyrenees-Orientales
#
#                                                         Location
# DisNo.
# 1999-9388-BDI  Bugabira, Buganda, Busoni, Cankuzo provinces, ...
# 1999-9388-ETH  Beneshangul Gumu, Gambela, North Wollo, Oromia...
# 1999-9388-RWA  Butare village (Huye district, East/Iburasiraz...
# 1999-9388-SOM  Baardheere districts (Gedo province), Bay, Cee...
# 2000-0012-MOZ  Chibuto, Chokwe, Inhambane, Mabalane districts...
# ...                                                          ...
# 2023-0391-VEN                     El Callao City (Bolivar State)
# 2023-0451-COL     Quetame Municipality (Cundinamarca Department)
# 2023-0458-ITA        Padoue, Vicence et Trévise regions (Venise)
# 2023-0459-IND  Irshalwadi Village (Raigad District, western M...
# 2023-0529-FRA  Saint-André and Argelès-sur-Mer (Pyrénées-Orie...
#
# [4262 rows x 4 columns]

# %%
emdat_geocode_adm2['Geo Locations'].astype(str).str.split(',').apply(len).sum()
# Out:
# 17109

# %%
(emdat_geocode_adm2['Admin2 Code'].astype(str).str.split(';')).apply(len).sum()
# Out:
# 17109

# %% [markdown]
# ## 2) Matching events without geolocations, only location names (2021-2023)

# %%
#Shape Adm1 locations: 1 row = 1 geolocation
emdat_geocode_adm2_stacked = pd.DataFrame(emdat_geocode_adm2["Admin2 Code"].str.split(';', expand=True).stack()).rename(columns={0:'ADM2_CODE'})
emdat_geocode_adm2_stacked['location'] = pd.DataFrame(emdat_geocode_adm2["Location"].str.split(',', expand=True).stack())
emdat_geocode_adm2_stacked['geolocation'] = pd.DataFrame(emdat_geocode_adm2["Geo Locations"].str.split(',', expand=True).stack())
emdat_geocode_adm2_identified = emdat_geocode_adm2_stacked.reset_index()


##Load administrative boundries objects to merge locations with events

gaul1 = gpd.read_file('/net/projects/xaida/raw_data/gaul_maps/gaul_admin1_clean.gpkg')
gaul2 = gpd.read_file('/net/projects/xaida/raw_data/gaul_maps/gaul_admin2_clean.gpkg')

#get the admin1 geolocated events geometries #emdat_geocode_adm1_identified
emdat_geocode_adm1_identified['ADM1_CODE'] = emdat_geocode_adm1_identified['ADM1_CODE'].astype(int)
events_adm1  = emdat_geocode_adm1_identified.merge(gaul1, on='ADM1_CODE', how='left')

#get the admin2 geolocated events geometries #emdat_geocode_adm2_identified
emdat_geocode_adm2_identified['ADM2_CODE'] = emdat_geocode_adm2_identified['ADM2_CODE'].astype(int)
events_adm2  = emdat_geocode_adm2_identified.merge(gaul2, on='ADM2_CODE', how='left')

#Find the geolocations for the events of which we only have the location name #Emdata_locations_only
#this needs to be done in different steps, as we have no indication about the administrative level of the location
#also, looking up the geometries needs to take place for each country separately, to limit mismatch

# %%
#loading data again to work on data without geolocation

Emdata = pd.read_excel('/net/projects/xaida/raw_data/emdat_data/public_emdat_1990_2023.xlsx')
Emdata_loconly = Emdata[Emdata['Admin Units'].isna() & Emdata['Location'].notna()]

# %%
def split_and_clean_locations(location):
    entries = re.split(r';', location)
    cleaned_entries = []
    for entry in entries:
        if '(' in entry and ')' in entry:
            cleaned_entries.append(entry.strip())
        else:
            sub_entries = re.split(r',\s*(?![^()]*\))', entry)
            cleaned_entries.extend([sub_entry.strip() for sub_entry in sub_entries if sub_entry.strip()])
    return cleaned_entries

# Expand the DataFrame
expanded_rows = [
    [row['DisNo.'], row['Location'], loc]
    for _, row in Emdata_loconly.iterrows()
    for loc in split_and_clean_locations(row['Location'])
]

expanded_df = pd.DataFrame(expanded_rows, columns=['DisNo.', 'Full_Location_List', 'Individual_Location'])

# Clean the 'Individual_Location' column
replace_terms = ["Near", "Province", "province", "state", "City", "Regency", "provinces", "region", "Region", 
                 "district", "districts", "District", "Municipality", "municipality"]

for term in replace_terms:
    expanded_df['Individual_Location'] = expanded_df['Individual_Location'].str.replace(term, "", regex=False)

def split_text(text):
    if text.count('(') > 1:
        return re.split(r',\s*(?=\S)', re.sub(r'\),\s*(?=\S)', '),\n', text))
    return re.split(r'\),\s*(?=\S)', text)

expanded_df['Individual_Location'] = expanded_df['Individual_Location'].apply(split_text)
expanded_df = expanded_df.explode('Individual_Location', ignore_index=True)

expanded_df['Individual_Location'] = expanded_df['Individual_Location'].str.replace(' and ', ', ')

def extract_locations(row):
    locations = []
    if '(' in row:
        parts = row.split('(')
        locs = parts[0].strip().split(',')
        regions = parts[1].replace(')', '').split(',')
        for loc in locs:
            for sub_loc in loc.strip().split('/'):
                for region in regions:
                    locations.append([sub_loc.strip(), region.strip()])
    elif ',' in row:
        for loc in row.split(','):
            locations.append([loc.strip(), None])
    else:
        for loc in row.strip().split('/'):
            locations.append([loc.strip(), None])
    return locations

new_data = [
    [row['DisNo.'], row['Individual_Location'], loc[0], loc[1]]
    for _, row in expanded_df.iterrows()
    for loc in extract_locations(row['Individual_Location'])
]

new_df = pd.DataFrame(new_data, columns=['DisNo.', 'Individual_Location', 'Location_Before', 'Bracketed'])
new_df['Appended'] = new_df['Location_Before'] + new_df['Bracketed'].apply(lambda x: f" {x}" if x else "")

print(new_df)
# Out:
#               DisNo. Individual_Location Location_Before Bracketed    Appended
# 0      1990-0001-LKA              Ampara          Ampara      None      Ampara
# 1      1990-0001-LKA             Badulla         Badulla      None     Badulla
# 2      1990-0001-LKA               Kandy           Kandy      None       Kandy
# 3      1990-0001-LKA          Kurunegala      Kurunegala      None  Kurunegala
# 4      1990-0001-LKA              Matale          Matale      None      Matale
# ...              ...                 ...             ...       ...         ...
# 21524  2023-9873-FSM              Kosrae          Kosrae      None      Kosrae
# 21525  2023-9873-FSM             Pohnpei         Pohnpei      None     Pohnpei
# 21526  2023-9873-FSM                 Yap             Yap      None         Yap
# 21527  2023-9879-BWA            Southern        Southern      None    Southern
# 21528  2023-9879-BWA          North East      North East      None  North East
#
# [21529 rows x 5 columns]

# %% [markdown]
# ##Now Data with locations , no geocoded data is further divided into three columns Location_Before - Location that is present before (Bracket Admin1 location) and third column appending both location before and Brackted data

# %%
#now data is further divided into two data sets ,first  dataset with  bracket data,
#second dataset is with no bracket data.


new_df_1 = new_df[new_df['Bracketed'].isnull()]
new_df_2 = new_df[~new_df['Bracketed'].isnull()]

# %%
new_df_1
# Out:
#               DisNo. Individual_Location Location_Before Bracketed    Appended
# 0      1990-0001-LKA              Ampara          Ampara      None      Ampara
# 1      1990-0001-LKA             Badulla         Badulla      None     Badulla
# 2      1990-0001-LKA               Kandy           Kandy      None       Kandy
# 3      1990-0001-LKA          Kurunegala      Kurunegala      None  Kurunegala
# 4      1990-0001-LKA              Matale          Matale      None      Matale
# ...              ...                 ...             ...       ...         ...
# 21524  2023-9873-FSM              Kosrae          Kosrae      None      Kosrae
# 21525  2023-9873-FSM             Pohnpei         Pohnpei      None     Pohnpei
# 21526  2023-9873-FSM                 Yap             Yap      None         Yap
# 21527  2023-9879-BWA            Southern        Southern      None    Southern
# 21528  2023-9879-BWA          North East      North East      None  North East
#
# [15677 rows x 5 columns]

# %%
############################
## Functions needed for fuzzy matching of geometries by name
############################

from thefuzz import process
#function for fuzzy names matching
def fuzzy_match(
    df_left, df_right, column_left, column_right, threshold=90, limit=1):
    # Create a series
    series_matches = df_left[column_left].apply(
        lambda x: process.extract(x, df_right[column_right], limit=limit)            # Creates a series with id from df_left and column name _column_left_, with _limit_ matches per item
    )

    # Convert matches to a tidy dataframe
    df_matches = series_matches.to_frame()
    df_matches = df_matches.explode(column_left)     # Convert list of matches to rows
    df_matches[
        ['match_string', 'match_score', 'df_right_id']
    ] = pd.DataFrame(df_matches[column_left].tolist(), index=df_matches.index)       # Convert match tuple to columns
    df_matches.drop(column_left, axis=1, inplace=True)      # Drop column of match tuples

    # Reset index, as in creating a tidy dataframe we've introduced multiple rows per id, so that no longer functions well as the index
    if df_matches.index.name:
        index_name = df_matches.index.name     # Stash index name
    else:
        index_name = 'index'        # Default used by pandas
    df_matches.reset_index(inplace=True)
    df_matches.rename(columns={index_name: 'df_left_id'}, inplace=True)       # The previous index has now become a column: rename for ease of reference

    # Drop matches below threshold
    df_matches.drop(
        df_matches.loc[df_matches['match_score'] < threshold].index,
        inplace=True
    )

    return df_matches

# %%
#function for matching datasets uses fuzzy names matching
def match_datasets(df1, df2, col_a, col_b):
    
    df_matches = fuzzy_match(
    df1,
    df2,
    col_a,
    col_b,
    threshold=90,
    limit=1
    )

    df_output = df1.merge(
        df_matches,
        how='left',
        left_index=True,
        right_on='df_left_id'
    ).merge(
        df2,
        how='left',
        left_on='df_right_id',
        right_index=True,
        suffixes=['_df1', '_df2']
    )
    return(df_output)

# %%
#function for matching names with corresponding vector geometries
def match_emdat_gdis(emdat_df, gdam_df, iso,varname):
    
    ## EM-DAT preprocess
    emdat_iso = emdat_df[emdat_df["DisNo."].str.contains(iso)]
    emdat_iso = emdat_iso.rename(columns={varname:"name_join"})
    
    gdam_df = gdam_df[gdam_df["iso3"] == iso]
    #join name and alternative names to enhance accuracy
    gdam_df["name_join"] = gdam_df[[varname]].astype(str).agg(' - '.join, axis=1)
    
    if emdat_iso.empty | gdam_df.empty:
        return(gpd.GeoDataFrame())
    else:
        ####double the string to match in EM-DAT for maximal accuracy
        #emdat_iso["name_join"] = emdat_iso[['name_join','name_join']].astype(str).agg(' - '.join, axis=1)
        #Eliminate generic words related to Russian political entities that cause errors in matches
        emdat_iso["name_join"] = emdat_iso["name_join"].str.replace("Rep.","")
        emdat_iso["name_join"] = emdat_iso["name_join"].str.replace("Kray","")
        emdat_iso["name_join"] = emdat_iso["name_join"].str.replace("Oblast","")
        #Names of Russian regions that need to be changed
        emdat_iso["name_join"] = emdat_iso["name_join"].str.replace("Dagestan","Daghestan")
        emdat_iso["name_join"] = emdat_iso["name_join"].str.replace("Karelya","Karelia")
        emdat_iso["name_join"] = emdat_iso["name_join"].str.replace("Yevreyskaya A","Yevrey - Yevreyskaya")
        #Eliminate generic words related to Philippino political entities that cause errors in matches
        emdat_iso["name_join"] = emdat_iso["name_join"].str.replace("Region XIII","")
        emdat_iso["name_join"] = emdat_iso["name_join"].str.replace("Region XII","")
        emdat_iso["name_join"] = emdat_iso["name_join"].str.replace("Region XI","")
        emdat_iso["name_join"] = emdat_iso["name_join"].str.replace("Region X","")
        emdat_iso["name_join"] = emdat_iso["name_join"].str.replace("Region IX","")
        emdat_iso["name_join"] = emdat_iso["name_join"].str.replace("Region VIII","")
        emdat_iso["name_join"] = emdat_iso["name_join"].str.replace("Region VII","")
        emdat_iso["name_join"] = emdat_iso["name_join"].str.replace("Region VI","")
        emdat_iso["name_join"] = emdat_iso["name_join"].str.replace("Region VI","")
        emdat_iso["name_join"] = emdat_iso["name_join"].str.replace("Region V","")
        emdat_iso["name_join"] = emdat_iso["name_join"].str.replace("Region III","")
        emdat_iso["name_join"] = emdat_iso["name_join"].str.replace("Region II","")
        emdat_iso["name_join"] = emdat_iso["name_join"].str.replace("Region I","")   
        emdat_iso["name_join"] = emdat_iso["name_join"].str.replace("region ","")
        
        
        ##GADM preprocess
        
        #Eliminate generic words related to Russian political entities that cause errors in matches
        gdam_df["name_join"] = gdam_df["name_join"].str.replace("Republic of","")
        gdam_df["name_join"] = gdam_df["name_join"].str.replace("Republic","")
        gdam_df["name_join"] = gdam_df["name_join"].str.replace("Respublika","")
        gdam_df["name_join"] = gdam_df["name_join"].str.replace("Kray","")
        gdam_df["name_join"] = gdam_df["name_join"].str.replace("Oblast","")
        
        #Elimination of string in case of no entry
        gdam_df["name_join"] = gdam_df["name_join"].str.replace("- None","")
        
        #Sort both datasets alphabetically with the name join column
        emdat_iso = emdat_iso.sort_values("name_join")
        gdam_df = gdam_df.sort_values("name_join")
        
        #Merge datasets
        merged = match_datasets(emdat_iso, gdam_df, "name_join", "name_join")
        merged = gpd.GeoDataFrame(merged)
        return(merged)

# %%
#function for concatenating geopandas dataframes
def concat_db(db1, db2):
    return(pd.concat([db1, db2], axis=0))

# %%
#Emdata_locations_only.Location = Emdata_locations_only.Location.str.replace(" Near","").replace(" and ",",").replace(" 'province)","").replace(" 'province ","").replace("Between","").replace('Isl.',"").replace(' districts',"").replace(' region',"")

# %%
Emdata_locations_only = new_df_1[['DisNo.','Location_Before']]

Emdata_locations_only.reset_index(drop=True, inplace=True)


iso_locations = Emdata_locations_only['DisNo.'].str.split('-',expand=True)[2]
Emdata_locations_only['iso3'] = iso_locations #add iso3 codes of every location/ event
# Out:
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys

# %% [markdown]
# ## 3) Merging all geolocated events

# %%
#Administrative level 1
isos = np.unique(Emdata_locations_only["iso3"])#iso codes for the loop
final_db = gpd.GeoDataFrame()#empty geoDF for results

Emdata_locations_only = Emdata_locations_only.rename(columns={'Location_Before':"ADM1_NAME"})#change name of column to merge on

for iso in isos:
    db = match_emdat_gdis(Emdata_locations_only, gaul1, iso,"ADM1_NAME")
    if db.empty:
        pass
    else:
        final_db = pd.concat([final_db,db],axis=0)
        
locations_only_events_admin1 = final_db[~final_db['geometry'].isna()].reset_index().drop(columns={'index'})
# Out:
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.

# %%
locations_only_events_admin1
# Out:
#              DisNo. name_join_df1 iso3_df1  df_left_id        match_string  \
# 0     1999-0465-AFG   - Badakshan      AFG        7216          Badakhshan
# 1     2002-0666-AFG    Badakhshan      AFG        8691          Badakhshan
# 2     1998-0267-AFG    Badakhshan      AFG        6008          Badakhshan
# 3     1997-0097-AFG  Badakhshan s      AFG        4808          Badakhshan
# 4     1993-0169-AFG    Badakhstan      AFG        1950          Badakhshan
# ...             ...           ...      ...         ...                 ...
# 6940  2005-0726-ZWE      Midlands      ZWE        9739            Midlands
# 6941  2022-0569-ZWE      Midlands      ZWE       14429            Midlands
# 6942  2011-0276-ZWE         North      ZWE       11704  Matabeleland North
# 6943  2007-0632-ZWE         South      ZWE       10466  Matabeleland South
# 6944  2005-0726-ZWE          West      ZWE        9737    Mashonaland West
#
#       match_score  df_right_id  ADM0_CODE    ADM0_NAME  ADM1_CODE  ...  \
# 0            95.0        516.0        1.0  Afghanistan      272.0  ...
# 1           100.0        516.0        1.0  Afghanistan      272.0  ...
# 2           100.0        516.0        1.0  Afghanistan      272.0  ...
# 3            95.0        516.0        1.0  Afghanistan      272.0  ...
# 4            90.0        516.0        1.0  Afghanistan      272.0  ...
# ...           ...          ...        ...          ...        ...  ...
# 6940        100.0        139.0      271.0     Zimbabwe     3444.0  ...
# 6941        100.0        139.0      271.0     Zimbabwe     3444.0  ...
# 6942         90.0         34.0      271.0     Zimbabwe    69549.0  ...
# 6943         90.0        138.0      271.0     Zimbabwe     3443.0  ...
# 6944         90.0        136.0      271.0     Zimbabwe     3440.0  ...
#
#      DISP_AREA EXP1_YEAR        STATUS STR1_YEAR  Shape_Area  Shape_Leng  \
# 0           NO    3000.0  Member State    1000.0    4.398368   20.784230
# 1           NO    3000.0  Member State    1000.0    4.398368   20.784230
# 2           NO    3000.0  Member State    1000.0    4.398368   20.784230
# 3           NO    3000.0  Member State    1000.0    4.398368   20.784230
# 4           NO    3000.0  Member State    1000.0    4.398368   20.784230
# ...        ...       ...           ...       ...         ...         ...
# 6940        NO    3000.0  Member State    1000.0    4.231023   16.425649
# 6941        NO    3000.0  Member State    1000.0    4.231023   16.425649
# 6942        NO    3000.0  Member State    1997.0    6.474435   16.788383
# 6943        NO    3000.0  Member State    1000.0    4.720131   16.330050
# 6944        NO    3000.0  Member State    1000.0    4.898301   14.873909
#
#                         official_name iso3_df2  \
# 0     Islamic Republic of Afghanistan      AFG
# 1     Islamic Republic of Afghanistan      AFG
# 2     Islamic Republic of Afghanistan      AFG
# 3     Islamic Republic of Afghanistan      AFG
# 4     Islamic Republic of Afghanistan      AFG
# ...                               ...      ...
# 6940             Republic of Zimbabwe      ZWE
# 6941             Republic of Zimbabwe      ZWE
# 6942             Republic of Zimbabwe      ZWE
# 6943             Republic of Zimbabwe      ZWE
# 6944             Republic of Zimbabwe      ZWE
#
#                                                geometry       name_join_df2
# 0     POLYGON ((69.98554 36.78234, 69.98748 36.78352...          Badakhshan
# 1     POLYGON ((69.98554 36.78234, 69.98748 36.78352...          Badakhshan
# 2     POLYGON ((69.98554 36.78234, 69.98748 36.78352...          Badakhshan
# 3     POLYGON ((69.98554 36.78234, 69.98748 36.78352...          Badakhshan
# 4     POLYGON ((69.98554 36.78234, 69.98748 36.78352...          Badakhshan
# ...                                                 ...                 ...
# 6940  POLYGON ((27.99733 -18.23833, 27.99745 -18.238...            Midlands
# 6941  POLYGON ((27.99733 -18.23833, 27.99745 -18.238...            Midlands
# 6942  POLYGON ((25.23703 -17.88990, 25.23757 -17.877...  Matabeleland North
# 6943  POLYGON ((26.69159 -19.89356, 26.69162 -19.893...  Matabeleland South
# 6944  POLYGON ((28.01492 -16.87896, 28.01525 -16.878...    Mashonaland West
#
# [6945 rows x 21 columns]

# %% [markdown]
# #consider only geometries where the location string exists in the geometry string name of the gaul object
# #events_admin1_locations_only_valid = locations_only_events_admin1[locations_only_events_admin1.apply(lambda x: x['name_join_df2'] in x['name_join_df1'], axis=1)]

# %%
events_admin1_locations_only_valid = locations_only_events_admin1[locations_only_events_admin1.match_score >= 90]

# %%
events_admin1_locations_only_valid
# Out:
#              DisNo. name_join_df1 iso3_df1  df_left_id        match_string  \
# 0     1999-0465-AFG   - Badakshan      AFG        7216          Badakhshan
# 1     2002-0666-AFG    Badakhshan      AFG        8691          Badakhshan
# 2     1998-0267-AFG    Badakhshan      AFG        6008          Badakhshan
# 3     1997-0097-AFG  Badakhshan s      AFG        4808          Badakhshan
# 4     1993-0169-AFG    Badakhstan      AFG        1950          Badakhshan
# ...             ...           ...      ...         ...                 ...
# 6940  2005-0726-ZWE      Midlands      ZWE        9739            Midlands
# 6941  2022-0569-ZWE      Midlands      ZWE       14429            Midlands
# 6942  2011-0276-ZWE         North      ZWE       11704  Matabeleland North
# 6943  2007-0632-ZWE         South      ZWE       10466  Matabeleland South
# 6944  2005-0726-ZWE          West      ZWE        9737    Mashonaland West
#
#       match_score  df_right_id  ADM0_CODE    ADM0_NAME  ADM1_CODE  ...  \
# 0            95.0        516.0        1.0  Afghanistan      272.0  ...
# 1           100.0        516.0        1.0  Afghanistan      272.0  ...
# 2           100.0        516.0        1.0  Afghanistan      272.0  ...
# 3            95.0        516.0        1.0  Afghanistan      272.0  ...
# 4            90.0        516.0        1.0  Afghanistan      272.0  ...
# ...           ...          ...        ...          ...        ...  ...
# 6940        100.0        139.0      271.0     Zimbabwe     3444.0  ...
# 6941        100.0        139.0      271.0     Zimbabwe     3444.0  ...
# 6942         90.0         34.0      271.0     Zimbabwe    69549.0  ...
# 6943         90.0        138.0      271.0     Zimbabwe     3443.0  ...
# 6944         90.0        136.0      271.0     Zimbabwe     3440.0  ...
#
#      DISP_AREA EXP1_YEAR        STATUS STR1_YEAR  Shape_Area  Shape_Leng  \
# 0           NO    3000.0  Member State    1000.0    4.398368   20.784230
# 1           NO    3000.0  Member State    1000.0    4.398368   20.784230
# 2           NO    3000.0  Member State    1000.0    4.398368   20.784230
# 3           NO    3000.0  Member State    1000.0    4.398368   20.784230
# 4           NO    3000.0  Member State    1000.0    4.398368   20.784230
# ...        ...       ...           ...       ...         ...         ...
# 6940        NO    3000.0  Member State    1000.0    4.231023   16.425649
# 6941        NO    3000.0  Member State    1000.0    4.231023   16.425649
# 6942        NO    3000.0  Member State    1997.0    6.474435   16.788383
# 6943        NO    3000.0  Member State    1000.0    4.720131   16.330050
# 6944        NO    3000.0  Member State    1000.0    4.898301   14.873909
#
#                         official_name iso3_df2  \
# 0     Islamic Republic of Afghanistan      AFG
# 1     Islamic Republic of Afghanistan      AFG
# 2     Islamic Republic of Afghanistan      AFG
# 3     Islamic Republic of Afghanistan      AFG
# 4     Islamic Republic of Afghanistan      AFG
# ...                               ...      ...
# 6940             Republic of Zimbabwe      ZWE
# 6941             Republic of Zimbabwe      ZWE
# 6942             Republic of Zimbabwe      ZWE
# 6943             Republic of Zimbabwe      ZWE
# 6944             Republic of Zimbabwe      ZWE
#
#                                                geometry       name_join_df2
# 0     POLYGON ((69.98554 36.78234, 69.98748 36.78352...          Badakhshan
# 1     POLYGON ((69.98554 36.78234, 69.98748 36.78352...          Badakhshan
# 2     POLYGON ((69.98554 36.78234, 69.98748 36.78352...          Badakhshan
# 3     POLYGON ((69.98554 36.78234, 69.98748 36.78352...          Badakhshan
# 4     POLYGON ((69.98554 36.78234, 69.98748 36.78352...          Badakhshan
# ...                                                 ...                 ...
# 6940  POLYGON ((27.99733 -18.23833, 27.99745 -18.238...            Midlands
# 6941  POLYGON ((27.99733 -18.23833, 27.99745 -18.238...            Midlands
# 6942  POLYGON ((25.23703 -17.88990, 25.23757 -17.877...  Matabeleland North
# 6943  POLYGON ((26.69159 -19.89356, 26.69162 -19.893...  Matabeleland South
# 6944  POLYGON ((28.01492 -16.87896, 28.01525 -16.878...    Mashonaland West
#
# [6945 rows x 21 columns]

# %%
events_admin1_locations_only_valid[['name_join_df1','name_join_df2']].iloc[100:150]
# Out:
#         name_join_df1   name_join_df2
# 100             Zabul           Zabul
# 101             Zabul           Zabul
# 102             Zabul           Zabul
# 103             Zabul           Zabul
# 104             Zabul           Zabul
# 105             Bengo           Bengo
# 106             Bengo           Bengo
# 107             Bengo           Bengo
# 108          Benguela        Benguela
# 109          Benguela        Benguela
# 110          Benguela        Benguela
# 111          Benguela        Benguela
# 112          Benguela        Benguela
# 113          Benguela        Benguela
# 114          Benguela        Benguela
# 115    Between Luanda          Luanda
# 116    Between Luanda          Luanda
# 117               Bie             Bie
# 118               Bie             Bie
# 119               Bie             Bie
# 120               Biè             Bie
# 121               Bié             Bie
# 122           Cabinda         Cabinda
# 123           Cabinda         Cabinda
# 124           Cabinda         Cabinda
# 125            Cuando  Cuando Cubango
# 126  Cuando Cubango s  Cuando Cubango
# 127           Cubango  Cuando Cubango
# 128            Cunene          Cunene
# 129            Cunene          Cunene
# 130          Cunene s          Cunene
# 131             Huamb          Huambo
# 132            Huambo          Huambo
# 133            Huambo          Huambo
# 134            Huambo          Huambo
# 135            Huambo          Huambo
# 136            Huambo          Huambo
# 137            Huambo          Huambo
# 138            Huambo          Huambo
# 139             Huila           Huila
# 140             Huila           Huila
# 141             Huila           Huila
# 142             Huila           Huila
# 143      Kuanza Norte    Kuanza Norte
# 144        Kuanza Sul      Cuanza Sul
# 145        Kuanza Sul      Cuanza Sul
# 146      Kwanza Norte    Kuanza Norte
# 147      Kwanza Norte    Kuanza Norte
# 148      Kwanza Norte    Kuanza Norte
# 149            Luanda          Luanda

# %%
#gaul2['ADM2_NAME_join'] = gaul2[['ADM1_NAME', 'ADM2_NAME']].astype(str).agg('  '.join, axis=1)

# %%
gaul2['ADM2_NAME_join'] = gaul2[['ADM2_NAME']]

# %%
#Administrative level 2
Emdata_locations_only['ADM2_NAME_join'] = Emdata_locations_only['ADM1_NAME']
final_db2 = gpd.GeoDataFrame()#empty geoDF for results

for iso in isos:
    db2 = match_emdat_gdis(Emdata_locations_only, gaul2, iso,"ADM2_NAME_join")
    if db2.empty:
        pass
    else:
        final_db2 = pd.concat([final_db2,db2],axis=0)
        
locations_only_events_admin2 = final_db2[~final_db2['geometry'].isna()].reset_index().drop(columns={'index'})
# Out:
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.

# %%
events_admin2_locations_only_valid = locations_only_events_admin2[locations_only_events_admin2.match_score >= 90]

# %%
#consider only geometries where the location string exists in the geometry string name of the gaul object
#events_admin2_locations_only_valid = locations_only_events_admin2[locations_only_events_admin2.apply(lambda x: x['name_join_df2'] in x['name_join_df1'], axis=1)]

# %%
events_admin2_locations_only_valid
# Out:
#              DisNo. ADM1_NAME_df1 iso3_df1 name_join_df1  df_left_id  \
# 0     2001-0331-AFG        Aibak)      AFG        Aibak)        8169
# 1     2003-0375-AFG         Aqcha      AFG         Aqcha        8956
# 2     2005-0326-AFG       Baghlan      AFG       Baghlan        9555
# 3     1997-0097-AFG       Baghlan      AFG       Baghlan        4806
# 4     1998-0267-AFG       Baghlan      AFG       Baghlan        6003
# ...             ...           ...      ...           ...         ...
# 6429  2023-0719-ZWE         Wedza      ZWE         Wedza       15382
# 6430  2008-0511-ZWE        Zvimba      ZWE        Zvimba       10832
# 6431  1999-0634-ZWE        Zvimba      ZWE        Zvimba        7429
# 6432  2008-0511-ZWE    Zvishavane      ZWE    Zvishavane       10847
# 6433  2023-0719-ZWE         uhera      ZWE         uhera       15366
#
#          match_string  match_score  df_right_id  ADM0_CODE    ADM0_NAME  ...  \
# 0                 Bak         90.0      16372.0        1.0  Afghanistan  ...
# 1               Aqcha        100.0      17494.0        1.0  Afghanistan  ...
# 2     Baghlan-e-Jadid         90.0      16297.0        1.0  Afghanistan  ...
# 3     Baghlan-e-Jadid         90.0      16297.0        1.0  Afghanistan  ...
# 4     Baghlan-e-Jadid         90.0      16297.0        1.0  Afghanistan  ...
# ...               ...          ...          ...        ...          ...  ...
# 6429           Hwedza         91.0       2526.0      271.0     Zimbabwe  ...
# 6430           Zvimba        100.0       2515.0      271.0     Zimbabwe  ...
# 6431           Zvimba        100.0       2515.0      271.0     Zimbabwe  ...
# 6432       Zvishavane        100.0      10433.0      271.0     Zimbabwe  ...
# 6433           Buhera         91.0      10413.0      271.0     Zimbabwe  ...
#
#       EXP2_YEAR        STATUS  STR2_YEAR Shape_Area Shape_Leng  \
# 0        3000.0  Member State     1000.0   0.016539   0.726353
# 1        3000.0  Member State     2004.0   0.015729   0.639598
# 2        3000.0  Member State     2004.0   0.260793   2.642237
# 3        3000.0  Member State     2004.0   0.260793   2.642237
# 4        3000.0  Member State     2004.0   0.260793   2.642237
# ...         ...           ...        ...        ...        ...
# 6429     3000.0  Member State     1000.0   0.219286   2.792234
# 6430     3000.0  Member State     1000.0   0.518949   5.658163
# 6431     3000.0  Member State     1000.0   0.518949   5.658163
# 6432     3000.0  Member State     1000.0   0.212085   2.791582
# 6433     3000.0  Member State     1000.0   0.461110   4.061706
#
#                         official_name iso3_df2  \
# 0     Islamic Republic of Afghanistan      AFG
# 1     Islamic Republic of Afghanistan      AFG
# 2     Islamic Republic of Afghanistan      AFG
# 3     Islamic Republic of Afghanistan      AFG
# 4     Islamic Republic of Afghanistan      AFG
# ...                               ...      ...
# 6429             Republic of Zimbabwe      ZWE
# 6430             Republic of Zimbabwe      ZWE
# 6431             Republic of Zimbabwe      ZWE
# 6432             Republic of Zimbabwe      ZWE
# 6433             Republic of Zimbabwe      ZWE
#
#                                                geometry   ADM2_NAME_join  \
# 0     POLYGON ((69.96592 33.57779, 69.96932 33.58159...              Bak
# 1     POLYGON ((66.20807 36.96791, 66.20920 36.96242...            Aqcha
# 2     POLYGON ((68.53223 36.15923, 68.53070 36.16115...  Baghlan-e-Jadid
# 3     POLYGON ((68.53223 36.15923, 68.53070 36.16115...  Baghlan-e-Jadid
# 4     POLYGON ((68.53223 36.15923, 68.53070 36.16115...  Baghlan-e-Jadid
# ...                                                 ...              ...
# 6429  POLYGON ((31.98308 -19.11863, 31.98306 -19.118...           Hwedza
# 6430  POLYGON ((30.61135 -17.55053, 30.61137 -17.553...           Zvimba
# 6431  POLYGON ((30.61135 -17.55053, 30.61137 -17.553...           Zvimba
# 6432  POLYGON ((30.09545 -20.14557, 30.09764 -20.147...       Zvishavane
# 6433  POLYGON ((31.18835 -19.23481, 31.22039 -19.231...           Buhera
#
#         name_join_df2
# 0                 Bak
# 1               Aqcha
# 2     Baghlan-e-Jadid
# 3     Baghlan-e-Jadid
# 4     Baghlan-e-Jadid
# ...               ...
# 6429           Hwedza
# 6430           Zvimba
# 6431           Zvimba
# 6432       Zvishavane
# 6433           Buhera
#
# [6434 rows x 25 columns]

# %%
events_admin2_locations_only_valid[['name_join_df1','name_join_df2']].iloc[300:350]
# Out:
#             name_join_df1  name_join_df2
# 300            Abomey-Zou         Abomey
# 301         Acomey-Calavi  Abomey-calavi
# 302              Adjohoun       Adjohoun
# 303     Aguegues villages        Aguegue
# 304                Allada         Allada
# 305                Allada         Allada
# 306                 Bante          Bante
# 307              Bassilla        Bassila
# 308         Between Ketou          Ketou
# 309       Between Parakou        Parakou
# 310                    Bo         Abomey
# 311               Bohicon        Bohicon
# 312               Cotonou        Cotonou
# 313               Cotonou        Cotonou
# 314               Cotonou        Cotonou
# 315               Cotonou        Cotonou
# 316               Cotonou        Cotonou
# 317               Cotonou        Cotonou
# 318               Cotonou        Cotonou
# 319                Dangbo         Dangbo
# 320                 Dassa          Dassa
# 321           Dassa-Zoumè          Dassa
# 322                Djidja         Djidja
# 323               Djougou        Djougou
# 324              Gogounou       Gogounou
# 325            Grand-Popo     Grand-popo
# 326            Malanville     Malanville
# 327            Malanville     Malanville
# 328            Natitingou     Natitingou
# 329                Ouesse         Ouesse
# 330               Parakou        Parakou
# 331            Porto Novo     Porto-novo
# 332            Porto-Novo     Porto-novo
# 333               Savalou        Savalou
# 334            Seme Podji    Seme-kpodji
# 335               Sinende        Sinende
# 336                So-Ava         So-ava
# 337                So-Ava         So-ava
# 338  Tori-Bossito commune   Tori-bossito
# 339              Toviklin       Toviklin
# 340            Zangnanado     Zangnanado
# 341                    Ze             Ze
# 342             Zogbodome      Zogbodome
# 343                   Zou   Agbangnizoun
# 344                    ou     Adja-ouere
# 345                   Bam            Bam
# 346                   Bam            Bam
# 347                Bazega         Bazega
# 348            Bougouriba     Bougouriba
# 349               Boulgou        Boulgou

# %%
# Merge the two DataFrames based on the columns 'name_join_df1' and 'DisNo.'
merged_df = pd.merge(events_admin2_locations_only_valid,
                     events_admin1_locations_only_valid,
                     on=['name_join_df1', 'DisNo.'],
                     how='left',
                     suffixes=('', '_right'),
                     indicator=True)

# Keep only the rows from events_admin2_locations_only_valid that are not present in events_admin1_locations_only_valid
events_admin2_locations_only_valid = merged_df.loc[merged_df['_merge'] == 'left_only', events_admin2_locations_only_valid.columns]

# %%
events_admin2_locations_only_valid
# Out:
#              DisNo.  ADM1_NAME_df1 iso3_df1  name_join_df1  df_left_id  \
# 0     2001-0331-AFG         Aibak)      AFG         Aibak)        8169
# 1     2003-0375-AFG          Aqcha      AFG          Aqcha        8956
# 5     1997-0097-AFG           Balk      AFG           Balk        4804
# 10    1999-0054-AFG   Baraki Barak      AFG   Baraki Barak        6601
# 11    2010-0108-AFG  Col de Salang      AFG  Col de Salang       11264
# ...             ...            ...      ...            ...         ...
# 6453  2023-0719-ZWE          Wedza      ZWE          Wedza       15382
# 6454  2008-0511-ZWE         Zvimba      ZWE         Zvimba       10832
# 6455  1999-0634-ZWE         Zvimba      ZWE         Zvimba        7429
# 6456  2008-0511-ZWE     Zvishavane      ZWE     Zvishavane       10847
# 6457  2023-0719-ZWE          uhera      ZWE          uhera       15366
#
#      match_string  match_score  df_right_id  ADM0_CODE    ADM0_NAME  ...  \
# 0             Bak         90.0      16372.0        1.0  Afghanistan  ...
# 1           Aqcha        100.0      17494.0        1.0  Afghanistan  ...
# 5         Balkhab         90.0      17453.0        1.0  Afghanistan  ...
# 10    Barakibarak         96.0      16386.0        1.0  Afghanistan  ...
# 11         Salang         90.0      16455.0        1.0  Afghanistan  ...
# ...           ...          ...          ...        ...          ...  ...
# 6453       Hwedza         91.0       2526.0      271.0     Zimbabwe  ...
# 6454       Zvimba        100.0       2515.0      271.0     Zimbabwe  ...
# 6455       Zvimba        100.0       2515.0      271.0     Zimbabwe  ...
# 6456   Zvishavane        100.0      10433.0      271.0     Zimbabwe  ...
# 6457       Buhera         91.0      10413.0      271.0     Zimbabwe  ...
#
#       EXP2_YEAR        STATUS  STR2_YEAR Shape_Area Shape_Leng  \
# 0        3000.0  Member State     1000.0   0.016539   0.726353
# 1        3000.0  Member State     2004.0   0.015729   0.639598
# 5        3000.0  Member State     1000.0   0.295543   2.820322
# 10       3000.0  Member State     1000.0   0.026634   0.834392
# 11       3000.0  Member State     1000.0   0.051562   1.139820
# ...         ...           ...        ...        ...        ...
# 6453     3000.0  Member State     1000.0   0.219286   2.792234
# 6454     3000.0  Member State     1000.0   0.518949   5.658163
# 6455     3000.0  Member State     1000.0   0.518949   5.658163
# 6456     3000.0  Member State     1000.0   0.212085   2.791582
# 6457     3000.0  Member State     1000.0   0.461110   4.061706
#
#                         official_name iso3_df2  \
# 0     Islamic Republic of Afghanistan      AFG
# 1     Islamic Republic of Afghanistan      AFG
# 5     Islamic Republic of Afghanistan      AFG
# 10    Islamic Republic of Afghanistan      AFG
# 11    Islamic Republic of Afghanistan      AFG
# ...                               ...      ...
# 6453             Republic of Zimbabwe      ZWE
# 6454             Republic of Zimbabwe      ZWE
# 6455             Republic of Zimbabwe      ZWE
# 6456             Republic of Zimbabwe      ZWE
# 6457             Republic of Zimbabwe      ZWE
#
#                                                geometry  ADM2_NAME_join  \
# 0     POLYGON ((69.96592 33.57779, 69.96932 33.58159...             Bak
# 1     POLYGON ((66.20807 36.96791, 66.20920 36.96242...           Aqcha
# 5     POLYGON ((66.89229 35.40295, 66.88988 35.40346...         Balkhab
# 10    POLYGON ((68.75063 33.91986, 68.75095 33.92102...     Barakibarak
# 11    POLYGON ((69.24382 35.16703, 69.24326 35.16527...          Salang
# ...                                                 ...             ...
# 6453  POLYGON ((31.98308 -19.11863, 31.98306 -19.118...          Hwedza
# 6454  POLYGON ((30.61135 -17.55053, 30.61137 -17.553...          Zvimba
# 6455  POLYGON ((30.61135 -17.55053, 30.61137 -17.553...          Zvimba
# 6456  POLYGON ((30.09545 -20.14557, 30.09764 -20.147...      Zvishavane
# 6457  POLYGON ((31.18835 -19.23481, 31.22039 -19.231...          Buhera
#
#       name_join_df2
# 0               Bak
# 1             Aqcha
# 5           Balkhab
# 10      Barakibarak
# 11           Salang
# ...             ...
# 6453         Hwedza
# 6454         Zvimba
# 6455         Zvimba
# 6456     Zvishavane
# 6457         Buhera
#
# [3216 rows x 25 columns]

# %%
#for dataset with bracket , repeating the same process , but only in admin 2


Emdata_locations_only = new_df_2[['DisNo.','Appended']]

Emdata_locations_only.reset_index(drop=True, inplace=True)


iso_locations = Emdata_locations_only['DisNo.'].str.split('-',expand=True)[2]
Emdata_locations_only['iso3'] = iso_locations #add iso3 codes of every location/ event
# Out:
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.

# %%
isos = np.unique(Emdata_locations_only["iso3"])#iso codes for the loop
final_db = gpd.GeoDataFrame()#empty geoDF for results

Emdata_locations_only = Emdata_locations_only.rename(columns={'Appended':"ADM1_NAME"})#change name of column to merge on

for iso in isos:
    db = match_emdat_gdis(Emdata_locations_only, gaul1, iso,"ADM1_NAME")
    if db.empty:
        pass
    else:
        final_db = pd.concat([final_db,db],axis=0)
        
locations_only_events_admin1 = final_db[~final_db['geometry'].isna()].reset_index().drop(columns={'index'})
# Out:
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.

# %%
events_admin1_locations_only_valid1 = locations_only_events_admin1[locations_only_events_admin1.match_score >= 90]

# %%
events_admin1_locations_only_valid1
# Out:
#              DisNo.                          name_join_df1 iso3_df1  \
# 0     2012-0361-AFG                         Ab Band Ghazni      AFG
# 1     2017-0026-AFG  Afsay Village - Barg-e-Matal Nuristan      AFG
# 2     2018-0398-AFG                        Anar Dara Farah      AFG
# 3     1991-0130-AFG                          Aqcha Jawzjan      AFG
# 4     1991-0130-AFG                        Arabjar Jawzjan      AFG
# ...             ...                                    ...      ...
# 2655  2007-0432-ZWE         South Rural s Mashonaland West      ZWE
# 2656  2007-0432-ZWE                 South Rural s Midlands      ZWE
# 2657  2008-0511-ZWE                          Zaka Masvingo      ZWE
# 2658  2009-0645-ZWE                          Zaka Masvingo      ZWE
# 2659  2009-0645-ZWE                Zvimba Mashonaland West      ZWE
#
#       df_left_id      match_string  match_score  df_right_id  ADM0_CODE  \
# 0           4304            Ghazni         90.0        523.0        1.0
# 1           4776          Nuristan         90.0        537.0        1.0
# 2           4952             Farah         90.0        521.0        1.0
# 3            199           Jawzjan         90.0        527.0        1.0
# 4            193           Jawzjan         90.0        527.0        1.0
# ...          ...               ...          ...          ...        ...
# 2655        3595  Mashonaland West         90.0        136.0      271.0
# 2656        3596          Midlands         90.0        139.0      271.0
# 2657        3763          Masvingo         90.0        137.0      271.0
# 2658        3937          Masvingo         90.0        137.0      271.0
# 2659        3920  Mashonaland West         95.0        136.0      271.0
#
#         ADM0_NAME  ADM1_CODE  ... DISP_AREA EXP1_YEAR        STATUS STR1_YEAR  \
# 0     Afghanistan      279.0  ...        NO    3000.0  Member State    1000.0
# 1     Afghanistan      294.0  ...        NO    3000.0  Member State    1000.0
# 2     Afghanistan      277.0  ...        NO    3000.0  Member State    1000.0
# 3     Afghanistan      283.0  ...        NO    3000.0  Member State    1000.0
# 4     Afghanistan      283.0  ...        NO    3000.0  Member State    1000.0
# ...           ...        ...  ...       ...       ...           ...       ...
# 2655     Zimbabwe     3440.0  ...        NO    3000.0  Member State    1000.0
# 2656     Zimbabwe     3444.0  ...        NO    3000.0  Member State    1000.0
# 2657     Zimbabwe     3441.0  ...        NO    3000.0  Member State    1000.0
# 2658     Zimbabwe     3441.0  ...        NO    3000.0  Member State    1000.0
# 2659     Zimbabwe     3440.0  ...        NO    3000.0  Member State    1000.0
#
#       Shape_Area  Shape_Leng                    official_name iso3_df2  \
# 0       2.099038   10.285901  Islamic Republic of Afghanistan      AFG
# 1       0.892065    6.551736  Islamic Republic of Afghanistan      AFG
# 2       4.718270   15.358933  Islamic Republic of Afghanistan      AFG
# 3       1.121940    6.203613  Islamic Republic of Afghanistan      AFG
# 4       1.121940    6.203613  Islamic Republic of Afghanistan      AFG
# ...          ...         ...                              ...      ...
# 2655    4.898301   14.873909             Republic of Zimbabwe      ZWE
# 2656    4.231023   16.425649             Republic of Zimbabwe      ZWE
# 2657    4.898562   12.419403             Republic of Zimbabwe      ZWE
# 2658    4.898562   12.419403             Republic of Zimbabwe      ZWE
# 2659    4.898301   14.873909             Republic of Zimbabwe      ZWE
#
#                                                geometry     name_join_df2
# 0     POLYGON ((66.82213 33.55940, 66.82243 33.56079...            Ghazni
# 1     POLYGON ((69.91360 35.35015, 69.91401 35.35259...          Nuristan
# 2     POLYGON ((60.58315 33.12982, 60.58746 33.13812...             Farah
# 3     POLYGON ((65.17136 35.94923, 65.17201 35.95074...           Jawzjan
# 4     POLYGON ((65.17136 35.94923, 65.17201 35.95074...           Jawzjan
# ...                                                 ...               ...
# 2655  POLYGON ((28.01492 -16.87896, 28.01525 -16.878...  Mashonaland West
# 2656  POLYGON ((27.99733 -18.23833, 27.99745 -18.238...          Midlands
# 2657  POLYGON ((29.73057 -21.02383, 29.73119 -21.024...          Masvingo
# 2658  POLYGON ((29.73057 -21.02383, 29.73119 -21.024...          Masvingo
# 2659  POLYGON ((28.01492 -16.87896, 28.01525 -16.878...  Mashonaland West
#
# [2660 rows x 21 columns]

# %%
gaul2['ADM2_NAME_join'] = gaul2[['ADM1_NAME', 'ADM2_NAME']].astype(str).agg('  '.join, axis=1)

# %%
Emdata_locations_only['ADM2_NAME_join'] = Emdata_locations_only['ADM1_NAME']
final_db2 = gpd.GeoDataFrame()#empty geoDF for results

for iso in isos:
    db2 = match_emdat_gdis(Emdata_locations_only, gaul2, iso,"ADM2_NAME_join")
    if db2.empty:
        pass
    else:
        final_db2 = pd.concat([final_db2,db2],axis=0)
        
locations_only_events_admin2 = final_db2[~final_db2['geometry'].isna()].reset_index().drop(columns={'index'})
# Out:
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.

# %%
events_admin2_locations_only_valid1 = locations_only_events_admin2[locations_only_events_admin2.match_score >= 90]

# %%
events_admin2_locations_only_valid1
# Out:
#              DisNo.            ADM1_NAME_df1 iso3_df1  \
# 0     2012-0361-AFG           Ab Band Ghazni      AFG
# 1     2018-0398-AFG          Anar Dara Farah      AFG
# 2     1991-0130-AFG            Aqcha Jawzjan      AFG
# 3     1993-0169-AFG          Chindawal Kabul      AFG
# 4     2002-0703-AFG         Darwaz Badakshan      AFG
# ...             ...                      ...      ...
# 1279  2009-0645-ZWE    SEke Mashonaland West      ZWE
# 1280  2008-0511-ZWE    Seke Mashonaland East      ZWE
# 1281  2008-0511-ZWE            Zaka Masvingo      ZWE
# 1282  2009-0645-ZWE            Zaka Masvingo      ZWE
# 1283  2009-0645-ZWE  Zvimba Mashonaland West      ZWE
#
#                 name_join_df1  df_left_id              match_string  \
# 0              Ab Band Ghazni        4304            Ghazni  Ghazni
# 1             Anar Dara Farah        4952              Farah  Farah
# 2               Aqcha Jawzjan         199            Jawzjan  Aqcha
# 3             Chindawal Kabul         632              Kabul  Kabul
# 4            Darwaz Badakshan        2543        Badakhshan  Darwaz
# ...                       ...         ...                       ...
# 1279    SEke Mashonaland West        3926    Mashonaland East  Seke
# 1280    Seke Mashonaland East        3757    Mashonaland East  Seke
# 1281            Zaka Masvingo        3763        Masvingo  Masvingo
# 1282            Zaka Masvingo        3937        Masvingo  Masvingo
# 1283  Zvimba Mashonaland West        3920  Mashonaland West  Zvimba
#
#       match_score  df_right_id  ADM0_CODE    ADM0_NAME  ...  EXP2_YEAR  \
# 0            95.0      16352.0        1.0  Afghanistan  ...     3000.0
# 1            95.0      17376.0        1.0  Afghanistan  ...     3000.0
# 2            95.0      17494.0        1.0  Afghanistan  ...     3000.0
# 3            95.0      16409.0        1.0  Afghanistan  ...     3000.0
# 4            92.0      16318.0        1.0  Afghanistan  ...     3000.0
# ...           ...          ...        ...          ...  ...        ...
# 1279         90.0       2531.0      271.0     Zimbabwe  ...     3000.0
# 1280         95.0       2531.0      271.0     Zimbabwe  ...     3000.0
# 1281         95.0      10421.0      271.0     Zimbabwe  ...     3000.0
# 1282         95.0      10421.0      271.0     Zimbabwe  ...     3000.0
# 1283         95.0       2515.0      271.0     Zimbabwe  ...     3000.0
#
#             STATUS  STR2_YEAR Shape_Area Shape_Leng  \
# 0     Member State     1000.0   0.034933   0.988983
# 1     Member State     1000.0   0.326498   3.870752
# 2     Member State     2004.0   0.015729   0.639598
# 3     Member State     1000.0   0.034377   1.168943
# 4     Member State     2004.0   0.125913   1.879592
# ...            ...        ...        ...        ...
# 1279  Member State     1000.0   0.225164   3.924185
# 1280  Member State     1000.0   0.225164   3.924185
# 1281  Member State     1000.0   0.598281   5.458565
# 1282  Member State     1000.0   0.598281   5.458565
# 1283  Member State     1000.0   0.518949   5.658163
#
#                         official_name iso3_df2  \
# 0     Islamic Republic of Afghanistan      AFG
# 1     Islamic Republic of Afghanistan      AFG
# 2     Islamic Republic of Afghanistan      AFG
# 3     Islamic Republic of Afghanistan      AFG
# 4     Islamic Republic of Afghanistan      AFG
# ...                               ...      ...
# 1279             Republic of Zimbabwe      ZWE
# 1280             Republic of Zimbabwe      ZWE
# 1281             Republic of Zimbabwe      ZWE
# 1282             Republic of Zimbabwe      ZWE
# 1283             Republic of Zimbabwe      ZWE
#
#                                                geometry  \
# 0     POLYGON ((68.51923 33.41982, 68.51812 33.41982...
# 1     POLYGON ((61.88133 32.30833, 61.88319 32.31950...
# 2     POLYGON ((66.20807 36.96791, 66.20920 36.96242...
# 3     POLYGON ((68.98100 34.44757, 68.98245 34.44858...
# 4     POLYGON ((71.02767 37.96882, 71.02387 37.96831...
# ...                                                 ...
# 1279  POLYGON ((30.76508 -18.50712, 30.76493 -18.504...
# 1280  POLYGON ((30.76508 -18.50712, 30.76493 -18.504...
# 1281  POLYGON ((31.40310 -20.00350, 31.39930 -20.009...
# 1282  POLYGON ((31.40310 -20.00350, 31.39930 -20.009...
# 1283  POLYGON ((30.61135 -17.55053, 30.61137 -17.553...
#
#                 ADM2_NAME_join             name_join_df2
# 0               Ghazni  Ghazni            Ghazni  Ghazni
# 1                 Farah  Farah              Farah  Farah
# 2               Jawzjan  Aqcha            Jawzjan  Aqcha
# 3                 Kabul  Kabul              Kabul  Kabul
# 4           Badakhshan  Darwaz        Badakhshan  Darwaz
# ...                        ...                       ...
# 1279    Mashonaland East  Seke    Mashonaland East  Seke
# 1280    Mashonaland East  Seke    Mashonaland East  Seke
# 1281        Masvingo  Masvingo        Masvingo  Masvingo
# 1282        Masvingo  Masvingo        Masvingo  Masvingo
# 1283  Mashonaland West  Zvimba  Mashonaland West  Zvimba
#
# [1284 rows x 25 columns]

# %%
events_admin2_locations_only_valid = pd.concat([events_admin2_locations_only_valid1, events_admin2_locations_only_valid])

# %%
events_admin2_locations_only_valid
# Out:
#              DisNo.     ADM1_NAME_df1 iso3_df1     name_join_df1  df_left_id  \
# 0     2012-0361-AFG    Ab Band Ghazni      AFG    Ab Band Ghazni        4304
# 1     2018-0398-AFG   Anar Dara Farah      AFG   Anar Dara Farah        4952
# 2     1991-0130-AFG     Aqcha Jawzjan      AFG     Aqcha Jawzjan         199
# 3     1993-0169-AFG   Chindawal Kabul      AFG   Chindawal Kabul         632
# 4     2002-0703-AFG  Darwaz Badakshan      AFG  Darwaz Badakshan        2543
# ...             ...               ...      ...               ...         ...
# 6453  2023-0719-ZWE             Wedza      ZWE             Wedza       15382
# 6454  2008-0511-ZWE            Zvimba      ZWE            Zvimba       10832
# 6455  1999-0634-ZWE            Zvimba      ZWE            Zvimba        7429
# 6456  2008-0511-ZWE        Zvishavane      ZWE        Zvishavane       10847
# 6457  2023-0719-ZWE             uhera      ZWE             uhera       15366
#
#             match_string  match_score  df_right_id  ADM0_CODE    ADM0_NAME  \
# 0         Ghazni  Ghazni         95.0      16352.0        1.0  Afghanistan
# 1           Farah  Farah         95.0      17376.0        1.0  Afghanistan
# 2         Jawzjan  Aqcha         95.0      17494.0        1.0  Afghanistan
# 3           Kabul  Kabul         95.0      16409.0        1.0  Afghanistan
# 4     Badakhshan  Darwaz         92.0      16318.0        1.0  Afghanistan
# ...                  ...          ...          ...        ...          ...
# 6453              Hwedza         91.0       2526.0      271.0     Zimbabwe
# 6454              Zvimba        100.0       2515.0      271.0     Zimbabwe
# 6455              Zvimba        100.0       2515.0      271.0     Zimbabwe
# 6456          Zvishavane        100.0      10433.0      271.0     Zimbabwe
# 6457              Buhera         91.0      10413.0      271.0     Zimbabwe
#
#       ...  EXP2_YEAR        STATUS  STR2_YEAR Shape_Area Shape_Leng  \
# 0     ...     3000.0  Member State     1000.0   0.034933   0.988983
# 1     ...     3000.0  Member State     1000.0   0.326498   3.870752
# 2     ...     3000.0  Member State     2004.0   0.015729   0.639598
# 3     ...     3000.0  Member State     1000.0   0.034377   1.168943
# 4     ...     3000.0  Member State     2004.0   0.125913   1.879592
# ...   ...        ...           ...        ...        ...        ...
# 6453  ...     3000.0  Member State     1000.0   0.219286   2.792234
# 6454  ...     3000.0  Member State     1000.0   0.518949   5.658163
# 6455  ...     3000.0  Member State     1000.0   0.518949   5.658163
# 6456  ...     3000.0  Member State     1000.0   0.212085   2.791582
# 6457  ...     3000.0  Member State     1000.0   0.461110   4.061706
#
#                         official_name iso3_df2  \
# 0     Islamic Republic of Afghanistan      AFG
# 1     Islamic Republic of Afghanistan      AFG
# 2     Islamic Republic of Afghanistan      AFG
# 3     Islamic Republic of Afghanistan      AFG
# 4     Islamic Republic of Afghanistan      AFG
# ...                               ...      ...
# 6453             Republic of Zimbabwe      ZWE
# 6454             Republic of Zimbabwe      ZWE
# 6455             Republic of Zimbabwe      ZWE
# 6456             Republic of Zimbabwe      ZWE
# 6457             Republic of Zimbabwe      ZWE
#
#                                                geometry      ADM2_NAME_join  \
# 0     POLYGON ((68.51923 33.41982, 68.51812 33.41982...      Ghazni  Ghazni
# 1     POLYGON ((61.88133 32.30833, 61.88319 32.31950...        Farah  Farah
# 2     POLYGON ((66.20807 36.96791, 66.20920 36.96242...      Jawzjan  Aqcha
# 3     POLYGON ((68.98100 34.44757, 68.98245 34.44858...        Kabul  Kabul
# 4     POLYGON ((71.02767 37.96882, 71.02387 37.96831...  Badakhshan  Darwaz
# ...                                                 ...                 ...
# 6453  POLYGON ((31.98308 -19.11863, 31.98306 -19.118...              Hwedza
# 6454  POLYGON ((30.61135 -17.55053, 30.61137 -17.553...              Zvimba
# 6455  POLYGON ((30.61135 -17.55053, 30.61137 -17.553...              Zvimba
# 6456  POLYGON ((30.09545 -20.14557, 30.09764 -20.147...          Zvishavane
# 6457  POLYGON ((31.18835 -19.23481, 31.22039 -19.231...              Buhera
#
#            name_join_df2
# 0         Ghazni  Ghazni
# 1           Farah  Farah
# 2         Jawzjan  Aqcha
# 3           Kabul  Kabul
# 4     Badakhshan  Darwaz
# ...                  ...
# 6453              Hwedza
# 6454              Zvimba
# 6455              Zvimba
# 6456          Zvishavane
# 6457              Buhera
#
# [4500 rows x 25 columns]

# %% [markdown]
# ### shape geodataframe to match GDIS database

# %%
####Shape all geodataframes and set same columns

events_adm1_clean = events_adm1[['DisNo.','iso3','official_name','ADM0_CODE','ADM0_NAME','ADM1_CODE','ADM1_NAME','location', 'geolocation','geometry']]
events_adm1_clean[['ADM2_CODE','ADM2_NAME']] = "None"
events_adm1_clean[['level']] = 1

events_adm2_clean = events_adm2[['DisNo.','iso3','official_name','ADM0_CODE','ADM0_NAME','ADM1_CODE','ADM1_NAME','ADM2_CODE','ADM2_NAME','location', 'geolocation','geometry']]
events_adm2_clean[['level']] = 2

events_adm1_loconly_clean = events_admin1_locations_only_valid.reset_index()[['DisNo.','iso3_df1','official_name','ADM0_CODE','ADM0_NAME','ADM1_CODE','ADM1_NAME','match_string','geometry']]
events_adm1_loconly_clean = events_adm1_loconly_clean.rename(columns={'iso3_df1':'iso3','match_string':'location'})
events_adm1_loconly_clean[['ADM2_CODE','ADM2_NAME','geolocation']] = "None"
events_adm1_loconly_clean[['level']] = 1

events_adm2_loconly_clean = events_admin2_locations_only_valid.reset_index()[['DisNo.','iso3_df1','official_name','ADM0_CODE','ADM0_NAME','ADM1_CODE','ADM1_NAME_df1','ADM2_CODE','ADM2_NAME','match_string','geometry']]
events_adm2_loconly_clean = events_adm2_loconly_clean.rename(columns={'iso3_df1':'iso3','match_string':'location'})
events_adm2_loconly_clean[['geolocation']] = "None"
events_adm2_loconly_clean[['level']] = 2
# Out:
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/pandas/core/frame.py:3645: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[col] = value

# %%
events_adm1_loconly_clean
# Out:
#              DisNo. iso3                    official_name  ADM0_CODE  \
# 0     1999-0465-AFG  AFG  Islamic Republic of Afghanistan        1.0
# 1     2002-0666-AFG  AFG  Islamic Republic of Afghanistan        1.0
# 2     1998-0267-AFG  AFG  Islamic Republic of Afghanistan        1.0
# 3     1997-0097-AFG  AFG  Islamic Republic of Afghanistan        1.0
# 4     1993-0169-AFG  AFG  Islamic Republic of Afghanistan        1.0
# ...             ...  ...                              ...        ...
# 6940  2005-0726-ZWE  ZWE             Republic of Zimbabwe      271.0
# 6941  2022-0569-ZWE  ZWE             Republic of Zimbabwe      271.0
# 6942  2011-0276-ZWE  ZWE             Republic of Zimbabwe      271.0
# 6943  2007-0632-ZWE  ZWE             Republic of Zimbabwe      271.0
# 6944  2005-0726-ZWE  ZWE             Republic of Zimbabwe      271.0
#
#         ADM0_NAME  ADM1_CODE           ADM1_NAME            location  \
# 0     Afghanistan      272.0          Badakhshan          Badakhshan
# 1     Afghanistan      272.0          Badakhshan          Badakhshan
# 2     Afghanistan      272.0          Badakhshan          Badakhshan
# 3     Afghanistan      272.0          Badakhshan          Badakhshan
# 4     Afghanistan      272.0          Badakhshan          Badakhshan
# ...           ...        ...                 ...                 ...
# 6940     Zimbabwe     3444.0            Midlands            Midlands
# 6941     Zimbabwe     3444.0            Midlands            Midlands
# 6942     Zimbabwe    69549.0  Matabeleland North  Matabeleland North
# 6943     Zimbabwe     3443.0  Matabeleland South  Matabeleland South
# 6944     Zimbabwe     3440.0    Mashonaland West    Mashonaland West
#
#                                                geometry ADM2_CODE ADM2_NAME  \
# 0     POLYGON ((69.98554 36.78234, 69.98748 36.78352...      None      None
# 1     POLYGON ((69.98554 36.78234, 69.98748 36.78352...      None      None
# 2     POLYGON ((69.98554 36.78234, 69.98748 36.78352...      None      None
# 3     POLYGON ((69.98554 36.78234, 69.98748 36.78352...      None      None
# 4     POLYGON ((69.98554 36.78234, 69.98748 36.78352...      None      None
# ...                                                 ...       ...       ...
# 6940  POLYGON ((27.99733 -18.23833, 27.99745 -18.238...      None      None
# 6941  POLYGON ((27.99733 -18.23833, 27.99745 -18.238...      None      None
# 6942  POLYGON ((25.23703 -17.88990, 25.23757 -17.877...      None      None
# 6943  POLYGON ((26.69159 -19.89356, 26.69162 -19.893...      None      None
# 6944  POLYGON ((28.01492 -16.87896, 28.01525 -16.878...      None      None
#
#      geolocation  level
# 0           None      1
# 1           None      1
# 2           None      1
# 3           None      1
# 4           None      1
# ...          ...    ...
# 6940        None      1
# 6941        None      1
# 6942        None      1
# 6943        None      1
# 6944        None      1
#
# [6945 rows x 13 columns]

# %%
events_adm2_loconly_clean
# Out:
#              DisNo. iso3                    official_name  ADM0_CODE  \
# 0     2012-0361-AFG  AFG  Islamic Republic of Afghanistan        1.0
# 1     2018-0398-AFG  AFG  Islamic Republic of Afghanistan        1.0
# 2     1991-0130-AFG  AFG  Islamic Republic of Afghanistan        1.0
# 3     1993-0169-AFG  AFG  Islamic Republic of Afghanistan        1.0
# 4     2002-0703-AFG  AFG  Islamic Republic of Afghanistan        1.0
# ...             ...  ...                              ...        ...
# 4495  2023-0719-ZWE  ZWE             Republic of Zimbabwe      271.0
# 4496  2008-0511-ZWE  ZWE             Republic of Zimbabwe      271.0
# 4497  1999-0634-ZWE  ZWE             Republic of Zimbabwe      271.0
# 4498  2008-0511-ZWE  ZWE             Republic of Zimbabwe      271.0
# 4499  2023-0719-ZWE  ZWE             Republic of Zimbabwe      271.0
#
#         ADM0_NAME  ADM1_CODE     ADM1_NAME_df1  ADM2_CODE   ADM2_NAME  \
# 0     Afghanistan      279.0    Ab Band Ghazni     3525.0      Ghazni
# 1     Afghanistan      277.0   Anar Dara Farah     3499.0       Farah
# 2     Afghanistan      283.0     Aqcha Jawzjan    99966.0       Aqcha
# 3     Afghanistan      284.0   Chindawal Kabul     3585.0       Kabul
# 4     Afghanistan      272.0  Darwaz Badakshan   100004.0      Darwaz
# ...           ...        ...               ...        ...         ...
# 4495     Zimbabwe    69550.0             Wedza    33068.0      Hwedza
# 4496     Zimbabwe     3440.0            Zvimba    33080.0      Zvimba
# 4497     Zimbabwe     3440.0            Zvimba    33080.0      Zvimba
# 4498     Zimbabwe     3444.0        Zvishavane    33107.0  Zvishavane
# 4499     Zimbabwe     3437.0             uhera    33053.0      Buhera
#
#                 location                                           geometry  \
# 0         Ghazni  Ghazni  POLYGON ((68.51923 33.41982, 68.51812 33.41982...
# 1           Farah  Farah  POLYGON ((61.88133 32.30833, 61.88319 32.31950...
# 2         Jawzjan  Aqcha  POLYGON ((66.20807 36.96791, 66.20920 36.96242...
# 3           Kabul  Kabul  POLYGON ((68.98100 34.44757, 68.98245 34.44858...
# 4     Badakhshan  Darwaz  POLYGON ((71.02767 37.96882, 71.02387 37.96831...
# ...                  ...                                                ...
# 4495              Hwedza  POLYGON ((31.98308 -19.11863, 31.98306 -19.118...
# 4496              Zvimba  POLYGON ((30.61135 -17.55053, 30.61137 -17.553...
# 4497              Zvimba  POLYGON ((30.61135 -17.55053, 30.61137 -17.553...
# 4498          Zvishavane  POLYGON ((30.09545 -20.14557, 30.09764 -20.147...
# 4499              Buhera  POLYGON ((31.18835 -19.23481, 31.22039 -19.231...
#
#      geolocation  level
# 0           None      2
# 1           None      2
# 2           None      2
# 3           None      2
# 4           None      2
# ...          ...    ...
# 4495        None      2
# 4496        None      2
# 4497        None      2
# 4498        None      2
# 4499        None      2
#
# [4500 rows x 13 columns]

# %%
new_df
# Out:
#               DisNo. Individual_Location Location_Before Bracketed    Appended
# 0      1990-0001-LKA              Ampara          Ampara      None      Ampara
# 1      1990-0001-LKA             Badulla         Badulla      None     Badulla
# 2      1990-0001-LKA               Kandy           Kandy      None       Kandy
# 3      1990-0001-LKA          Kurunegala      Kurunegala      None  Kurunegala
# 4      1990-0001-LKA              Matale          Matale      None      Matale
# ...              ...                 ...             ...       ...         ...
# 21524  2023-9873-FSM              Kosrae          Kosrae      None      Kosrae
# 21525  2023-9873-FSM             Pohnpei         Pohnpei      None     Pohnpei
# 21526  2023-9873-FSM                 Yap             Yap      None         Yap
# 21527  2023-9879-BWA            Southern        Southern      None    Southern
# 21528  2023-9879-BWA          North East      North East      None  North East
#
# [21529 rows x 5 columns]

# %%
freq_emdata = new_df['DisNo.'].value_counts()

# Count the frequency of each DisNo. in locations_only_events_admin1
freq_admin1 = events_adm1_loconly_clean['DisNo.'].value_counts()

# Count the frequency of each DisNo. in vents_adm2_loconly_clean
freq_admin2 = events_adm2_loconly_clean['DisNo.'].value_counts()

# Combine the frequencies into a single DataFrame
combined_freq = pd.DataFrame({
    'Emdata': freq_emdata, 
    'Admin1': freq_admin1, 
    'Admin2': freq_admin2
}).fillna(0)

# Calculate the ratio for each DisNo.
combined_freq['Ratio_Admin1'] = combined_freq['Admin1'] / combined_freq['Emdata']
combined_freq['Ratio_Admin2'] = combined_freq['Admin2'] / combined_freq['Emdata']
combined_freq['total_ratio'] =  combined_freq['Ratio_Admin1'] + combined_freq['Ratio_Admin2'] 
# Display the result
print(combined_freq)
# Out:
#                Emdata  Admin1  Admin2  Ratio_Admin1  Ratio_Admin2  total_ratio
# 1990-0001-LKA      10     0.0     9.0          0.00           0.9         0.90
# 1990-0002-TUN       8     6.0     0.0          0.75           0.0         0.75
# 1990-0003-WSM       2     0.0     0.0          0.00           0.0         0.00
# 1990-0004-FRA       2     0.0     1.0          0.00           0.5         0.50
# 1990-0005-IDN      11     0.0     0.0          0.00           0.0         0.00
# ...               ...     ...     ...           ...           ...          ...
# 2023-9651-BRA       1     1.0     0.0          1.00           0.0         1.00
# 2023-9706-BOL       5     5.0     0.0          1.00           0.0         1.00
# 2023-9868-USA      10    10.0     0.0          1.00           0.0         1.00
# 2023-9873-FSM       4     0.0     0.0          0.00           0.0         0.00
# 2023-9879-BWA       2     2.0     0.0          1.00           0.0         1.00
#
# [10887 rows x 6 columns]

# %%
disno_to_remove = combined_freq[combined_freq['total_ratio'] < 0.6].index

# Filter out these DisNo. from events_adm1_loconly_clean and events_adm2_loconly_clean
events_adm1_loconly_clean = events_adm1_loconly_clean[~events_adm1_loconly_clean['DisNo.'].isin(disno_to_remove)].reset_index(drop=True)
events_adm2_loconly_clean = events_adm2_loconly_clean[~events_adm2_loconly_clean['DisNo.'].isin(disno_to_remove)].reset_index(drop=True)

# Display the result
print("Filtered events_adm1_loconly_clean:")
print(events_adm1_loconly_clean)
print("\nFiltered events_adm2_loconly_clean:")
print(events_adm2_loconly_clean)
# Out:
# Filtered events_adm1_loconly_clean:
#              DisNo. iso3                    official_name  ADM0_CODE  \
# 0     1999-0465-AFG  AFG  Islamic Republic of Afghanistan        1.0
# 1     2002-0666-AFG  AFG  Islamic Republic of Afghanistan        1.0
# 2     1998-0267-AFG  AFG  Islamic Republic of Afghanistan        1.0
# 3     1997-0097-AFG  AFG  Islamic Republic of Afghanistan        1.0
# 4     1993-0169-AFG  AFG  Islamic Republic of Afghanistan        1.0
# ...             ...  ...                              ...        ...
# 6408  2023-0719-ZWE  ZWE             Republic of Zimbabwe      271.0
# 6409  2005-0726-ZWE  ZWE             Republic of Zimbabwe      271.0
# 6410  2011-0276-ZWE  ZWE             Republic of Zimbabwe      271.0
# 6411  2007-0632-ZWE  ZWE             Republic of Zimbabwe      271.0
# 6412  2005-0726-ZWE  ZWE             Republic of Zimbabwe      271.0
#
#         ADM0_NAME  ADM1_CODE           ADM1_NAME            location  \
# 0     Afghanistan      272.0          Badakhshan          Badakhshan
# 1     Afghanistan      272.0          Badakhshan          Badakhshan
# 2     Afghanistan      272.0          Badakhshan          Badakhshan
# 3     Afghanistan      272.0          Badakhshan          Badakhshan
# 4     Afghanistan      272.0          Badakhshan          Badakhshan
# ...           ...        ...                 ...                 ...
# 6408     Zimbabwe     3443.0  Matabeleland South  Matabeleland South
# 6409     Zimbabwe     3444.0            Midlands            Midlands
# 6410     Zimbabwe    69549.0  Matabeleland North  Matabeleland North
# 6411     Zimbabwe     3443.0  Matabeleland South  Matabeleland South
# 6412     Zimbabwe     3440.0    Mashonaland West    Mashonaland West
#
#                                                geometry ADM2_CODE ADM2_NAME  \
# 0     POLYGON ((69.98554 36.78234, 69.98748 36.78352...      None      None
# 1     POLYGON ((69.98554 36.78234, 69.98748 36.78352...      None      None
# 2     POLYGON ((69.98554 36.78234, 69.98748 36.78352...      None      None
# 3     POLYGON ((69.98554 36.78234, 69.98748 36.78352...      None      None
# 4     POLYGON ((69.98554 36.78234, 69.98748 36.78352...      None      None
# ...                                                 ...       ...       ...
# 6408  POLYGON ((26.69159 -19.89356, 26.69162 -19.893...      None      None
# 6409  POLYGON ((27.99733 -18.23833, 27.99745 -18.238...      None      None
# 6410  POLYGON ((25.23703 -17.88990, 25.23757 -17.877...      None      None
# 6411  POLYGON ((26.69159 -19.89356, 26.69162 -19.893...      None      None
# 6412  POLYGON ((28.01492 -16.87896, 28.01525 -16.878...      None      None
#
#      geolocation  level
# 0           None      1
# 1           None      1
# 2           None      1
# 3           None      1
# 4           None      1
# ...          ...    ...
# 6408        None      1
# 6409        None      1
# 6410        None      1
# 6411        None      1
# 6412        None      1
#
# [6413 rows x 13 columns]
#
# Filtered events_adm2_loconly_clean:
#              DisNo. iso3                    official_name  ADM0_CODE  \
# 0     2012-0361-AFG  AFG  Islamic Republic of Afghanistan        1.0
# 1     2018-0398-AFG  AFG  Islamic Republic of Afghanistan        1.0
# 2     1993-0169-AFG  AFG  Islamic Republic of Afghanistan        1.0
# 3     2015-0559-AFG  AFG  Islamic Republic of Afghanistan        1.0
# 4     2011-0167-AFG  AFG  Islamic Republic of Afghanistan        1.0
# ...             ...  ...                              ...        ...
# 3774  2023-0719-ZWE  ZWE             Republic of Zimbabwe      271.0
# 3775  2008-0511-ZWE  ZWE             Republic of Zimbabwe      271.0
# 3776  1999-0634-ZWE  ZWE             Republic of Zimbabwe      271.0
# 3777  2008-0511-ZWE  ZWE             Republic of Zimbabwe      271.0
# 3778  2023-0719-ZWE  ZWE             Republic of Zimbabwe      271.0
#
#         ADM0_NAME  ADM1_CODE           ADM1_NAME_df1  ADM2_CODE  \
# 0     Afghanistan      279.0          Ab Band Ghazni     3525.0
# 1     Afghanistan      277.0         Anar Dara Farah     3499.0
# 2     Afghanistan      284.0         Chindawal Kabul     3585.0
# 3     Afghanistan      298.0  Hazrat Sultan Samangan   100022.0
# 4     Afghanistan      275.0           Hesarak Balkh     3477.0
# ...           ...        ...                     ...        ...
# 3774     Zimbabwe    69550.0                   Wedza    33068.0
# 3775     Zimbabwe     3440.0                  Zvimba    33080.0
# 3776     Zimbabwe     3440.0                  Zvimba    33080.0
# 3777     Zimbabwe     3444.0              Zvishavane    33107.0
# 3778     Zimbabwe     3437.0                   uhera    33053.0
#
#              ADM2_NAME                    location  \
# 0               Ghazni              Ghazni  Ghazni
# 1                Farah                Farah  Farah
# 2                Kabul                Kabul  Kabul
# 3     Hazrat-e- Sultan  Samangan  Hazrat-e- Sultan
# 4                Balkh                Balkh  Balkh
# ...                ...                         ...
# 3774            Hwedza                      Hwedza
# 3775            Zvimba                      Zvimba
# 3776            Zvimba                      Zvimba
# 3777        Zvishavane                  Zvishavane
# 3778            Buhera                      Buhera
#
#                                                geometry geolocation  level
# 0     POLYGON ((68.51923 33.41982, 68.51812 33.41982...        None      2
# 1     POLYGON ((61.88133 32.30833, 61.88319 32.31950...        None      2
# 2     POLYGON ((68.98100 34.44757, 68.98245 34.44858...        None      2
# 3     POLYGON ((67.41337 36.18583, 67.40281 36.19645...        None      2
# 4     POLYGON ((66.76101 36.90265, 66.76492 36.90138...        None      2
# ...                                                 ...         ...    ...
# 3774  POLYGON ((31.98308 -19.11863, 31.98306 -19.118...        None      2
# 3775  POLYGON ((30.61135 -17.55053, 30.61137 -17.553...        None      2
# 3776  POLYGON ((30.61135 -17.55053, 30.61137 -17.553...        None      2
# 3777  POLYGON ((30.09545 -20.14557, 30.09764 -20.147...        None      2
# 3778  POLYGON ((31.18835 -19.23481, 31.22039 -19.231...        None      2
#
# [3779 rows x 13 columns]

# %%
geolocated_events = pd.concat([events_adm1_clean, events_adm2_clean,events_adm1_loconly_clean,events_adm2_loconly_clean])
geolocated_events['disaster_number_country'] = geolocated_events['DisNo.']
geolocated_events = geolocated_events.set_index('DisNo.').sort_index()

# %%
geolocated_events[['ADM0_CODE','ADM1_CODE']] = geolocated_events[['ADM0_CODE','ADM1_CODE']].astype(int)

# %%
gaul1_subset = gaul1[['ADM1_CODE','ADM1_NAME']]

# %%
def find_location(x):
    return gaul1_subset[gaul1_subset.ADM1_CODE == x]['ADM1_NAME'].values[0]

# %%
ADM1_NAMES_data = geolocated_events['ADM1_CODE'].apply(lambda x: find_location(x))

# %%
ADM1_NAMES_data
# Out:
# DisNo.
# 1990-0001-LKA    North Central
# 1990-0001-LKA          Central
# 1990-0001-LKA          Central
# 1990-0001-LKA    North Western
# 1990-0001-LKA          Central
#                      ...
# 2023-9868-USA            Texas
# 2023-9868-USA       Washington
# 2023-9868-USA         Missouri
# 2023-9879-BWA         Southern
# 2023-9879-BWA       North East
# Name: ADM1_CODE, Length: 53520, dtype: object

# %%
geolocated_events['ADM1_NAME'] = ADM1_NAMES_data

# %%
geolocated_events = geolocated_events.drop(columns='ADM1_NAME_df1')

# %%
len(np.unique(geolocated_events.index))
# Out:
# 13557

# %%
print(geolocated_events)
# Out:
#               iso3                               official_name  ADM0_CODE  \
# DisNo.
# 1990-0001-LKA  LKA  Democratic Socialist Republic of Sri Lanka        231
# 1990-0001-LKA  LKA  Democratic Socialist Republic of Sri Lanka        231
# 1990-0001-LKA  LKA  Democratic Socialist Republic of Sri Lanka        231
# 1990-0001-LKA  LKA  Democratic Socialist Republic of Sri Lanka        231
# 1990-0001-LKA  LKA  Democratic Socialist Republic of Sri Lanka        231
# ...            ...                                         ...        ...
# 2023-9868-USA  USA                    United States of America        259
# 2023-9868-USA  USA                    United States of America        259
# 2023-9868-USA  USA                    United States of America        259
# 2023-9879-BWA  BWA                        Republic of Botswana         35
# 2023-9879-BWA  BWA                        Republic of Botswana         35
#
#                               ADM0_NAME  ADM1_CODE      ADM1_NAME  \
# DisNo.
# 1990-0001-LKA                 Sri Lanka       2738  North Central
# 1990-0001-LKA                 Sri Lanka       2736        Central
# 1990-0001-LKA                 Sri Lanka       2736        Central
# 1990-0001-LKA                 Sri Lanka       2739  North Western
# 1990-0001-LKA                 Sri Lanka       2736        Central
# ...                                 ...        ...            ...
# 2023-9868-USA  United States of America       3257          Texas
# 2023-9868-USA  United States of America       3261     Washington
# 2023-9868-USA  United States of America       3239       Missouri
# 2023-9879-BWA                  Botswana        663       Southern
# 2023-9879-BWA                  Botswana        661     North East
#
#                    location geolocation  \
# DisNo.
# 1990-0001-LKA   Polonnaruwa        None
# 1990-0001-LKA  Nuwara Eliya        None
# 1990-0001-LKA         Kandy        None
# 1990-0001-LKA    Kurunegala        None
# 1990-0001-LKA        Matale        None
# ...                     ...         ...
# 2023-9868-USA         Texas        None
# 2023-9868-USA    Washington        None
# 2023-9868-USA      Missouri        None
# 2023-9879-BWA      Southern        None
# 2023-9879-BWA    North East        None
#
#                                                         geometry ADM2_CODE  \
# DisNo.
# 1990-0001-LKA  POLYGON ((80.98834 7.72038, 80.98802 7.72037, ...   25836.0
# 1990-0001-LKA  POLYGON ((80.46715 7.02203, 80.46714 7.02214, ...   41749.0
# 1990-0001-LKA  POLYGON ((80.56631 7.45748, 80.56660 7.45725, ...   41748.0
# 1990-0001-LKA  POLYGON ((80.49657 7.80912, 80.49659 7.80868, ...   25837.0
# 1990-0001-LKA  POLYGON ((80.49657 7.80912, 80.49657 7.80952, ...   25830.0
# ...                                                          ...       ...
# 2023-9868-USA  MULTIPOLYGON (((-97.51395 26.83975, -97.51390 ...      None
# 2023-9868-USA  MULTIPOLYGON (((-124.72645 47.99174, -124.7265...      None
# 2023-9868-USA  POLYGON ((-95.77470 40.57357, -95.77355 40.578...      None
# 2023-9879-BWA  POLYGON ((23.04889 -24.83722, 23.04917 -24.823...      None
# 2023-9879-BWA  POLYGON ((27.20695 -20.81806, 27.20889 -20.813...      None
#
#                   ADM2_NAME  level disaster_number_country
# DisNo.
# 1990-0001-LKA   Polonnaruwa      2           1990-0001-LKA
# 1990-0001-LKA  Nuwara Eliya      2           1990-0001-LKA
# 1990-0001-LKA         Kandy      2           1990-0001-LKA
# 1990-0001-LKA    Kurunegala      2           1990-0001-LKA
# 1990-0001-LKA        Matale      2           1990-0001-LKA
# ...                     ...    ...                     ...
# 2023-9868-USA          None      1           2023-9868-USA
# 2023-9868-USA          None      1           2023-9868-USA
# 2023-9868-USA          None      1           2023-9868-USA
# 2023-9879-BWA          None      1           2023-9879-BWA
# 2023-9879-BWA          None      1           2023-9879-BWA
#
# [53520 rows x 13 columns]

# %%
geolocated_events.columns
# Out:
# Index(['iso3', 'official_name', 'ADM0_CODE', 'ADM0_NAME', 'ADM1_CODE',
#        'ADM1_NAME', 'location', 'geolocation', 'geometry', 'ADM2_CODE',
#        'ADM2_NAME', 'level', 'disaster_number_country'],
#       dtype='object')

# %%
geolocated_events = gpd.GeoDataFrame(geolocated_events)
geolocated_events.to_file('geolocated_events_clean_1990-2023_final.gpkg', driver="GPKG")

# %%
# !ls -lh
# Out:
# total 12G
# -rw-rw-r-- 1 dchinthaparthy dchinthaparthy  690K May 23 15:41 02_2023.ipynb
# -rw-rw-r-- 1 dchinthaparthy dchinthaparthy  573K May 18 16:12 02_geolocate_events-2.ipynb
# -rw-rw-r-- 1 dchinthaparthy dchinthaparthy  593K Apr 24 23:12 02_geolocate_events-Copy1.ipynb
# -rw-rw-r-- 1 dchinthaparthy dchinthaparthy  719K Jul 11 12:28 02_geolocate_events-mod.ipynb
# -rw-rw-r-- 1 dchinthaparthy dchinthaparthy  736K May 29 00:30 02_geolocate_events-no-locations.ipynb
# -rw-rw-r-- 1 dchinthaparthy dchinthaparthy  678K May 19 15:05 02_geolocate_events.ipynb
# -rw-rw-r-- 1 dchinthaparthy dchinthaparthy  874K Jul 11 13:06 02_geolocate_events_full.ipynb
# -rw-rw-r-- 1 dchinthaparthy dchinthaparthy  148K May 22 16:31 2023.xlsx
# -rw-rw-r-- 1 dchinthaparthy dchinthaparthy   442 Feb 28 17:14 README.md
# -rw-rw-r-- 1 dchinthaparthy dchinthaparthy   983 Feb 29 15:28 Untitled.ipynb
# -rw-rw-r-- 1 dchinthaparthy dchinthaparthy  2.0K Apr 24 22:54 Untitled1.ipynb
# -rw-rw-r-- 1 dchinthaparthy dchinthaparthy  298K May 29 20:51 Untitled2.ipynb
# -rw-rw-r-- 1 dchinthaparthy dchinthaparthy  309K May 29 21:05 Untitled3.ipynb
# -rw-rw-r-- 1 dchinthaparthy dchinthaparthy  204K Jun  2 20:20 Untitled4.ipynb
# -rw-rw-r-- 1 dchinthaparthy dchinthaparthy  3.9K May  5 16:35 agg_data.csv
# -rw-rw-r-- 1 dchinthaparthy dchinthaparthy   930 Feb 28 17:14 aggreg_country_script.py
# -rw-rw-r-- 1 dchinthaparthy dchinthaparthy   21K May  5 20:50 aggregation_functions.py
# -rw-rw-r-- 1 dchinthaparthy dchinthaparthy  866K May  4 16:37 code_analysis.ipynb
# -rw-rw-r-- 1 dchinthaparthy dchinthaparthy  3.0K May  4 16:43 country_counts.csv
# -rw-rw-r-- 1 dchinthaparthy dchinthaparthy  365K Mar 12 14:38 data.ipynb
# -rw-rw-r-- 1 dchinthaparthy dchinthaparthy  796K Apr 24 22:13 data_ref.xlsx
# -rw-rw-r-- 1 dchinthaparthy dchinthaparthy  7.8K Apr 28 19:46 doc_String.ipynb
# -rw-rw-r-- 1 dchinthaparthy dchinthaparthy  3.5M Apr 24 21:51 emdat_public_1960_2022.xlsx
# -rw-rw-r-- 1 dchinthaparthy dchinthaparthy  8.5K Mar 12 15:43 event_shape.csv
# -rw-rw-r-- 1 dchinthaparthy dchinthaparthy  532K Jun  2 20:46 final_0.ipynb
# -rw-rw-r-- 1 dchinthaparthy dchinthaparthy  452K Jun  3 17:27 final_8.ipynb
# -rw-rw-r-- 1 dchinthaparthy dchinthaparthy   33K Jun  3 18:24 final_freq.csv
# -rw-rw-r-- 1 dchinthaparthy dchinthaparthy  207K May  5 20:47 final_test.ipynb
# -rw-rw-r-- 1 dchinthaparthy dchinthaparthy   24K Jun  2 22:41 finalemo.csv
# -rw-rw-r-- 1 dchinthaparthy dchinthaparthy  274K Jun  2 21:27 finaltesting.csv
# -rw-r--r-- 1 dchinthaparthy dchinthaparthy  1.1G Apr 25 00:13 geolocated_events_clean.gpkg
# -rw-r--r-- 1 dchinthaparthy dchinthaparthy  9.5G Jul 11 13:04 geolocated_events_clean_1990-2023_final.gpkg
# -rw-r--r-- 1 dchinthaparthy dchinthaparthy  1.2G May 19 19:15 geolocated_events_clean_2021-2023.gpkg
# -rw-r--r-- 1 dchinthaparthy dchinthaparthy  1.1G Jun  9 20:35 geolocated_events_clean_2021-2023_final.gpkg
# -rw-rw-r-- 1 dchinthaparthy dchinthaparthy  402K May 29 23:17 hpiwd.ipynb
# -rw-rw-r-- 1 dchinthaparthy dchinthaparthy  461K Apr 24 21:30 public_emdat_2021_2023.xlsx
# -rw-rw-r-- 1 dchinthaparthy dchinthaparthy   20K May  4 16:11 re_doc_Strings.ipynb
# -rw-rw-r-- 1 dchinthaparthy dchinthaparthy   14K Feb 28 12:34 requirements.txt
# drwxrwxr-x 4 dchinthaparthy dchinthaparthy     7 Mar 20 11:08 src
# -rw-rw-r-- 1 dchinthaparthy dchinthaparthy   30K Mar 21 14:08 test.ipynb
# -rw-rw-r-- 1 dchinthaparthy dchinthaparthy 1006K Mar  5 16:44 test_aggregation.ipynb
# -rw-rw-r-- 1 dchinthaparthy dchinthaparthy  183K Jun  2 21:35 testing.csv
# -rw-rw-r-- 1 dchinthaparthy dchinthaparthy  198K Jun  2 21:39 testing2.csv

# %%
cp geolocated_events_clean_1990-2023_final.gpkg /net/scratch/XAIDA/share_folder

# %%
data = gpd.read_file('geolocated_events_clean_1990-2023_final.gpkg')

# %%
data
# Out:
#               DisNo. iso3                               official_name  \
# 0      1990-0001-LKA  LKA  Democratic Socialist Republic of Sri Lanka
# 1      1990-0001-LKA  LKA  Democratic Socialist Republic of Sri Lanka
# 2      1990-0001-LKA  LKA  Democratic Socialist Republic of Sri Lanka
# 3      1990-0001-LKA  LKA  Democratic Socialist Republic of Sri Lanka
# 4      1990-0001-LKA  LKA  Democratic Socialist Republic of Sri Lanka
# ...              ...  ...                                         ...
# 53515  2023-9868-USA  USA                    United States of America
# 53516  2023-9868-USA  USA                    United States of America
# 53517  2023-9868-USA  USA                    United States of America
# 53518  2023-9879-BWA  BWA                        Republic of Botswana
# 53519  2023-9879-BWA  BWA                        Republic of Botswana
#
#        ADM0_CODE                 ADM0_NAME  ADM1_CODE      ADM1_NAME  \
# 0            231                 Sri Lanka       2738  North Central
# 1            231                 Sri Lanka       2736        Central
# 2            231                 Sri Lanka       2736        Central
# 3            231                 Sri Lanka       2739  North Western
# 4            231                 Sri Lanka       2736        Central
# ...          ...                       ...        ...            ...
# 53515        259  United States of America       3257          Texas
# 53516        259  United States of America       3261     Washington
# 53517        259  United States of America       3239       Missouri
# 53518         35                  Botswana        663       Southern
# 53519         35                  Botswana        661     North East
#
#            location geolocation ADM2_CODE     ADM2_NAME  level  \
# 0       Polonnaruwa        None     25836   Polonnaruwa      2
# 1      Nuwara Eliya        None     41749  Nuwara Eliya      2
# 2             Kandy        None     41748         Kandy      2
# 3        Kurunegala        None     25837    Kurunegala      2
# 4            Matale        None     25830        Matale      2
# ...             ...         ...       ...           ...    ...
# 53515         Texas        None      None          None      1
# 53516    Washington        None      None          None      1
# 53517      Missouri        None      None          None      1
# 53518      Southern        None      None          None      1
# 53519    North East        None      None          None      1
#
#       disaster_number_country  \
# 0               1990-0001-LKA
# 1               1990-0001-LKA
# 2               1990-0001-LKA
# 3               1990-0001-LKA
# 4               1990-0001-LKA
# ...                       ...
# 53515           2023-9868-USA
# 53516           2023-9868-USA
# 53517           2023-9868-USA
# 53518           2023-9879-BWA
# 53519           2023-9879-BWA
#
#                                                 geometry
# 0      POLYGON ((80.98834 7.72038, 80.98802 7.72037, ...
# 1      POLYGON ((80.46715 7.02203, 80.46714 7.02214, ...
# 2      POLYGON ((80.56631 7.45748, 80.56660 7.45725, ...
# 3      POLYGON ((80.49657 7.80912, 80.49659 7.80868, ...
# 4      POLYGON ((80.49657 7.80912, 80.49657 7.80952, ...
# ...                                                  ...
# 53515  MULTIPOLYGON (((-97.51395 26.83975, -97.51390 ...
# 53516  MULTIPOLYGON (((-124.72645 47.99174, -124.7265...
# 53517  POLYGON ((-95.77470 40.57357, -95.77355 40.578...
# 53518  POLYGON ((23.04889 -24.83722, 23.04917 -24.823...
# 53519  POLYGON ((27.20695 -20.81806, 27.20889 -20.813...
#
# [53520 rows x 14 columns]
