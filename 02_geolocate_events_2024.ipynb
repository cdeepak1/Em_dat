# %%
import xarray as xr
import numpy as np
import geopandas as gpd
import pandas as pd
import re

# %% [markdown]
# This notebook (script) is to geolocate the EM-DAT events from 2021 to 2023 based on the cleaned GAUL geometries from script 1 (clean_gaul.ipynb(py)).
#
# The first part is locating the events that have the geocodes to the GAUL geometries.
#
# The second part is locating the events  based on the names of the geometries. For this, the names of the locations and geometries will be matched by a fuzzy algorithm, and then only the geometries that pass a certain threshold and which names exist fully in the location column of the event are kept.
# In the case where geometries with similar names at admin levels 1 and 2 are found, the geometries of level 1 are favored and kept over the level 2.
#
# At the end, all geodataframes are concatenated together and columns are created to enable their integration with the GDIS database.

# %%
emdat = pd.read_excel('/net/projects/xaida/raw_data/emdat_data/public_emdat_2021_2023.xlsx')

# %%
import pandas as pd

# Read the Excel file into emdat DataFrame and set 'DisNo.' as index
emdat = pd.read_excel('/net/projects/xaida/raw_data/emdat_data/public_emdat_2021_2023.xlsx')
emdat = emdat.set_index('DisNo.')

# Select only 'Location' and 'Admin Units' columns and drop rows where both are NaN
emdat = emdat[['Location', 'Admin Units']].dropna(how='all')

# Sort 'Location' column alphabetically
emdat['Location'] = emdat['Location'].apply(lambda x: ', '.join(sorted(str(x).split(', '))))

# Process 'Admin Units' column to get Admin1 Code, Admin2 Code, and Geo Locations
def process_admin_units(units):
    if pd.isna(units):
        return pd.Series([None, None, None])
    
    admin1_units = []
    admin2_units = []

    # Extract Admin1 and Admin2 information
    for unit in eval(units):
        if 'adm1_code' in unit:
            admin1_units.append((unit['adm1_code'], unit['adm1_name']))
        if 'adm2_code' in unit:
            admin2_units.append((unit['adm2_code'], unit['adm2_name']))
    
    # Sort admin units alphabetically
    admin1_units.sort(key=lambda x: x[1])  # Sort by adm1_name
    admin2_units.sort(key=lambda x: x[1])  # Sort by adm2_name

    admin1_codes = [str(unit[0]) for unit in admin1_units]
    admin1_names_list = [unit[1] for unit in admin1_units]
    
    admin2_codes = [str(unit[0]) for unit in admin2_units]
    admin2_names_list = [unit[1] for unit in admin2_units]
    
    # Construct Geo Locations string
    geo_location_str = ', '.join(admin1_names_list) + (' (Adm1).' if admin1_names_list else '')
    if admin2_names_list:
        geo_location_str += ' ' + ', '.join(admin2_names_list) + ' (Adm2).'
    
    return pd.Series([';'.join(admin1_codes), ';'.join(admin2_codes), geo_location_str])

# Apply the process_admin_units function to 'Admin Units' column and assign the result to Emdata
Emdata = emdat['Admin Units'].apply(process_admin_units)
Emdata.columns = ['Admin1 Code', 'Admin2 Code', 'Geo Locations']

# Merge 'Location' column from emdat into Emdata DataFrame
Emdata['Location'] = emdat['Location']

# Print the DataFrame
print(Emdata)

# Access a specific DisNo.
print(Emdata.loc['2021-0003-IDN'])
# Out:
#                            Admin1 Code Admin2 Code  \
# DisNo.
# 2020-0051-IRL                1592;1603
# 2020-9609-SOM                     None        None
# 2021-0001-BOL  40443;40445;40446;40450
# 2021-0001-PRY                                23869
# 2021-0002-ARG                      446
# ...                                ...         ...
# 2023-9589-URY                     None        None
# 2023-9651-BRA                     None        None
# 2023-9706-BOL                     None        None
# 2023-9868-USA                     None        None
# 2023-9873-FSM                     None        None
#
#                                           Geo Locations  \
# DisNo.
# 2020-0051-IRL                      Laois, Sligo (Adm1).
# 2020-9609-SOM                                      None
# 2021-0001-BOL  Beni, Cochabamba, La Paz, Tarija (Adm1).
# 2021-0001-PRY                        Concepcion (Adm2).
# 2021-0002-ARG                          San Juan (Adm1).
# ...                                                 ...
# 2023-9589-URY                                      None
# 2023-9651-BRA                                      None
# 2023-9706-BOL                                      None
# 2023-9868-USA                                      None
# 2023-9873-FSM                                      None
#
#                                                         Location
# DisNo.
# 2020-0051-IRL  County Laois., Geevagh (County Sligo), Riverst...
# 2020-9609-SOM  Eilafwen (Sanaag), Gedo; Las Anod / Hudun and ...
# 2021-0001-BOL       Beni, Cochabamba, La Paz Departments, Tarija
# 2021-0001-PRY                                    Conception City
# 2021-0002-ARG                                  San Juan Province
# ...                                                          ...
# 2023-9589-URY  Cerro Largo, Florida, Lavalleja, San Jose, Tac...
# 2023-9651-BRA                                     Amazonas state
# 2023-9706-BOL  Chuquisaca, Cochabamba, La Paz, Oruro, Santa Cruz
# 2023-9868-USA  Illinois, Kansas, Louisiana, Missouri, Montana...
# 2023-9873-FSM                        Chuuk, Kosrae, Pohnpei, Yap
#
# [1582 rows x 4 columns]
# Admin1 Code
# Admin2 Code                                      18177;73786;73828
# Geo Locations               Majene, Mamuju, Polewalimamasa (Adm2).
# Location         Majene, Mamuju, Polewali Mandar districts (Wes...
# Name: 2021-0003-IDN, dtype: object

# %%
print(Emdata.loc['2021-0036-MDG'])
# Out:
# Admin1 Code
# Admin2 Code                     154596;154527;154556;154557;154530
# Geo Locations     Antalaha, Maroantsetra, Toamasina I, Toamasin...
# Location         Antalaha, Maroantsetra, Vavatenina and Toamasi...
# Name: 2021-0036-MDG, dtype: object

# %%
print(Emdata.loc['2021-0016-ESP'])
# Out:
# Admin1 Code
# Admin2 Code                      25820;25782;25786
# Geo Locations     Madrid, Málaga, Zaragoza (Adm2).
# Location                  Madrid, Malaga, Zaragoza
# Name: 2021-0016-ESP, dtype: object

# %%
print(Emdata.loc['2023-9167-HND'])
# Out:
# Admin1 Code                                    1420;1421;1433;1438
# Admin2 Code                          17413;17439;17335;17287;17313
# Geo Locations    Atlantida, Choluteca, Ocotepeque, Yoro (Adm1)....
# Location         Catacamas, Choculeta, Flores, Jacaleapa, La Es...
# Name: 2023-9167-HND, dtype: object

# %%
common_nans = emdat[ emdat['Location'].notna() &  emdat['Admin Units'].isna()]

# Print the result
print("Rows with common NaNs in 'Location' and 'Admin Units':")
print(common_nans)
# Out:
# Rows with common NaNs in 'Location' and 'Admin Units':
#                                                         Location Admin Units
# DisNo.
# 2020-9609-SOM  Eilafwen (Sanaag), Gedo; Las Anod / Hudun and ...         NaN
# 2021-0012-BGD                                        Cox's Bazar         NaN
# 2021-0029-IND                     Surat district (Gujarat state)         NaN
# 2021-0030-ECU                                   Bolivar province         NaN
# 2021-0032-IDN                                           Java Sea         NaN
# ...                                                          ...         ...
# 2023-9589-URY  Cerro Largo, Florida, Lavalleja, San Jose, Tac...         NaN
# 2023-9651-BRA                                     Amazonas state         NaN
# 2023-9706-BOL  Chuquisaca, Cochabamba, La Paz, Oruro, Santa Cruz         NaN
# 2023-9868-USA  Illinois, Kansas, Louisiana, Missouri, Montana...         NaN
# 2023-9873-FSM                        Chuuk, Kosrae, Pohnpei, Yap         NaN
#
# [835 rows x 2 columns]

# %%
#get the entires that only have location name indiction (not the geolocation name and code)
Emdata_loconly = Emdata[Emdata['Admin1 Code'].isna() & Emdata['Admin2 Code'].isna()]
#get the geocoded entries
Emdata_geocode = Emdata.drop(Emdata_loconly.index)

# %% [markdown]
# ## 1) Matching events with geolocations (from 2021 onwards)

# %% [markdown]
# ### geometries at Admin 1 level

# %%
####Administrative level 1 geometries
#Extract Adm1 locations
emdat_geocode_adm1 = Emdata_geocode.loc[Emdata_geocode['Geo Locations'].str.contains("(Adm1)")]
emdat_geocode_adm1["Geo Locations"] = emdat_geocode_adm1["Geo Locations"].str.split(" \(Adm1",expand=True)[0]
#Shape Adm1 locations: 1 row = 1 geolocation
emdat_geocode_adm1_stacked = pd.DataFrame(emdat_geocode_adm1["Admin1 Code"].str.split(';', expand=True).stack()).rename(columns={0:'ADM1_CODE'})
emdat_geocode_adm1_stacked['location'] = pd.DataFrame(emdat_geocode_adm1["Location"].str.split(',', expand=True).stack())
emdat_geocode_adm1_stacked['geolocation'] = pd.DataFrame(emdat_geocode_adm1["Geo Locations"].str.split(',', expand=True).stack())
emdat_geocode_adm1_identified = emdat_geocode_adm1_stacked.reset_index().drop(columns={'level_1'})

emdat_geocode_adm1_identified
# Out:
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
#              DisNo. ADM1_CODE                 location  \
# 0     2020-0051-IRL      1592            County Laois.
# 1     2020-0051-IRL      1603   Geevagh (County Sligo)
# 2     2021-0001-BOL     40443                     Beni
# 3     2021-0001-BOL     40445               Cochabamba
# 4     2021-0001-BOL     40446       La Paz Departments
# ...             ...       ...                      ...
# 2103  2023-9167-HND      1438                Jacaleapa
# 2104  2023-9234-ESP      2716                Andalusia
# 2105  2023-9234-ESP      2724                 Asturias
# 2106  2023-9234-ESP      2718               Catalognia
# 2107  2023-9494-IDN     73617                     Bali
#
#                   geolocation
# 0                       Laois
# 1                       Sligo
# 2                        Beni
# 3                  Cochabamba
# 4                      La Paz
# ...                       ...
# 2103                     Yoro
# 2104                Andalucía
# 2105       Cataluña/Catalunya
# 2106   Principado de Asturias
# 2107                    Papua
#
# [2108 rows x 4 columns]

# %%
emdat_geocode_adm1
# Out:
#                                                      Admin1 Code  \
# DisNo.
# 2020-0051-IRL                                          1592;1603
# 2021-0001-BOL                            40443;40445;40446;40450
# 2021-0002-ARG                                                446
# 2021-0004-IDN                                               1520
# 2021-0005-IDN  1522;1523;1524;1525;73615;73616;73619;73620;15...
# ...                                                          ...
# 2023-0539-CHL                                     889;892;149630
# 2023-0548-IND                                               1502
# 2023-9167-HND                                1420;1421;1433;1438
# 2023-9234-ESP                                     2716;2724;2718
# 2023-9494-IDN                                              73617
#
#                                  Admin2 Code  \
# DisNo.
# 2020-0051-IRL
# 2021-0001-BOL
# 2021-0002-ARG
# 2021-0004-IDN
# 2021-0005-IDN
# ...                                      ...
# 2023-0539-CHL                    12971;12947
# 2023-0548-IND
# 2023-9167-HND  17413;17439;17335;17287;17313
# 2023-9234-ESP
# 2023-9494-IDN
#
#                                                    Geo Locations  \
# DisNo.
# 2020-0051-IRL                                       Laois, Sligo
# 2021-0001-BOL                   Beni, Cochabamba, La Paz, Tarija
# 2021-0002-ARG                                           San Juan
# 2021-0004-IDN                                        Jawa Tengah
# 2021-0005-IDN  Kalimantan Barat, Kalimantan Selatan, Kalimant...
# ...                                                          ...
# 2023-0539-CHL  Libertador Gral. Bernardo O'Higgins, Maule, Va...
# 2023-0548-IND                                            Mizoram
# 2023-9167-HND             Atlantida, Choluteca, Ocotepeque, Yoro
# 2023-9234-ESP  Andalucía, Cataluña/Catalunya, Principado de A...
# 2023-9494-IDN                                              Papua
#
#                                                         Location
# DisNo.
# 2020-0051-IRL  County Laois., Geevagh (County Sligo), Riverst...
# 2021-0001-BOL       Beni, Cochabamba, La Paz Departments, Tarija
# 2021-0002-ARG                                  San Juan Province
# 2021-0004-IDN                                       Central Java
# 2021-0005-IDN        Kalimantan, Maluku Islands, Sulawesi Island
# ...                                                          ...
# 2023-0539-CHL  Biobío Regions, Maule, O’Higgins, Santiago Met...
# 2023-0548-IND                                      Mizoram State
# 2023-9167-HND  Catacamas, Choculeta, Flores, Jacaleapa, La Es...
# 2023-9234-ESP                    Andalusia, Asturias, Catalognia
# 2023-9494-IDN  Bali, Bangka Belitung, Banten, Bengkulu, Daera...
#
# [518 rows x 4 columns]

# %%
emdat_geocode_adm1['Location'].astype(str).str.split(',').apply(len).sum()
# Out:
# 2396

# %%
(emdat_geocode_adm1['Admin1 Code'].astype(str).str.split(';').apply(len) + (emdat_geocode_adm1['Admin2 Code'].astype(str).str.split(';').apply(len) - emdat_geocode_adm1['Admin2 Code'].isna())).sum()
# Out:
# 2930

# %%
emdat_geocode_adm1_identified
# Out:
#              DisNo. ADM1_CODE                 location  \
# 0     2020-0051-IRL      1592            County Laois.
# 1     2020-0051-IRL      1603   Geevagh (County Sligo)
# 2     2021-0001-BOL     40443                     Beni
# 3     2021-0001-BOL     40445               Cochabamba
# 4     2021-0001-BOL     40446       La Paz Departments
# ...             ...       ...                      ...
# 2103  2023-9167-HND      1438                Jacaleapa
# 2104  2023-9234-ESP      2716                Andalusia
# 2105  2023-9234-ESP      2724                 Asturias
# 2106  2023-9234-ESP      2718               Catalognia
# 2107  2023-9494-IDN     73617                     Bali
#
#                   geolocation
# 0                       Laois
# 1                       Sligo
# 2                        Beni
# 3                  Cochabamba
# 4                      La Paz
# ...                       ...
# 2103                     Yoro
# 2104                Andalucía
# 2105       Cataluña/Catalunya
# 2106   Principado de Asturias
# 2107                    Papua
#
# [2108 rows x 4 columns]

# %%
gaul_1 = gpd.read_file('/net/projects/xaida/raw_data/gaul_maps/gaul_admin1_clean.gpkg')

# %%
gaul_1.columns
# Out:
# Index(['ADM0_CODE', 'ADM0_NAME', 'ADM1_CODE', 'ADM1_NAME', 'DISP_AREA',
#        'EXP1_YEAR', 'STATUS', 'STR1_YEAR', 'Shape_Area', 'Shape_Leng',
#        'official_name', 'iso3', 'geometry'],
#       dtype='object')

# %%
gaul_1_loc = gaul_1[['ADM1_CODE','ADM1_NAME']]

# %%
gaul_1_loc.dtypes
# Out:
# ADM1_CODE     int64
# ADM1_NAME    object
# dtype: object

# %%
emdat_geocode_adm1_identified.dtypes
# Out:
# DisNo.         object
# ADM1_CODE      object
# location       object
# geolocation    object
# dtype: object

# %%
emdat_geocode_adm1_identified['ADM1_CODE'] = emdat_geocode_adm1_identified['ADM1_CODE'].astype(int)

# %%
emdat_geocode_adm1_identified_merged = emdat_geocode_adm1_identified.merge(gaul_1_loc, on = 'ADM1_CODE',how = 'left')

# %%
emdat_geocode_adm1_identified_merged
# Out:
#              DisNo.  ADM1_CODE                 location  \
# 0     2020-0051-IRL       1592            County Laois.
# 1     2020-0051-IRL       1603   Geevagh (County Sligo)
# 2     2021-0001-BOL      40443                     Beni
# 3     2021-0001-BOL      40445               Cochabamba
# 4     2021-0001-BOL      40446       La Paz Departments
# ...             ...        ...                      ...
# 2107  2023-9167-HND       1438                Jacaleapa
# 2108  2023-9234-ESP       2716                Andalusia
# 2109  2023-9234-ESP       2724                 Asturias
# 2110  2023-9234-ESP       2718               Catalognia
# 2111  2023-9494-IDN      73617                     Bali
#
#                   geolocation               ADM1_NAME
# 0                       Laois                   Laois
# 1                       Sligo                   Sligo
# 2                        Beni                    Beni
# 3                  Cochabamba              Cochabamba
# 4                      La Paz                  La Paz
# ...                       ...                     ...
# 2107                     Yoro                    Yoro
# 2108                Andalucía               Andaluc�a
# 2109       Cataluña/Catalunya      Catalu�a/Catalunya
# 2110   Principado de Asturias  Principado de Asturias
# 2111                    Papua                   Papua
#
# [2112 rows x 5 columns]

# %%
emdat_geocode_adm1_identified_merged["geolocation"] = emdat_geocode_adm1_identified_merged["geolocation"].str.lstrip()
emdat_geocode_adm1_identified_merged["geolocation"] = emdat_geocode_adm1_identified_merged["geolocation"].str.rstrip()

# %%
emdat_geocode_adm1_identified_merged["ADM1_NAME"] = emdat_geocode_adm1_identified_merged["ADM1_NAME"].str.lstrip()
emdat_geocode_adm1_identified_merged["ADM1_NAME"] = emdat_geocode_adm1_identified_merged["ADM1_NAME"].str.rstrip()

# %%
emdat_geocode_adm1_identified_merged['comparison'] = emdat_geocode_adm1_identified_merged.apply(lambda x: x['geolocation'] == x['ADM1_NAME'], axis=1)

# %%
emdat_geocode_adm1_identified_merged[emdat_geocode_adm1_identified_merged.comparison == False]
# Out:
#              DisNo.  ADM1_CODE  \
# 86    2021-0071-MAR     147337
# 122   2021-0098-PER       2339
# 158   2021-0170-PER       2349
# 236   2021-0212-PER       2349
# 242   2021-0230-GTM      64823
# 394   2021-0300-GTM      64837
# 398   2021-0300-GTM      64827
# 399   2021-0300-GTM      64830
# 422   2021-0326-GUY       1399
# 423   2021-0326-GUY       1400
# 424   2021-0326-GUY       1401
# 425   2021-0326-GUY       1402
# 426   2021-0326-GUY       1403
# 427   2021-0326-GUY       1406
# 428   2021-0326-GUY       1407
# 433   2021-0328-PAN      93669
# 434   2021-0328-PAN       2283
# 435   2021-0328-PAN       2288
# 464   2021-0356-CAN        835
# 601   2021-0445-PAN      93669
# 602   2021-0445-PAN      93672
# 780   2021-0588-GTM      64827
# 942   2021-0766-ESP       2733
# 1114  2022-0092-GTM      64823
# 1115  2022-0092-GTM      64827
# 1116  2022-0092-GTM      64830
# 1117  2022-0092-GTM      64828
# 1345  2022-0375-GUY       1399
# 1346  2022-0375-GUY       1403
# 1347  2022-0375-GUY       1406
# 1348  2022-0375-GUY       1407
# 1396  2022-0449-CAF        866
# 1498  2022-0603-CAN        831
# 1499  2022-0603-CAN        834
# 1500  2022-0603-CAN        835
# 1512  2022-0603-DOM      36857
# 1574  2022-0647-GTM      64837
# 1576  2022-0647-GTM      64834
# 1577  2022-0647-GTM      64823
# 1579  2022-0647-GTM      64827
# 1580  2022-0647-GTM      64828
# 1980  2023-0280-CAN        831
# 1982  2023-0280-CAN        835
# 2038  2023-0365-GTM      64830
# 2039  2023-0365-GTM      64828
# 2108  2023-9234-ESP       2716
# 2109  2023-9234-ESP       2724
#
#                                                location  \
# 86                                               Tanger
# 122                                               Junín
# 158         Yurimaguas District (Alto Amazonas Province
# 236   Nauta District (Loreto Province); San Martin r...
# 242   Uspantán and Chicamán Municipalities (Quiché D...
# 394                                      Quetzaltenango
# 398                           Suchitepéquez departments
# 399                                                 NaN
# 422                                                   4
# 423                                                   5
# 424                                                   6
# 425                                                   7
# 426                                            9 and 10
# 427                                           Regions 3
# 428                                                 NaN
# 433                                            Chiriquí
# 434                      Cristóbal Town (Colón Province
# 435    Las Garzas de Pacora locality (eastern Panama...
# 464                         Montreal City area (Quebec)
# 601                                           Almirante
# 602                                         Changuinola
# 780                                                 NaN
# 942                        Cantabria and Basque Regions
# 1114                                       Sacatepéquez
# 1115                                             Sololá
# 1116          Suchitepéquez and Totonicapán departments
# 1117                                                NaN
# 1345                                    Cuyuni-Mazaruni
# 1346                                    Mahaica-Berbice
# 1347                       Upper Demerara-Upper Berbice
# 1348           and Upper Takutu-Upper Essequibo Regions
# 1396                                        Ouham-Pendé
# 1498                                        Nova Scotia
# 1499                               Prince Edward Island
# 1500                                         and Quebec
# 1512                                   San José de Ocoa
# 1574                                              Petén
# 1576                                             Quiché
# 1577                                       Sacatepéquez
# 1579                                             Sololá
# 1580                                        Totonicapán
# 1980                                        Nova Scotia
# 1982                                             Québec
# 2038                                      Suchitepéques
# 2039                 Zacapa and Totonicapán Departments
# 2108                                          Andalusia
# 2109                                           Asturias
#
#                                        geolocation  \
# 86                                Tanger - Tétouan
# 122                                          Junín
# 158                                     San Martín
# 236                                     San Martín
# 242                                   Sacatepéquez
# 394                                          Petén
# 398                                         Sololá
# 399                                  Suchitepéquez
# 422                   Cuyuni/mazaruni (region N°7)
# 423                  Demerara Mahaica (region N°4)
# 424            East Berbice/corentyne (region N°6)
# 425   Essequibo Islands/west Demerara (region N°3)
# 426                   Mahaica Berbice (region N°5)
# 427           Upper Demerara/berbice (region N°10)
# 428      Upper Takutu/upper Essequibo (region N°9)
# 433                                       Chiriquí
# 434                                          Colón
# 435                                         Panamá
# 464                                Quebec / Québec
# 601                                       Chiriquí
# 602                                    Ngöbe Buglé
# 780                                         Sololá
# 942                             País Vasco/Euskadi
# 1114                                  Sacatepéquez
# 1115                                        Sololá
# 1116                                 Suchitepéquez
# 1117                                   Totonicapán
# 1345                  Cuyuni/mazaruni (region N°7)
# 1346                  Mahaica Berbice (region N°5)
# 1347          Upper Demerara/berbice (region N°10)
# 1348     Upper Takutu/upper Essequibo (region N°9)
# 1396                                   Ouham Pendé
# 1498                 Nova Scotia / Nouvelle-Écosse
# 1499  Prince Edward Island / Île-du-Prince-Édouard
# 1500                               Quebec / Québec
# 1512                              San José de Ocoa
# 1574                                         Petén
# 1576                                        Quiché
# 1577                                  Sacatepéquez
# 1579                                        Sololá
# 1580                                   Totonicapán
# 1980                 Nova Scotia / Nouvelle-Écosse
# 1982                               Quebec / Québec
# 2038                                 Suchitepéquez
# 2039                                   Totonicapán
# 2108                                     Andalucía
# 2109                            Cataluña/Catalunya
#
#                                          ADM1_NAME  comparison
# 86                                Tanger - T�touan       False
# 122                                          Jun�n       False
# 158                                     San Mart�n       False
# 236                                     San Mart�n       False
# 242                                   Sacatep�quez       False
# 394                                          Pet�n       False
# 398                                         Solol�       False
# 399                                  Suchitep�quez       False
# 422                   Cuyuni/mazaruni (region N�7)       False
# 423                  Demerara Mahaica (region N�4)       False
# 424            East Berbice/corentyne (region N�6)       False
# 425   Essequibo Islands/west Demerara (region N�3)       False
# 426                   Mahaica Berbice (region N�5)       False
# 427           Upper Demerara/berbice (region N�10)       False
# 428      Upper Takutu/upper Essequibo (region N�9)       False
# 433                                       Chiriqu�       False
# 434                                          Col�n       False
# 435                                         Panam�       False
# 464                                Quebec / Qu�bec       False
# 601                                       Chiriqu�       False
# 602                                    Ng�be Bugl�       False
# 780                                         Solol�       False
# 942                             Pa�s Vasco/Euskadi       False
# 1114                                  Sacatep�quez       False
# 1115                                        Solol�       False
# 1116                                 Suchitep�quez       False
# 1117                                   Totonicap�n       False
# 1345                  Cuyuni/mazaruni (region N�7)       False
# 1346                  Mahaica Berbice (region N�5)       False
# 1347          Upper Demerara/berbice (region N�10)       False
# 1348     Upper Takutu/upper Essequibo (region N�9)       False
# 1396                                   Ouham Pend�       False
# 1498                 Nova Scotia / Nouvelle-�cosse       False
# 1499  Prince Edward Island / �le-du-Prince-�douard       False
# 1500                               Quebec / Qu�bec       False
# 1512                              San Jos� de Ocoa       False
# 1574                                         Pet�n       False
# 1576                                        Quich�       False
# 1577                                  Sacatep�quez       False
# 1579                                        Solol�       False
# 1580                                   Totonicap�n       False
# 1980                 Nova Scotia / Nouvelle-�cosse       False
# 1982                               Quebec / Qu�bec       False
# 2038                                 Suchitep�quez       False
# 2039                                   Totonicap�n       False
# 2108                                     Andaluc�a       False
# 2109                            Catalu�a/Catalunya       False

# %%
gaul_1[gaul_1.ADM1_CODE == 2754]
# Out:
#     ADM0_CODE    ADM0_NAME  ADM1_CODE                ADM1_NAME DISP_AREA  \
# 22         74  South Sudan       2754  Northern Bahr El Ghazal        NO
#
#     EXP1_YEAR        STATUS  STR1_YEAR  Shape_Area  Shape_Leng  \
# 22       3000  Member State       1994    2.494846    7.052428
#
#               official_name iso3  \
# 22  Republic of South Sudan  SSD
#
#                                              geometry
# 22  POLYGON ((26.13292 9.08244, 26.13530 9.10099, ...

# %%
gaul_1[gaul_1.ADM0_NAME == 'South Sudan']
# Out:
#     ADM0_CODE    ADM0_NAME  ADM1_CODE                          ADM1_NAME  \
# 17         74  South Sudan       2746                        El Buheyrat
# 18         74  South Sudan       2747                              Unity
# 19         74  South Sudan       2748                  Central Equatoria
# 20         74  South Sudan       2750                  Eastern Equatoria
# 21         74  South Sudan       2751                            Jonglei
# 22         74  South Sudan       2754            Northern Bahr El Ghazal
# 23         74  South Sudan       2765                              Warab
# 24         74  South Sudan       2766             Western Bahr El Ghazal
# 25         74  South Sudan       2768                  Western Equatoria
# 26         74  South Sudan      37021                         Upper Nile
# 61        102  South Sudan        124  Administrative unit not available
#
#    DISP_AREA  EXP1_YEAR                 STATUS  STR1_YEAR  Shape_Area  \
# 17        NO       3000           Member State       1994    3.503620
# 18        NO       3000           Member State       1994    3.011566
# 19        NO       3000           Member State       1994    3.595255
# 20        NO       3000           Member State       1994    5.769396
# 21        NO       3000           Member State       1994    9.907790
# 22        NO       3000           Member State       1994    2.494846
# 23        NO       3000           Member State       1994    3.105859
# 24        NO       3000           Member State       1994    7.362645
# 25        NO       3000           Member State       1994    6.400287
# 26        NO       3000           Member State       1994    6.447897
# 61       YES       3000  Sovereignty unsettled       2011    0.818949
#
#     Shape_Leng            official_name iso3  \
# 17   11.235001  Republic of South Sudan  SSD
# 18   11.096973  Republic of South Sudan  SSD
# 19   11.441561  Republic of South Sudan  SSD
# 20   13.566082  Republic of South Sudan  SSD
# 21   17.315025  Republic of South Sudan  SSD
# 22    7.052428  Republic of South Sudan  SSD
# 23    9.675830  Republic of South Sudan  SSD
# 24   15.653986  Republic of South Sudan  SSD
# 25   15.338082  Republic of South Sudan  SSD
# 26   15.496584  Republic of South Sudan  SSD
# 61    3.608281  Republic of South Sudan  SSD
#
#                                              geometry
# 17  POLYGON ((28.46691 6.47376, 28.46786 6.47947, ...
# 18  POLYGON ((28.71832 9.04250, 28.71832 9.04375, ...
# 19  POLYGON ((29.79232 4.50914, 29.79785 4.51991, ...
# 20  POLYGON ((31.69433 3.95444, 31.70147 3.96158, ...
# 21  POLYGON ((30.21263 8.91872, 30.21501 8.92348, ...
# 22  POLYGON ((26.13292 9.08244, 26.13530 9.10099, ...
# 23  POLYGON ((27.62626 8.28199, 27.62715 8.28258, ...
# 24  POLYGON ((24.15070 8.39634, 24.15072 8.39642, ...
# 25  POLYGON ((26.28462 6.45896, 26.29016 6.47718, ...
# 26  POLYGON ((30.74803 9.46688, 30.74923 9.53971, ...
# 61  POLYGON ((27.81417 9.80064, 27.81453 9.80080, ...

# %% [markdown]
# ### geometries at Admin 2 level

# %%
####Administrative level 2 geometries
#Extract Adm2 locations
emdat_geocode_adm2 = Emdata_geocode[Emdata_geocode['Geo Locations'].str.contains("(Adm2)")]
#In the Geo Locations column, some rows still have admin1 geometry locations that need to be removed
#clean Adm1 mention for the admin2 locations
emdat_geocode_adm2_cadm1 = emdat_geocode_adm2[emdat_geocode_adm2['Geo Locations'].str.contains("(Adm1)")]#location 2 with location 1 mentions still
#emdat_geocode_adm2_cadm1 = emdat_geocode_adm2_cadm1.reset_index().iloc[:,1::]
emdat_geocode_adm2_cadm1["Geo Locations"] = emdat_geocode_adm2_cadm1["Geo Locations"].str.split(" \(Adm1\).",expand=True)[1].str.replace(" \(Adm2\).","")
emdat_geocode_adm2_wtadm1 = emdat_geocode_adm2[~emdat_geocode_adm2['Geo Locations'].str.contains("(Adm1)")]
emdat_geocode_adm2_wtadm1["Geo Locations"] = emdat_geocode_adm2_wtadm1["Geo Locations"].str.replace(" \(Adm2\).","")

emdat_geocode_adm2 = pd.concat([emdat_geocode_adm2_cadm1,emdat_geocode_adm2_wtadm1])
# Out:
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:6: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:8: FutureWarning: The default value of regex will change from True to False in a future version.
#
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:9: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   if __name__ == "__main__":
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:10: FutureWarning: The default value of regex will change from True to False in a future version.
#   # Remove the CWD from sys.path while we load stuff.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.

# %%
emdat_geocode_adm2
# Out:
#                                  Admin1 Code        Admin2 Code  \
# DisNo.
# 2021-0020-BGR                            713              11862
# 2021-0022-PHL                          67165        24251;24259
# 2021-0035-BOL              40445;40446;40448              40458
# 2021-0059-USA  3233;3244;3246;3252;3260;3261              29907
# 2021-0069-CHL         884;887;889;892;149630              12971
# ...                                      ...                ...
# 2023-0391-VEN                                             31914
# 2023-0451-COL                                             13906
# 2023-0458-ITA                                 18415;18417;18420
# 2023-0459-IND                                             17777
# 2023-0529-FRA                                             16289
#
#                                     Geo Locations  \
# DisNo.
# 2021-0020-BGR                           Strumjani
# 2021-0022-PHL   Negros Occidental, Northern Samar
# 2021-0035-BOL                             Oropeza
# 2021-0059-USA                             Suffolk
# 2021-0069-CHL                            Santiago
# ...                                           ...
# 2023-0391-VEN                           El Callao
# 2023-0451-COL                             Quetame
# 2023-0458-ITA            Padova, Treviso, Vicenza
# 2023-0459-IND                             Raigarh
# 2023-0529-FRA                 Pyrenees-Orientales
#
#                                                         Location
# DisNo.
# 2021-0020-BGR                        Batanovtsi, Strumiani, Tran
# 2021-0022-PHL  Negros Occidental and Northern Samar Provinces...
# 2021-0035-BOL  Cochabamba Department, Paz Department, Potosì ...
# 2021-0059-USA  Boston (Suffolk, Maine, Massachusetts), New Je...
# 2021-0069-CHL  Araucanía, Maule, O’Higgins, Santiago Metropol...
# ...                                                          ...
# 2023-0391-VEN                     El Callao City (Bolivar State)
# 2023-0451-COL     Quetame Municipality (Cundinamarca Department)
# 2023-0458-ITA        Padoue, Vicence et Trévise regions (Venise)
# 2023-0459-IND  Irshalwadi Village (Raigad District, western M...
# 2023-0529-FRA  Saint-André and Argelès-sur-Mer (Pyrénées-Orie...
#
# [353 rows x 4 columns]

# %%
emdat_geocode_adm2['Geo Locations'].astype(str).str.split(',').apply(len).sum()
# Out:
# 1218

# %%
(emdat_geocode_adm2['Admin2 Code'].astype(str).str.split(';')).apply(len).sum()
# Out:
# 1218

# %% [markdown]
# ## 2) Matching events without geolocations, only location names (2021-2023)

# %%
#Shape Adm1 locations: 1 row = 1 geolocation
emdat_geocode_adm2_stacked = pd.DataFrame(emdat_geocode_adm2["Admin2 Code"].str.split(';', expand=True).stack()).rename(columns={0:'ADM2_CODE'})
emdat_geocode_adm2_stacked['location'] = pd.DataFrame(emdat_geocode_adm2["Location"].str.split(',', expand=True).stack())
emdat_geocode_adm2_stacked['geolocation'] = pd.DataFrame(emdat_geocode_adm2["Geo Locations"].str.split(',', expand=True).stack())
emdat_geocode_adm2_identified = emdat_geocode_adm2_stacked.reset_index()


##Load administrative boundries objects to merge locations with events

gaul1 = gpd.read_file('/net/projects/xaida/raw_data/gaul_maps/gaul_admin1_clean.gpkg')
gaul2 = gpd.read_file('/net/projects/xaida/raw_data/gaul_maps/gaul_admin2_clean.gpkg')

#get the admin1 geolocated events geometries #emdat_geocode_adm1_identified
emdat_geocode_adm1_identified['ADM1_CODE'] = emdat_geocode_adm1_identified['ADM1_CODE'].astype(int)
events_adm1  = emdat_geocode_adm1_identified.merge(gaul1, on='ADM1_CODE', how='left')

#get the admin2 geolocated events geometries #emdat_geocode_adm2_identified
emdat_geocode_adm2_identified['ADM2_CODE'] = emdat_geocode_adm2_identified['ADM2_CODE'].astype(int)
events_adm2  = emdat_geocode_adm2_identified.merge(gaul2, on='ADM2_CODE', how='left')

#Find the geolocations for the events of which we only have the location name #Emdata_locations_only
#this needs to be done in different steps, as we have no indication about the administrative level of the location
#also, looking up the geometries needs to take place for each country separately, to limit mismatch

# %%
#loading data again to work on data without geolocation

Emdata = pd.read_excel('/net/projects/xaida/raw_data/emdat_data/public_emdat_2021_2023.xlsx')
Emdata_loconly = Emdata[Emdata['Admin Units'].isna() & Emdata['Location'].notna()]

# %%
def split_and_clean_locations(location):
    entries = re.split(r';', location)
    cleaned_entries = []
    for entry in entries:
        if '(' in entry and ')' in entry:
            cleaned_entries.append(entry.strip())
        else:
            sub_entries = re.split(r',\s*(?![^()]*\))', entry)
            cleaned_entries.extend([sub_entry.strip() for sub_entry in sub_entries if sub_entry.strip()])
    return cleaned_entries

# Expand the DataFrame
expanded_rows = [
    [row['DisNo.'], row['Location'], loc]
    for _, row in Emdata_loconly.iterrows()
    for loc in split_and_clean_locations(row['Location'])
]

expanded_df = pd.DataFrame(expanded_rows, columns=['DisNo.', 'Full_Location_List', 'Individual_Location'])

# Clean the 'Individual_Location' column
replace_terms = ["Near", "Province", "province", "state", "City", "Regency", "provinces", "region", "Region", 
                 "district", "districts", "District", "Municipality", "municipality"]

for term in replace_terms:
    expanded_df['Individual_Location'] = expanded_df['Individual_Location'].str.replace(term, "", regex=False)

def split_text(text):
    if text.count('(') > 1:
        return re.split(r',\s*(?=\S)', re.sub(r'\),\s*(?=\S)', '),\n', text))
    return re.split(r'\),\s*(?=\S)', text)

expanded_df['Individual_Location'] = expanded_df['Individual_Location'].apply(split_text)
expanded_df = expanded_df.explode('Individual_Location', ignore_index=True)

expanded_df['Individual_Location'] = expanded_df['Individual_Location'].str.replace(' and ', ', ')

def extract_locations(row):
    locations = []
    if '(' in row:
        parts = row.split('(')
        locs = parts[0].strip().split(',')
        regions = parts[1].replace(')', '').split(',')
        for loc in locs:
            for sub_loc in loc.strip().split('/'):
                for region in regions:
                    locations.append([sub_loc.strip(), region.strip()])
    elif ',' in row:
        for loc in row.split(','):
            locations.append([loc.strip(), None])
    else:
        for loc in row.strip().split('/'):
            locations.append([loc.strip(), None])
    return locations

new_data = [
    [row['DisNo.'], row['Individual_Location'], loc[0], loc[1]]
    for _, row in expanded_df.iterrows()
    for loc in extract_locations(row['Individual_Location'])
]

new_df = pd.DataFrame(new_data, columns=['DisNo.', 'Individual_Location', 'Location_Before', 'Bracketed'])
new_df['Appended'] = new_df['Location_Before'] + new_df['Bracketed'].apply(lambda x: f" {x}" if x else "")

print(new_df)
# Out:
#              DisNo.             Individual_Location Location_Before Bracketed  \
# 0     2020-9609-SOM                            Gedo            Gedo      None
# 1     2020-9609-SOM  Las Anod / Hudun, Taleb (Sool)        Las Anod      Sool
# 2     2020-9609-SOM  Las Anod / Hudun, Taleb (Sool)           Hudun      Sool
# 3     2020-9609-SOM  Las Anod / Hudun, Taleb (Sool)           Taleb      Sool
# 4     2020-9609-SOM               Eilafwen (Sanaag)        Eilafwen    Sanaag
# ...             ...                             ...             ...       ...
# 2633  2023-9868-USA                         Montana         Montana      None
# 2634  2023-9873-FSM                           Chuuk           Chuuk      None
# 2635  2023-9873-FSM                          Kosrae          Kosrae      None
# 2636  2023-9873-FSM                         Pohnpei         Pohnpei      None
# 2637  2023-9873-FSM                             Yap             Yap      None
#
#              Appended
# 0                Gedo
# 1       Las Anod Sool
# 2          Hudun Sool
# 3          Taleb Sool
# 4     Eilafwen Sanaag
# ...               ...
# 2633          Montana
# 2634            Chuuk
# 2635           Kosrae
# 2636          Pohnpei
# 2637              Yap
#
# [2638 rows x 5 columns]

# %% [markdown]
# ##Now Data with locations , no geocoded data is further divided into three columns Location_Before - Location that is present before (Bracket Admin1 location) and third column appending both location before and Brackted data

# %%
#now data is further divided into two data sets ,first  dataset with  bracket data,
#second dataset is with no bracket data.


new_df_1 = new_df[new_df['Bracketed'].isnull()]
new_df_2 = new_df[~new_df['Bracketed'].isnull()]

# %%
new_df_1
# Out:
#              DisNo. Individual_Location Location_Before Bracketed  Appended
# 0     2020-9609-SOM                Gedo            Gedo      None      Gedo
# 11    2020-9609-SOM           Puntland         Puntland      None  Puntland
# 12    2020-9609-SOM              Nugaal          Nugaal      None    Nugaal
# 13    2020-9609-SOM            Galmudug        Galmudug      None  Galmudug
# 14    2020-9609-SOM            Jubaland        Jubaland      None  Jubaland
# ...             ...                 ...             ...       ...       ...
# 2633  2023-9868-USA             Montana         Montana      None   Montana
# 2634  2023-9873-FSM               Chuuk           Chuuk      None     Chuuk
# 2635  2023-9873-FSM              Kosrae          Kosrae      None    Kosrae
# 2636  2023-9873-FSM             Pohnpei         Pohnpei      None   Pohnpei
# 2637  2023-9873-FSM                 Yap             Yap      None       Yap
#
# [1802 rows x 5 columns]

# %%
############################
## Functions needed for fuzzy matching of geometries by name
############################

from thefuzz import process
#function for fuzzy names matching
def fuzzy_match(
    df_left, df_right, column_left, column_right, threshold=90, limit=1):
    # Create a series
    series_matches = df_left[column_left].apply(
        lambda x: process.extract(x, df_right[column_right], limit=limit)            # Creates a series with id from df_left and column name _column_left_, with _limit_ matches per item
    )

    # Convert matches to a tidy dataframe
    df_matches = series_matches.to_frame()
    df_matches = df_matches.explode(column_left)     # Convert list of matches to rows
    df_matches[
        ['match_string', 'match_score', 'df_right_id']
    ] = pd.DataFrame(df_matches[column_left].tolist(), index=df_matches.index)       # Convert match tuple to columns
    df_matches.drop(column_left, axis=1, inplace=True)      # Drop column of match tuples

    # Reset index, as in creating a tidy dataframe we've introduced multiple rows per id, so that no longer functions well as the index
    if df_matches.index.name:
        index_name = df_matches.index.name     # Stash index name
    else:
        index_name = 'index'        # Default used by pandas
    df_matches.reset_index(inplace=True)
    df_matches.rename(columns={index_name: 'df_left_id'}, inplace=True)       # The previous index has now become a column: rename for ease of reference

    # Drop matches below threshold
    df_matches.drop(
        df_matches.loc[df_matches['match_score'] < threshold].index,
        inplace=True
    )

    return df_matches

# %%
#function for matching datasets uses fuzzy names matching
def match_datasets(df1, df2, col_a, col_b):
    
    df_matches = fuzzy_match(
    df1,
    df2,
    col_a,
    col_b,
    threshold=90,
    limit=1
    )

    df_output = df1.merge(
        df_matches,
        how='left',
        left_index=True,
        right_on='df_left_id'
    ).merge(
        df2,
        how='left',
        left_on='df_right_id',
        right_index=True,
        suffixes=['_df1', '_df2']
    )
    return(df_output)

# %%
#function for matching names with corresponding vector geometries
def match_emdat_gdis(emdat_df, gdam_df, iso,varname):
    
    ## EM-DAT preprocess
    emdat_iso = emdat_df[emdat_df["DisNo."].str.contains(iso)]
    emdat_iso = emdat_iso.rename(columns={varname:"name_join"})
    
    gdam_df = gdam_df[gdam_df["iso3"] == iso]
    #join name and alternative names to enhance accuracy
    gdam_df["name_join"] = gdam_df[[varname]].astype(str).agg(' - '.join, axis=1)
    
    if emdat_iso.empty | gdam_df.empty:
        return(gpd.GeoDataFrame())
    else:
        ####double the string to match in EM-DAT for maximal accuracy
        #emdat_iso["name_join"] = emdat_iso[['name_join','name_join']].astype(str).agg(' - '.join, axis=1)
        #Eliminate generic words related to Russian political entities that cause errors in matches
        emdat_iso["name_join"] = emdat_iso["name_join"].str.replace("Rep.","")
        emdat_iso["name_join"] = emdat_iso["name_join"].str.replace("Kray","")
        emdat_iso["name_join"] = emdat_iso["name_join"].str.replace("Oblast","")
        #Names of Russian regions that need to be changed
        emdat_iso["name_join"] = emdat_iso["name_join"].str.replace("Dagestan","Daghestan")
        emdat_iso["name_join"] = emdat_iso["name_join"].str.replace("Karelya","Karelia")
        emdat_iso["name_join"] = emdat_iso["name_join"].str.replace("Yevreyskaya A","Yevrey - Yevreyskaya")
        #Eliminate generic words related to Philippino political entities that cause errors in matches
        emdat_iso["name_join"] = emdat_iso["name_join"].str.replace("Region XIII","")
        emdat_iso["name_join"] = emdat_iso["name_join"].str.replace("Region XII","")
        emdat_iso["name_join"] = emdat_iso["name_join"].str.replace("Region XI","")
        emdat_iso["name_join"] = emdat_iso["name_join"].str.replace("Region X","")
        emdat_iso["name_join"] = emdat_iso["name_join"].str.replace("Region IX","")
        emdat_iso["name_join"] = emdat_iso["name_join"].str.replace("Region VIII","")
        emdat_iso["name_join"] = emdat_iso["name_join"].str.replace("Region VII","")
        emdat_iso["name_join"] = emdat_iso["name_join"].str.replace("Region VI","")
        emdat_iso["name_join"] = emdat_iso["name_join"].str.replace("Region VI","")
        emdat_iso["name_join"] = emdat_iso["name_join"].str.replace("Region V","")
        emdat_iso["name_join"] = emdat_iso["name_join"].str.replace("Region III","")
        emdat_iso["name_join"] = emdat_iso["name_join"].str.replace("Region II","")
        emdat_iso["name_join"] = emdat_iso["name_join"].str.replace("Region I","")   
        emdat_iso["name_join"] = emdat_iso["name_join"].str.replace("region ","")
        
        
        ##GADM preprocess
        
        #Eliminate generic words related to Russian political entities that cause errors in matches
        gdam_df["name_join"] = gdam_df["name_join"].str.replace("Republic of","")
        gdam_df["name_join"] = gdam_df["name_join"].str.replace("Republic","")
        gdam_df["name_join"] = gdam_df["name_join"].str.replace("Respublika","")
        gdam_df["name_join"] = gdam_df["name_join"].str.replace("Kray","")
        gdam_df["name_join"] = gdam_df["name_join"].str.replace("Oblast","")
        
        #Elimination of string in case of no entry
        gdam_df["name_join"] = gdam_df["name_join"].str.replace("- None","")
        
        #Sort both datasets alphabetically with the name join column
        emdat_iso = emdat_iso.sort_values("name_join")
        gdam_df = gdam_df.sort_values("name_join")
        
        #Merge datasets
        merged = match_datasets(emdat_iso, gdam_df, "name_join", "name_join")
        merged = gpd.GeoDataFrame(merged)
        return(merged)

# %%
#function for concatenating geopandas dataframes
def concat_db(db1, db2):
    return(pd.concat([db1, db2], axis=0))

# %%
#Emdata_locations_only.Location = Emdata_locations_only.Location.str.replace(" Near","").replace(" and ",",").replace(" 'province)","").replace(" 'province ","").replace("Between","").replace('Isl.',"").replace(' districts',"").replace(' region',"")

# %%
Emdata_locations_only = new_df_1[['DisNo.','Location_Before']]

Emdata_locations_only.reset_index(drop=True, inplace=True)


iso_locations = Emdata_locations_only['DisNo.'].str.split('-',expand=True)[2]
Emdata_locations_only['iso3'] = iso_locations #add iso3 codes of every location/ event
# Out:
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys

# %% [markdown]
# ## 3) Merging all geolocated events

# %%
#Administrative level 1
isos = np.unique(Emdata_locations_only["iso3"])#iso codes for the loop
final_db = gpd.GeoDataFrame()#empty geoDF for results

Emdata_locations_only = Emdata_locations_only.rename(columns={'Location_Before':"ADM1_NAME"})#change name of column to merge on

for iso in isos:
    db = match_emdat_gdis(Emdata_locations_only, gaul1, iso,"ADM1_NAME")
    if db.empty:
        pass
    else:
        final_db = pd.concat([final_db,db],axis=0)
        
locations_only_events_admin1 = final_db[~final_db['geometry'].isna()].reset_index().drop(columns={'index'})
# Out:
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# ...
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.

# %%
locations_only_events_admin1
# Out:
#             DisNo.       name_join_df1 iso3_df1  df_left_id  \
# 0    2022-0264-AFG          Badakhshan      AFG         346
# 1    2022-0264-AFG             Badghis      AFG         354
# 2    2022-0264-AFG             Baghlan      AFG         351
# 3    2022-0264-AFG              Bamyan      AFG         355
# 4    2022-0514-AFG               Farah      AFG         513
# ..             ...                 ...      ...         ...
# 891  2022-0569-ZWE          Manicaland      ZWE         563
# 892  2023-0719-ZWE            Masvingo      ZWE        1512
# 893  2022-0569-ZWE            Masvingo      ZWE         562
# 894  2023-0719-ZWE  Matabeleland South      ZWE        1511
# 895  2022-0569-ZWE            Midlands      ZWE         567
#
#            match_string  match_score  df_right_id  ADM0_CODE    ADM0_NAME  \
# 0            Badakhshan        100.0        516.0        1.0  Afghanistan
# 1               Badghis        100.0        517.0        1.0  Afghanistan
# 2               Baghlan        100.0        518.0        1.0  Afghanistan
# 3                Bamyan        100.0        520.0        1.0  Afghanistan
# 4                 Farah        100.0        521.0        1.0  Afghanistan
# ..                  ...          ...          ...        ...          ...
# 891          Manicaland        100.0        134.0      271.0     Zimbabwe
# 892            Masvingo        100.0        137.0      271.0     Zimbabwe
# 893            Masvingo        100.0        137.0      271.0     Zimbabwe
# 894  Matabeleland South        100.0        138.0      271.0     Zimbabwe
# 895            Midlands        100.0        139.0      271.0     Zimbabwe
#
#      ADM1_CODE  ... DISP_AREA EXP1_YEAR        STATUS STR1_YEAR  Shape_Area  \
# 0        272.0  ...        NO    3000.0  Member State    1000.0    4.398368
# 1        273.0  ...        NO    3000.0  Member State    1000.0    2.038149
# 2        274.0  ...        NO    3000.0  Member State    1000.0    1.776595
# 3        276.0  ...        NO    3000.0  Member State    1000.0    1.762777
# 4        277.0  ...        NO    3000.0  Member State    1000.0    4.718270
# ..         ...  ...       ...       ...           ...       ...         ...
# 891     3437.0  ...        NO    3000.0  Member State    1000.0    3.062811
# 892     3441.0  ...        NO    3000.0  Member State    1000.0    4.898562
# 893     3441.0  ...        NO    3000.0  Member State    1000.0    4.898562
# 894     3443.0  ...        NO    3000.0  Member State    1000.0    4.720131
# 895     3444.0  ...        NO    3000.0  Member State    1000.0    4.231023
#
#      Shape_Leng                    official_name iso3_df2  \
# 0     20.784230  Islamic Republic of Afghanistan      AFG
# 1      8.212745  Islamic Republic of Afghanistan      AFG
# 2      7.786293  Islamic Republic of Afghanistan      AFG
# 3      8.587412  Islamic Republic of Afghanistan      AFG
# 4     15.358933  Islamic Republic of Afghanistan      AFG
# ..          ...                              ...      ...
# 891   13.462677             Republic of Zimbabwe      ZWE
# 892   12.419403             Republic of Zimbabwe      ZWE
# 893   12.419403             Republic of Zimbabwe      ZWE
# 894   16.330050             Republic of Zimbabwe      ZWE
# 895   16.425649             Republic of Zimbabwe      ZWE
#
#                                               geometry       name_join_df2
# 0    POLYGON ((69.98554 36.78234, 69.98748 36.78352...          Badakhshan
# 1    POLYGON ((62.66683 34.99415, 62.66690 34.99676...             Badghis
# 2    POLYGON ((68.00412 35.13949, 68.00416 35.14001...             Baghlan
# 3    POLYGON ((66.29666 35.13259, 66.29699 35.13380...              Bamyan
# 4    POLYGON ((60.58315 33.12982, 60.58746 33.13812...               Farah
# ..                                                 ...                 ...
# 891  POLYGON ((31.18835 -19.23481, 31.22039 -19.231...          Manicaland
# 892  POLYGON ((29.73057 -21.02383, 29.73119 -21.024...            Masvingo
# 893  POLYGON ((29.73057 -21.02383, 29.73119 -21.024...            Masvingo
# 894  POLYGON ((26.69159 -19.89356, 26.69162 -19.893...  Matabeleland South
# 895  POLYGON ((27.99733 -18.23833, 27.99745 -18.238...            Midlands
#
# [896 rows x 21 columns]

# %% [markdown]
# #consider only geometries where the location string exists in the geometry string name of the gaul object
# #events_admin1_locations_only_valid = locations_only_events_admin1[locations_only_events_admin1.apply(lambda x: x['name_join_df2'] in x['name_join_df1'], axis=1)]

# %%
events_admin1_locations_only_valid = locations_only_events_admin1[locations_only_events_admin1.match_score >= 90]

# %%
events_admin1_locations_only_valid
# Out:
#             DisNo.       name_join_df1 iso3_df1  df_left_id  \
# 0    2022-0264-AFG          Badakhshan      AFG         346
# 1    2022-0264-AFG             Badghis      AFG         354
# 2    2022-0264-AFG             Baghlan      AFG         351
# 3    2022-0264-AFG              Bamyan      AFG         355
# 4    2022-0514-AFG               Farah      AFG         513
# ..             ...                 ...      ...         ...
# 891  2022-0569-ZWE          Manicaland      ZWE         563
# 892  2023-0719-ZWE            Masvingo      ZWE        1512
# 893  2022-0569-ZWE            Masvingo      ZWE         562
# 894  2023-0719-ZWE  Matabeleland South      ZWE        1511
# 895  2022-0569-ZWE            Midlands      ZWE         567
#
#            match_string  match_score  df_right_id  ADM0_CODE    ADM0_NAME  \
# 0            Badakhshan        100.0        516.0        1.0  Afghanistan
# 1               Badghis        100.0        517.0        1.0  Afghanistan
# 2               Baghlan        100.0        518.0        1.0  Afghanistan
# 3                Bamyan        100.0        520.0        1.0  Afghanistan
# 4                 Farah        100.0        521.0        1.0  Afghanistan
# ..                  ...          ...          ...        ...          ...
# 891          Manicaland        100.0        134.0      271.0     Zimbabwe
# 892            Masvingo        100.0        137.0      271.0     Zimbabwe
# 893            Masvingo        100.0        137.0      271.0     Zimbabwe
# 894  Matabeleland South        100.0        138.0      271.0     Zimbabwe
# 895            Midlands        100.0        139.0      271.0     Zimbabwe
#
#      ADM1_CODE  ... DISP_AREA EXP1_YEAR        STATUS STR1_YEAR  Shape_Area  \
# 0        272.0  ...        NO    3000.0  Member State    1000.0    4.398368
# 1        273.0  ...        NO    3000.0  Member State    1000.0    2.038149
# 2        274.0  ...        NO    3000.0  Member State    1000.0    1.776595
# 3        276.0  ...        NO    3000.0  Member State    1000.0    1.762777
# 4        277.0  ...        NO    3000.0  Member State    1000.0    4.718270
# ..         ...  ...       ...       ...           ...       ...         ...
# 891     3437.0  ...        NO    3000.0  Member State    1000.0    3.062811
# 892     3441.0  ...        NO    3000.0  Member State    1000.0    4.898562
# 893     3441.0  ...        NO    3000.0  Member State    1000.0    4.898562
# 894     3443.0  ...        NO    3000.0  Member State    1000.0    4.720131
# 895     3444.0  ...        NO    3000.0  Member State    1000.0    4.231023
#
#      Shape_Leng                    official_name iso3_df2  \
# 0     20.784230  Islamic Republic of Afghanistan      AFG
# 1      8.212745  Islamic Republic of Afghanistan      AFG
# 2      7.786293  Islamic Republic of Afghanistan      AFG
# 3      8.587412  Islamic Republic of Afghanistan      AFG
# 4     15.358933  Islamic Republic of Afghanistan      AFG
# ..          ...                              ...      ...
# 891   13.462677             Republic of Zimbabwe      ZWE
# 892   12.419403             Republic of Zimbabwe      ZWE
# 893   12.419403             Republic of Zimbabwe      ZWE
# 894   16.330050             Republic of Zimbabwe      ZWE
# 895   16.425649             Republic of Zimbabwe      ZWE
#
#                                               geometry       name_join_df2
# 0    POLYGON ((69.98554 36.78234, 69.98748 36.78352...          Badakhshan
# 1    POLYGON ((62.66683 34.99415, 62.66690 34.99676...             Badghis
# 2    POLYGON ((68.00412 35.13949, 68.00416 35.14001...             Baghlan
# 3    POLYGON ((66.29666 35.13259, 66.29699 35.13380...              Bamyan
# 4    POLYGON ((60.58315 33.12982, 60.58746 33.13812...               Farah
# ..                                                 ...                 ...
# 891  POLYGON ((31.18835 -19.23481, 31.22039 -19.231...          Manicaland
# 892  POLYGON ((29.73057 -21.02383, 29.73119 -21.024...            Masvingo
# 893  POLYGON ((29.73057 -21.02383, 29.73119 -21.024...            Masvingo
# 894  POLYGON ((26.69159 -19.89356, 26.69162 -19.893...  Matabeleland South
# 895  POLYGON ((27.99733 -18.23833, 27.99745 -18.238...            Midlands
#
# [896 rows x 21 columns]

# %%
events_admin1_locations_only_valid[['name_join_df1','name_join_df2']].iloc[100:150]
# Out:
#              name_join_df1                 name_join_df2
# 100                  Henan                   Henan Sheng
# 101                  Hunan                   Hunan Sheng
# 102                  Hunan                   Hunan Sheng
# 103                  Hunan                   Hunan Sheng
# 104                Jiangsu                 Jiangsu Sheng
# 105                Jiangxi                 Jiangxi Sheng
# 106                Ningxia         Ningxia Huizu Zizhiqu
# 107                QingHai                 Qinghai Sheng
# 108                Qinghai                 Qinghai Sheng
# 109                Qinghai                 Qinghai Sheng
# 110                Shaanxi                 Shaanxi Sheng
# 111                 Shanxi                  Shanxi Sheng
# 112                Sichuan                 Sichuan Sheng
# 113               Xinjiang        Xinjiang Uygur Zizhiqu
# 114                 Yunnan                  Yunnan Sheng
# 115                Abidjan  District autonome de Abidjan
# 116              Northwest                           Est
# 117             South-West                           Est
# 118            Southwest s                           Est
# 119         and Littoral s                      Littoral
# 120         and North-West                           Est
# 121           Haut-Katanga                       Katanga
# 122                  Kasai              Kasai Occidental
# 123               Kinshasa                      Kinshasa
# 124               Kinshasa                      Kinshasa
# 125             Bazzaville                   Brazzaville
# 126                Bouenza                       Bouenza
# 127            Brazzaville                   Brazzaville
# 128                Cuvette                       Cuvette
# 129                Kouilou                       Kouilou
# 130               Likouala                      Likouala
# 131                  Niari                         Niari
# 132                  Niari                         Niari
# 133               Plateaux                      Plateaux
# 134           Pointe-Noire                   Point-Noire
# 135           Pointe-Noire                   Point-Noire
# 136                 Sangha                        Sangha
# 137              Atlantico                     Atlantico
# 138              Atlántico                     Atlantico
# 139                Bolivar                       Bolivar
# 140                 Boyacá                        Boyaca
# 141                  Cauca                         Cauca
# 142             La Guajira                       Guajira
# 143              Magdalena                     Magdalena
# 144  Magdalena departments                     Magdalena
# 145      Narino department                        Narino
# 146                 Nariño                        Narino
# 147     Norte de Santander            Norte De Santander
# 148     Norte de Santander            Norte De Santander
# 149                 Tolima                        Tolima

# %%
events_admin1_locations_only_valid[['name_join_df1','name_join_df2']].iloc[147]
# Out:
# name_join_df1    San Juan Municipalities (Bolivar Department); ...
# name_join_df2                                   Norte De Santander
# Name: 147, dtype: object

# %%
#gaul2['ADM2_NAME_join'] = gaul2[['ADM1_NAME', 'ADM2_NAME']].astype(str).agg('  '.join, axis=1)

# %%
gaul2['ADM2_NAME_join'] = gaul2[['ADM2_NAME']]

# %%
#Administrative level 2
Emdata_locations_only['ADM2_NAME_join'] = Emdata_locations_only['ADM1_NAME']
final_db2 = gpd.GeoDataFrame()#empty geoDF for results

for iso in isos:
    db2 = match_emdat_gdis(Emdata_locations_only, gaul2, iso,"ADM2_NAME_join")
    if db2.empty:
        pass
    else:
        final_db2 = pd.concat([final_db2,db2],axis=0)
        
locations_only_events_admin2 = final_db2[~final_db2['geometry'].isna()].reset_index().drop(columns={'index'})
# Out:
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# ...
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.

# %%
events_admin2_locations_only_valid = locations_only_events_admin2[locations_only_events_admin2.match_score >= 90]

# %%
#consider only geometries where the location string exists in the geometry string name of the gaul object
#events_admin2_locations_only_valid = locations_only_events_admin2[locations_only_events_admin2.apply(lambda x: x['name_join_df2'] in x['name_join_df1'], axis=1)]

# %%
events_admin2_locations_only_valid
# Out:
#             DisNo. ADM1_NAME_df1 iso3_df1 name_join_df1  df_left_id  \
# 0    2022-0264-AFG       Baghlan      AFG       Baghlan         351
# 1    2022-0264-AFG        Bamyan      AFG        Bamyan         355
# 2    2022-0514-AFG         Farah      AFG         Farah         513
# 3    2022-0514-AFG        Ghazni      AFG        Ghazni         506
# 4    2023-0636-AFG         Herat      AFG         Herat        1439
# ..             ...           ...      ...           ...         ...
# 664  2023-0719-ZWE       Mwenezi      ZWE       Mwenezi        1507
# 665  2023-0719-ZWE          Seke      ZWE          Seke        1508
# 666  2023-0719-ZWE        Shamva      ZWE        Shamva        1504
# 667  2023-0719-ZWE         Wedza      ZWE         Wedza        1509
# 668  2023-0719-ZWE         uhera      ZWE         uhera        1493
#
#         match_string  match_score  df_right_id  ADM0_CODE    ADM0_NAME  ...  \
# 0    Baghlan-e-Jadid         90.0      16297.0        1.0  Afghanistan  ...
# 1             Bamyan        100.0      16404.0        1.0  Afghanistan  ...
# 2              Farah        100.0      17376.0        1.0  Afghanistan  ...
# 3             Ghazni        100.0      16352.0        1.0  Afghanistan  ...
# 4              Herat        100.0      17426.0        1.0  Afghanistan  ...
# ..               ...          ...          ...        ...          ...  ...
# 664          Mwenezi        100.0      10422.0      271.0     Zimbabwe  ...
# 665             Seke        100.0       2531.0      271.0     Zimbabwe  ...
# 666           Shamva        100.0       2509.0      271.0     Zimbabwe  ...
# 667           Hwedza         91.0       2526.0      271.0     Zimbabwe  ...
# 668           Buhera         91.0      10413.0      271.0     Zimbabwe  ...
#
#      EXP2_YEAR        STATUS  STR2_YEAR Shape_Area Shape_Leng  \
# 0       3000.0  Member State     2004.0   0.260793   2.642237
# 1       3000.0  Member State     1000.0   0.177110   2.128533
# 2       3000.0  Member State     1000.0   0.326498   3.870752
# 3       3000.0  Member State     1000.0   0.034933   0.988983
# 4       3000.0  Member State     1000.0   0.008094   0.414472
# ..         ...           ...        ...        ...        ...
# 664     3000.0  Member State     1000.0   1.146266   6.310072
# 665     3000.0  Member State     1000.0   0.225164   3.924185
# 666     3000.0  Member State     1000.0   0.228929   3.284518
# 667     3000.0  Member State     1000.0   0.219286   2.792234
# 668     3000.0  Member State     1000.0   0.461110   4.061706
#
#                        official_name iso3_df2  \
# 0    Islamic Republic of Afghanistan      AFG
# 1    Islamic Republic of Afghanistan      AFG
# 2    Islamic Republic of Afghanistan      AFG
# 3    Islamic Republic of Afghanistan      AFG
# 4    Islamic Republic of Afghanistan      AFG
# ..                               ...      ...
# 664             Republic of Zimbabwe      ZWE
# 665             Republic of Zimbabwe      ZWE
# 666             Republic of Zimbabwe      ZWE
# 667             Republic of Zimbabwe      ZWE
# 668             Republic of Zimbabwe      ZWE
#
#                                               geometry   ADM2_NAME_join  \
# 0    POLYGON ((68.53223 36.15923, 68.53070 36.16115...  Baghlan-e-Jadid
# 1    POLYGON ((67.36119 34.80934, 67.36119 34.81523...           Bamyan
# 2    POLYGON ((61.88133 32.30833, 61.88319 32.31950...            Farah
# 3    POLYGON ((68.51923 33.41982, 68.51812 33.41982...           Ghazni
# 4    POLYGON ((62.11880 34.37322, 62.11942 34.37507...            Herat
# ..                                                 ...              ...
# 664  POLYGON ((30.94386 -22.11357, 30.93747 -22.110...          Mwenezi
# 665  POLYGON ((30.76508 -18.50712, 30.76493 -18.504...             Seke
# 666  POLYGON ((31.50866 -17.50133, 31.50852 -17.501...           Shamva
# 667  POLYGON ((31.98308 -19.11863, 31.98306 -19.118...           Hwedza
# 668  POLYGON ((31.18835 -19.23481, 31.22039 -19.231...           Buhera
#
#        name_join_df2
# 0    Baghlan-e-Jadid
# 1             Bamyan
# 2              Farah
# 3             Ghazni
# 4              Herat
# ..               ...
# 664          Mwenezi
# 665             Seke
# 666           Shamva
# 667           Hwedza
# 668           Buhera
#
# [669 rows x 25 columns]

# %%
events_admin2_locations_only_valid[['name_join_df1','name_join_df2']].iloc[300:350]
# Out:
#        name_join_df1        name_join_df2
# 300          Puttlam             Puttalam
# 301      Ratnapura s            Ratnapura
# 302     and Matara s               Matara
# 303           Leribe               Leribe
# 304         Al Haouz             Al Haouz
# 305           Azilal               Azilal
# 306        Chichaoua            Chichaoua
# 307          Guelmim              Guelmim
# 308        Marrakech            Marrakech
# 309       Ouarzazate           Ouarzazate
# 310            Rabat                Rabat
# 311             Taza                 Taza
# 312      Grigoriopol          Grigoriopol
# 313     Antananarivo       Antananarivo I
# 314           Chalco               Chalco
# 315    Ciudad Juarez               Juarez
# 316  Lagos de Moreno      Lagos De Moreno
# 317           Mexico                 Xico
# 318           Mexico                 Xico
# 319           Puebla               Puebla
# 320          Sinaloa              Sinaloa
# 321         Veracruz             Veracruz
# 322           Tetovo               Tetovo
# 323             Bago                 Bago
# 324             Bago                 Bago
# 325         Mandalay             Mandalay
# 326              Mon            Monghpyak
# 327           Yangon            Yangon(E)
# 328      Bayan-Ölgii                Bayan
# 329      Bayan-Ölgii                Bayan
# 330      Bayanhongor          Bayanxongor
# 331      Bayanhongor          Bayanxongor
# 332           Bulgan               Bulgan
# 333           Bulgan               Bulgan
# 334       Govi-Altai                Altai
# 335       Govi-Altai                Altai
# 336       Govi-Altai                Altai
# 337          Selenge              Selenge
# 338        Selenge s              Selenge
# 339            Beira      Cidade da Beira
# 340        Inhambane  Cidade de Inhambane
# 341           Manica               Manica
# 342           Maputo     Cidade de Maputo
# 343          Nampula              Nampula
# 344           Niassa          Lago niassa
# 345             Tete       Cidade de Tete
# 346             Tete       Cidade de Tete
# 347           Balaka               Balaka
# 348           Balaka               Balaka
# 349           Balaka               Balaka

# %%
# Merge the two DataFrames based on the columns 'name_join_df1' and 'DisNo.'
merged_df = pd.merge(events_admin2_locations_only_valid,
                     events_admin1_locations_only_valid,
                     on=['name_join_df1', 'DisNo.'],
                     how='left',
                     suffixes=('', '_right'),
                     indicator=True)

# Keep only the rows from events_admin2_locations_only_valid that are not present in events_admin1_locations_only_valid
events_admin2_locations_only_valid = merged_df.loc[merged_df['_merge'] == 'left_only', events_admin2_locations_only_valid.columns]

# %%
events_admin2_locations_only_valid
# Out:
#             DisNo. ADM1_NAME_df1 iso3_df1 name_join_df1  df_left_id  \
# 4    2023-0636-AFG         Herat      AFG         Herat        1439
# 5    2022-0264-AFG         Herat      AFG         Herat         345
# 12   2022-0806-AFG        Salang      AFG        Salang         717
# 21   2023-0644-BEN    Seme Podji      BEN    Seme Podji        1443
# 22   2023-0512-BGD     Bandarban      BGD     Bandarban        1298
# ..             ...           ...      ...           ...         ...
# 668  2023-0719-ZWE       Mwenezi      ZWE       Mwenezi        1507
# 669  2023-0719-ZWE          Seke      ZWE          Seke        1508
# 670  2023-0719-ZWE        Shamva      ZWE        Shamva        1504
# 671  2023-0719-ZWE         Wedza      ZWE         Wedza        1509
# 672  2023-0719-ZWE         uhera      ZWE         uhera        1493
#
#     match_string  match_score  df_right_id  ADM0_CODE    ADM0_NAME  ...  \
# 4          Herat        100.0      17426.0        1.0  Afghanistan  ...
# 5          Herat        100.0      17426.0        1.0  Afghanistan  ...
# 12        Salang        100.0      16455.0        1.0  Afghanistan  ...
# 21   Seme-kpodji         95.0       2595.0       29.0        Benin  ...
# 22     Bandarban        100.0      15729.0       23.0   Bangladesh  ...
# ..           ...          ...          ...        ...          ...  ...
# 668      Mwenezi        100.0      10422.0      271.0     Zimbabwe  ...
# 669         Seke        100.0       2531.0      271.0     Zimbabwe  ...
# 670       Shamva        100.0       2509.0      271.0     Zimbabwe  ...
# 671       Hwedza         91.0       2526.0      271.0     Zimbabwe  ...
# 672       Buhera         91.0      10413.0      271.0     Zimbabwe  ...
#
#      EXP2_YEAR        STATUS  STR2_YEAR Shape_Area Shape_Leng  \
# 4       3000.0  Member State     1000.0   0.008094   0.414472
# 5       3000.0  Member State     1000.0   0.008094   0.414472
# 12      3000.0  Member State     1000.0   0.051562   1.139820
# 21      3000.0  Member State     1000.0   0.015388   0.736261
# 22      3000.0  Member State     1000.0   0.403544   5.417817
# ..         ...           ...        ...        ...        ...
# 668     3000.0  Member State     1000.0   1.146266   6.310072
# 669     3000.0  Member State     1000.0   0.225164   3.924185
# 670     3000.0  Member State     1000.0   0.228929   3.284518
# 671     3000.0  Member State     1000.0   0.219286   2.792234
# 672     3000.0  Member State     1000.0   0.461110   4.061706
#
#                        official_name iso3_df2  \
# 4    Islamic Republic of Afghanistan      AFG
# 5    Islamic Republic of Afghanistan      AFG
# 12   Islamic Republic of Afghanistan      AFG
# 21                 Republic of Benin      BEN
# 22   People's Republic of Bangladesh      BGD
# ..                               ...      ...
# 668             Republic of Zimbabwe      ZWE
# 669             Republic of Zimbabwe      ZWE
# 670             Republic of Zimbabwe      ZWE
# 671             Republic of Zimbabwe      ZWE
# 672             Republic of Zimbabwe      ZWE
#
#                                               geometry  ADM2_NAME_join  \
# 4    POLYGON ((62.11880 34.37322, 62.11942 34.37507...           Herat
# 5    POLYGON ((62.11880 34.37322, 62.11942 34.37507...           Herat
# 12   POLYGON ((69.24382 35.16703, 69.24326 35.16527...          Salang
# 21   POLYGON ((2.49788 6.36010, 2.49787 6.36097, 2....     Seme-kpodji
# 22   POLYGON ((92.05993 21.90284, 92.05996 21.90319...       Bandarban
# ..                                                 ...             ...
# 668  POLYGON ((30.94386 -22.11357, 30.93747 -22.110...         Mwenezi
# 669  POLYGON ((30.76508 -18.50712, 30.76493 -18.504...            Seke
# 670  POLYGON ((31.50866 -17.50133, 31.50852 -17.501...          Shamva
# 671  POLYGON ((31.98308 -19.11863, 31.98306 -19.118...          Hwedza
# 672  POLYGON ((31.18835 -19.23481, 31.22039 -19.231...          Buhera
#
#      name_join_df2
# 4            Herat
# 5            Herat
# 12          Salang
# 21     Seme-kpodji
# 22       Bandarban
# ..             ...
# 668        Mwenezi
# 669           Seke
# 670         Shamva
# 671         Hwedza
# 672         Buhera
#
# [291 rows x 25 columns]

# %%
#for dataset with bracket , repeating the same process , but only in admin 2


Emdata_locations_only = new_df_2[['DisNo.','Appended']]

Emdata_locations_only.reset_index(drop=True, inplace=True)


iso_locations = Emdata_locations_only['DisNo.'].str.split('-',expand=True)[2]
Emdata_locations_only['iso3'] = iso_locations #add iso3 codes of every location/ event
# Out:
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.

# %%
isos = np.unique(Emdata_locations_only["iso3"])#iso codes for the loop
final_db = gpd.GeoDataFrame()#empty geoDF for results

Emdata_locations_only = Emdata_locations_only.rename(columns={'Appended':"ADM1_NAME"})#change name of column to merge on

for iso in isos:
    db = match_emdat_gdis(Emdata_locations_only, gaul1, iso,"ADM1_NAME")
    if db.empty:
        pass
    else:
        final_db = pd.concat([final_db,db],axis=0)
        
locations_only_events_admin1 = final_db[~final_db['geometry'].isna()].reset_index().drop(columns={'index'})
# Out:
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.

# %%
events_admin1_locations_only_valid1 = locations_only_events_admin1[locations_only_events_admin1.match_score >= 90]

# %%
events_admin1_locations_only_valid1
# Out:
#             DisNo.                    name_join_df1 iso3_df1  df_left_id  \
# 0    2022-0514-AFG                Shenwari s Parwan      AFG         224
# 1    2022-0514-AFG                   Siagard Parwan      AFG         223
# 2    2023-0831-ARG        Bahía Blanca Buenos Aires      ARG         812
# 3    2023-0831-ARG       Moreno Cities Buenos Aires      ARG         813
# 4    2023-0138-AUS              northern Queensland      AUS         421
# ..             ...                              ...      ...         ...
# 435  2022-0052-ZWE          Masvingo rural Masvingo      ZWE          63
# 436  2022-0052-ZWE           Mudzi Mashonaland East      ZWE          61
# 437  2022-0052-ZWE                Mutasa Manicaland      ZWE          65
# 438  2022-0052-ZWE  Muzarabani tMashonaland Central      ZWE          60
# 439  2022-0052-ZWE              Nyanga s Manicaland      ZWE          68
#
#             match_string  match_score  df_right_id  ADM0_CODE    ADM0_NAME  \
# 0                 Parwan         90.0        514.0        1.0  Afghanistan
# 1                 Parwan         90.0        514.0        1.0  Afghanistan
# 2           Buenos Aires         90.0       3351.0       12.0    Argentina
# 3           Buenos Aires         90.0       3351.0       12.0    Argentina
# 4             Queensland         90.0       2883.0       17.0    Australia
# ..                   ...          ...          ...        ...          ...
# 435             Masvingo         90.0        137.0      271.0     Zimbabwe
# 436     Mashonaland East         95.0         35.0      271.0     Zimbabwe
# 437           Manicaland         90.0        134.0      271.0     Zimbabwe
# 438  Mashonaland Central         90.0        135.0      271.0     Zimbabwe
# 439           Manicaland         90.0        134.0      271.0     Zimbabwe
#
#      ADM1_CODE  ... DISP_AREA EXP1_YEAR        STATUS STR1_YEAR  Shape_Area  \
# 0      99880.0  ...        NO    3000.0  Member State    2004.0    0.552083
# 1      99880.0  ...        NO    3000.0  Member State    2004.0    0.552083
# 2        429.0  ...        NO    3000.0  Member State    1000.0   30.833566
# 3        429.0  ...        NO    3000.0  Member State    1000.0   30.833566
# 4        473.0  ...        NO    3000.0  Member State    1000.0  152.276773
# ..         ...  ...       ...       ...           ...       ...         ...
# 435     3441.0  ...        NO    3000.0  Member State    1000.0    4.898562
# 436    69550.0  ...        NO    3000.0  Member State    1997.0    2.736920
# 437     3437.0  ...        NO    3000.0  Member State    1000.0    3.062811
# 438     3438.0  ...        NO    3000.0  Member State    1000.0    2.382755
# 439     3437.0  ...        NO    3000.0  Member State    1000.0    3.062811
#
#      Shape_Leng                    official_name iso3_df2  \
# 0      5.265414  Islamic Republic of Afghanistan      AFG
# 1      5.265414  Islamic Republic of Afghanistan      AFG
# 2     64.151403               Argentine Republic      ARG
# 3     64.151403               Argentine Republic      ARG
# 4    150.144387                        Australia      AUS
# ..          ...                              ...      ...
# 435   12.419403             Republic of Zimbabwe      ZWE
# 436   12.574162             Republic of Zimbabwe      ZWE
# 437   13.462677             Republic of Zimbabwe      ZWE
# 438   10.800846             Republic of Zimbabwe      ZWE
# 439   13.462677             Republic of Zimbabwe      ZWE
#
#                                               geometry        name_join_df2
# 0    POLYGON ((68.18910 35.01769, 68.18911 35.01787...               Parwan
# 1    POLYGON ((68.18910 35.01769, 68.18911 35.01787...               Parwan
# 2    MULTIPOLYGON (((-62.73597 -41.04164, -62.73970...         Buenos Aires
# 3    MULTIPOLYGON (((-62.73597 -41.04164, -62.73970...         Buenos Aires
# 4    MULTIPOLYGON (((139.55596 -17.11589, 139.55796...           Queensland
# ..                                                 ...                  ...
# 435  POLYGON ((29.73057 -21.02383, 29.73119 -21.024...             Masvingo
# 436  POLYGON ((30.55430 -18.92903, 30.55430 -18.928...     Mashonaland East
# 437  POLYGON ((31.18835 -19.23481, 31.22039 -19.231...           Manicaland
# 438  POLYGON ((30.04615 -16.00357, 30.04615 -16.003...  Mashonaland Central
# 439  POLYGON ((31.18835 -19.23481, 31.22039 -19.231...           Manicaland
#
# [440 rows x 21 columns]

# %%
gaul2['ADM2_NAME_join'] = gaul2[['ADM1_NAME', 'ADM2_NAME']].astype(str).agg('  '.join, axis=1)

# %%
Emdata_locations_only['ADM2_NAME_join'] = Emdata_locations_only['ADM1_NAME']
final_db2 = gpd.GeoDataFrame()#empty geoDF for results

for iso in isos:
    db2 = match_emdat_gdis(Emdata_locations_only, gaul2, iso,"ADM2_NAME_join")
    if db2.empty:
        pass
    else:
        final_db2 = pd.concat([final_db2,db2],axis=0)
        
locations_only_events_admin2 = final_db2[~final_db2['geometry'].isna()].reset_index().drop(columns={'index'})
# Out:
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.

# %%
events_admin2_locations_only_valid1 = locations_only_events_admin2[locations_only_events_admin2.match_score >= 90]

# %%
events_admin2_locations_only_valid1
# Out:
#             DisNo.                  ADM1_NAME_df1 iso3_df1  \
# 0    2023-0831-ARG      Bahía Blanca Buenos Aires      ARG
# 1    2023-0831-ARG     Moreno Cities Buenos Aires      ARG
# 2    2023-0828-AUS              Cairns Queensland      AUS
# 3    2023-0138-AUS  Doomadgee northern Queensland      AUS
# 4    2023-0828-AUS           Hope Vale Queensland      AUS
# ..             ...                            ...      ...
# 219  2022-0052-ZWE        Kariba Mashonaland West      ZWE
# 220  2022-0052-ZWE        Masvingo rural Masvingo      ZWE
# 221  2022-0052-ZWE         Mudzi Mashonaland East      ZWE
# 222  2022-0052-ZWE              Mutasa Manicaland      ZWE
# 223  2022-0052-ZWE            Nyanga s Manicaland      ZWE
#
#                      name_join_df1  df_left_id                match_string  \
# 0        Bahía Blanca Buenos Aires         812  Buenos Aires  Bahia Blanca
# 1       Moreno Cities Buenos Aires         813        Buenos Aires  Moreno
# 2                Cairns Queensland         806      Queensland  Cairns (R)
# 3    Doomadgee northern Queensland         420   Queensland  Doomadgee (S)
# 4             Hope Vale Queensland         811   Queensland  Hope Vale (S)
# ..                             ...         ...                         ...
# 219        Kariba Mashonaland West          58    Mashonaland West  Kariba
# 220        Masvingo rural Masvingo          63          Masvingo  Masvingo
# 221         Mudzi Mashonaland East          61     Mashonaland East  Mudzi
# 222              Mutasa Manicaland          65          Manicaland  Mutasa
# 223            Nyanga s Manicaland          68          Manicaland  Nyanga
#
#      match_score  df_right_id  ADM0_CODE  ADM0_NAME  ...  EXP2_YEAR  \
# 0           93.0      37751.0       12.0  Argentina  ...     3000.0
# 1           95.0      37817.0       12.0  Argentina  ...     3000.0
# 2           95.0      24857.0       17.0  Australia  ...     3000.0
# 3           90.0      24862.0       17.0  Australia  ...     3000.0
# 4           95.0      24864.0       17.0  Australia  ...     3000.0
# ..           ...          ...        ...        ...  ...        ...
# 219         95.0       2513.0      271.0   Zimbabwe  ...     3000.0
# 220         95.0      10421.0      271.0   Zimbabwe  ...     3000.0
# 221         95.0       2528.0      271.0   Zimbabwe  ...     3000.0
# 222         95.0       2502.0      271.0   Zimbabwe  ...     3000.0
# 223         95.0       2503.0      271.0   Zimbabwe  ...     3000.0
#
#            STATUS  STR2_YEAR Shape_Area Shape_Leng         official_name  \
# 0    Member State     1000.0   0.232311   3.292568    Argentine Republic
# 1    Member State     1000.0   0.018316   0.602528    Argentine Republic
# 2    Member State     2011.0   0.348500   6.728153             Australia
# 3    Member State     2011.0   0.156206   2.406009             Australia
# 4    Member State     2011.0   0.092905   2.955616             Australia
# ..            ...        ...        ...        ...                   ...
# 219  Member State     1000.0   0.691808   4.535196  Republic of Zimbabwe
# 220  Member State     1000.0   0.598281   5.458565  Republic of Zimbabwe
# 221  Member State     1000.0   0.354802   3.043542  Republic of Zimbabwe
# 222  Member State     1000.0   0.212884   3.362333  Republic of Zimbabwe
# 223  Member State     1000.0   0.489853   4.150860  Republic of Zimbabwe
#
#     iso3_df2                                           geometry  \
# 0        ARG  MULTIPOLYGON (((-62.42643 -38.75657, -62.42643...
# 1        ARG  POLYGON ((-58.86567 -34.68238, -58.88124 -34.6...
# 2        AUS  MULTIPOLYGON (((145.69512 -16.73106, 145.69528...
# 3        AUS  MULTIPOLYGON (((138.58381 -17.87517, 138.58594...
# 4        AUS  POLYGON ((145.23842 -15.44147, 145.21484 -15.4...
# ..       ...                                                ...
# 219      ZWE  POLYGON ((28.01492 -16.87896, 28.01525 -16.878...
# 220      ZWE  POLYGON ((31.40310 -20.00350, 31.39930 -20.009...
# 221      ZWE  POLYGON ((32.99403 -17.24688, 32.99388 -17.246...
# 222      ZWE  POLYGON ((32.48668 -18.76334, 32.48670 -18.762...
# 223      ZWE  POLYGON ((32.44579 -18.40057, 32.44188 -18.380...
#
#                  ADM2_NAME_join               name_join_df2
# 0    Buenos Aires  Bahia Blanca  Buenos Aires  Bahia Blanca
# 1          Buenos Aires  Moreno        Buenos Aires  Moreno
# 2        Queensland  Cairns (R)      Queensland  Cairns (R)
# 3     Queensland  Doomadgee (S)   Queensland  Doomadgee (S)
# 4     Queensland  Hope Vale (S)   Queensland  Hope Vale (S)
# ..                          ...                         ...
# 219    Mashonaland West  Kariba    Mashonaland West  Kariba
# 220          Masvingo  Masvingo          Masvingo  Masvingo
# 221     Mashonaland East  Mudzi     Mashonaland East  Mudzi
# 222          Manicaland  Mutasa          Manicaland  Mutasa
# 223          Manicaland  Nyanga          Manicaland  Nyanga
#
# [224 rows x 25 columns]

# %%
events_admin2_locations_only_valid = pd.concat([events_admin2_locations_only_valid1, events_admin2_locations_only_valid])

# %%
events_admin2_locations_only_valid
# Out:
#             DisNo.                  ADM1_NAME_df1 iso3_df1  \
# 0    2023-0831-ARG      Bahía Blanca Buenos Aires      ARG
# 1    2023-0831-ARG     Moreno Cities Buenos Aires      ARG
# 2    2023-0828-AUS              Cairns Queensland      AUS
# 3    2023-0138-AUS  Doomadgee northern Queensland      AUS
# 4    2023-0828-AUS           Hope Vale Queensland      AUS
# ..             ...                            ...      ...
# 668  2023-0719-ZWE                        Mwenezi      ZWE
# 669  2023-0719-ZWE                           Seke      ZWE
# 670  2023-0719-ZWE                         Shamva      ZWE
# 671  2023-0719-ZWE                          Wedza      ZWE
# 672  2023-0719-ZWE                          uhera      ZWE
#
#                      name_join_df1  df_left_id                match_string  \
# 0        Bahía Blanca Buenos Aires         812  Buenos Aires  Bahia Blanca
# 1       Moreno Cities Buenos Aires         813        Buenos Aires  Moreno
# 2                Cairns Queensland         806      Queensland  Cairns (R)
# 3    Doomadgee northern Queensland         420   Queensland  Doomadgee (S)
# 4             Hope Vale Queensland         811   Queensland  Hope Vale (S)
# ..                             ...         ...                         ...
# 668                        Mwenezi        1507                     Mwenezi
# 669                           Seke        1508                        Seke
# 670                         Shamva        1504                      Shamva
# 671                          Wedza        1509                      Hwedza
# 672                          uhera        1493                      Buhera
#
#      match_score  df_right_id  ADM0_CODE  ADM0_NAME  ...  EXP2_YEAR  \
# 0           93.0      37751.0       12.0  Argentina  ...     3000.0
# 1           95.0      37817.0       12.0  Argentina  ...     3000.0
# 2           95.0      24857.0       17.0  Australia  ...     3000.0
# 3           90.0      24862.0       17.0  Australia  ...     3000.0
# 4           95.0      24864.0       17.0  Australia  ...     3000.0
# ..           ...          ...        ...        ...  ...        ...
# 668        100.0      10422.0      271.0   Zimbabwe  ...     3000.0
# 669        100.0       2531.0      271.0   Zimbabwe  ...     3000.0
# 670        100.0       2509.0      271.0   Zimbabwe  ...     3000.0
# 671         91.0       2526.0      271.0   Zimbabwe  ...     3000.0
# 672         91.0      10413.0      271.0   Zimbabwe  ...     3000.0
#
#            STATUS  STR2_YEAR Shape_Area Shape_Leng         official_name  \
# 0    Member State     1000.0   0.232311   3.292568    Argentine Republic
# 1    Member State     1000.0   0.018316   0.602528    Argentine Republic
# 2    Member State     2011.0   0.348500   6.728153             Australia
# 3    Member State     2011.0   0.156206   2.406009             Australia
# 4    Member State     2011.0   0.092905   2.955616             Australia
# ..            ...        ...        ...        ...                   ...
# 668  Member State     1000.0   1.146266   6.310072  Republic of Zimbabwe
# 669  Member State     1000.0   0.225164   3.924185  Republic of Zimbabwe
# 670  Member State     1000.0   0.228929   3.284518  Republic of Zimbabwe
# 671  Member State     1000.0   0.219286   2.792234  Republic of Zimbabwe
# 672  Member State     1000.0   0.461110   4.061706  Republic of Zimbabwe
#
#     iso3_df2                                           geometry  \
# 0        ARG  MULTIPOLYGON (((-62.42643 -38.75657, -62.42643...
# 1        ARG  POLYGON ((-58.86567 -34.68238, -58.88124 -34.6...
# 2        AUS  MULTIPOLYGON (((145.69512 -16.73106, 145.69528...
# 3        AUS  MULTIPOLYGON (((138.58381 -17.87517, 138.58594...
# 4        AUS  POLYGON ((145.23842 -15.44147, 145.21484 -15.4...
# ..       ...                                                ...
# 668      ZWE  POLYGON ((30.94386 -22.11357, 30.93747 -22.110...
# 669      ZWE  POLYGON ((30.76508 -18.50712, 30.76493 -18.504...
# 670      ZWE  POLYGON ((31.50866 -17.50133, 31.50852 -17.501...
# 671      ZWE  POLYGON ((31.98308 -19.11863, 31.98306 -19.118...
# 672      ZWE  POLYGON ((31.18835 -19.23481, 31.22039 -19.231...
#
#                  ADM2_NAME_join               name_join_df2
# 0    Buenos Aires  Bahia Blanca  Buenos Aires  Bahia Blanca
# 1          Buenos Aires  Moreno        Buenos Aires  Moreno
# 2        Queensland  Cairns (R)      Queensland  Cairns (R)
# 3     Queensland  Doomadgee (S)   Queensland  Doomadgee (S)
# 4     Queensland  Hope Vale (S)   Queensland  Hope Vale (S)
# ..                          ...                         ...
# 668                     Mwenezi                     Mwenezi
# 669                        Seke                        Seke
# 670                      Shamva                      Shamva
# 671                      Hwedza                      Hwedza
# 672                      Buhera                      Buhera
#
# [515 rows x 25 columns]

# %% [markdown]
# ### shape geodataframe to match GDIS database

# %%
####Shape all geodataframes and set same columns

events_adm1_clean = events_adm1[['DisNo.','iso3','official_name','ADM0_CODE','ADM0_NAME','ADM1_CODE','ADM1_NAME','location', 'geolocation','geometry']]
events_adm1_clean[['ADM2_CODE','ADM2_NAME']] = "None"
events_adm1_clean[['level']] = 1

events_adm2_clean = events_adm2[['DisNo.','iso3','official_name','ADM0_CODE','ADM0_NAME','ADM1_CODE','ADM1_NAME','ADM2_CODE','ADM2_NAME','location', 'geolocation','geometry']]
events_adm2_clean[['level']] = 2

events_adm1_loconly_clean = events_admin1_locations_only_valid.reset_index()[['DisNo.','iso3_df1','official_name','ADM0_CODE','ADM0_NAME','ADM1_CODE','ADM1_NAME','match_string','geometry']]
events_adm1_loconly_clean = events_adm1_loconly_clean.rename(columns={'iso3_df1':'iso3','match_string':'location'})
events_adm1_loconly_clean[['ADM2_CODE','ADM2_NAME','geolocation']] = "None"
events_adm1_loconly_clean[['level']] = 1

events_adm2_loconly_clean = events_admin2_locations_only_valid.reset_index()[['DisNo.','iso3_df1','official_name','ADM0_CODE','ADM0_NAME','ADM1_CODE','ADM1_NAME_df1','ADM2_CODE','ADM2_NAME','match_string','geometry']]
events_adm2_loconly_clean = events_adm2_loconly_clean.rename(columns={'iso3_df1':'iso3','match_string':'location'})
events_adm2_loconly_clean[['geolocation']] = "None"
events_adm2_loconly_clean[['level']] = 2
# Out:
# /net/home/dchinthaparthy/.conda/envs/agg_env/lib/python3.7/site-packages/pandas/core/frame.py:3645: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[col] = value

# %%
events_adm1_loconly_clean
# Out:
#             DisNo. iso3                    official_name  ADM0_CODE  \
# 0    2022-0264-AFG  AFG  Islamic Republic of Afghanistan        1.0
# 1    2022-0264-AFG  AFG  Islamic Republic of Afghanistan        1.0
# 2    2022-0264-AFG  AFG  Islamic Republic of Afghanistan        1.0
# 3    2022-0264-AFG  AFG  Islamic Republic of Afghanistan        1.0
# 4    2022-0514-AFG  AFG  Islamic Republic of Afghanistan        1.0
# ..             ...  ...                              ...        ...
# 891  2022-0569-ZWE  ZWE             Republic of Zimbabwe      271.0
# 892  2023-0719-ZWE  ZWE             Republic of Zimbabwe      271.0
# 893  2022-0569-ZWE  ZWE             Republic of Zimbabwe      271.0
# 894  2023-0719-ZWE  ZWE             Republic of Zimbabwe      271.0
# 895  2022-0569-ZWE  ZWE             Republic of Zimbabwe      271.0
#
#        ADM0_NAME  ADM1_CODE           ADM1_NAME            location  \
# 0    Afghanistan      272.0          Badakhshan          Badakhshan
# 1    Afghanistan      273.0             Badghis             Badghis
# 2    Afghanistan      274.0             Baghlan             Baghlan
# 3    Afghanistan      276.0              Bamyan              Bamyan
# 4    Afghanistan      277.0               Farah               Farah
# ..           ...        ...                 ...                 ...
# 891     Zimbabwe     3437.0          Manicaland          Manicaland
# 892     Zimbabwe     3441.0            Masvingo            Masvingo
# 893     Zimbabwe     3441.0            Masvingo            Masvingo
# 894     Zimbabwe     3443.0  Matabeleland South  Matabeleland South
# 895     Zimbabwe     3444.0            Midlands            Midlands
#
#                                               geometry ADM2_CODE ADM2_NAME  \
# 0    POLYGON ((69.98554 36.78234, 69.98748 36.78352...      None      None
# 1    POLYGON ((62.66683 34.99415, 62.66690 34.99676...      None      None
# 2    POLYGON ((68.00412 35.13949, 68.00416 35.14001...      None      None
# 3    POLYGON ((66.29666 35.13259, 66.29699 35.13380...      None      None
# 4    POLYGON ((60.58315 33.12982, 60.58746 33.13812...      None      None
# ..                                                 ...       ...       ...
# 891  POLYGON ((31.18835 -19.23481, 31.22039 -19.231...      None      None
# 892  POLYGON ((29.73057 -21.02383, 29.73119 -21.024...      None      None
# 893  POLYGON ((29.73057 -21.02383, 29.73119 -21.024...      None      None
# 894  POLYGON ((26.69159 -19.89356, 26.69162 -19.893...      None      None
# 895  POLYGON ((27.99733 -18.23833, 27.99745 -18.238...      None      None
#
#     geolocation  level
# 0          None      1
# 1          None      1
# 2          None      1
# 3          None      1
# 4          None      1
# ..          ...    ...
# 891        None      1
# 892        None      1
# 893        None      1
# 894        None      1
# 895        None      1
#
# [896 rows x 13 columns]

# %%
events_adm2_loconly_clean
# Out:
#             DisNo. iso3         official_name  ADM0_CODE  ADM0_NAME  \
# 0    2023-0831-ARG  ARG    Argentine Republic       12.0  Argentina
# 1    2023-0831-ARG  ARG    Argentine Republic       12.0  Argentina
# 2    2023-0828-AUS  AUS             Australia       17.0  Australia
# 3    2023-0138-AUS  AUS             Australia       17.0  Australia
# 4    2023-0828-AUS  AUS             Australia       17.0  Australia
# ..             ...  ...                   ...        ...        ...
# 510  2023-0719-ZWE  ZWE  Republic of Zimbabwe      271.0   Zimbabwe
# 511  2023-0719-ZWE  ZWE  Republic of Zimbabwe      271.0   Zimbabwe
# 512  2023-0719-ZWE  ZWE  Republic of Zimbabwe      271.0   Zimbabwe
# 513  2023-0719-ZWE  ZWE  Republic of Zimbabwe      271.0   Zimbabwe
# 514  2023-0719-ZWE  ZWE  Republic of Zimbabwe      271.0   Zimbabwe
#
#      ADM1_CODE                  ADM1_NAME_df1  ADM2_CODE      ADM2_NAME  \
# 0        429.0      Bahía Blanca Buenos Aires     4389.0   Bahia Blanca
# 1        429.0     Moreno Cities Buenos Aires     4462.0         Moreno
# 2        473.0              Cairns Queensland   154657.0     Cairns (R)
# 3        473.0  Doomadgee northern Queensland   154664.0  Doomadgee (S)
# 4        473.0           Hope Vale Queensland   154671.0  Hope Vale (S)
# ..         ...                            ...        ...            ...
# 510     3441.0                        Mwenezi    33086.0        Mwenezi
# 511    69550.0                           Seke    33073.0           Seke
# 512     3438.0                         Shamva    33066.0         Shamva
# 513    69550.0                          Wedza    33068.0         Hwedza
# 514     3437.0                          uhera    33053.0         Buhera
#
#                        location  \
# 0    Buenos Aires  Bahia Blanca
# 1          Buenos Aires  Moreno
# 2        Queensland  Cairns (R)
# 3     Queensland  Doomadgee (S)
# 4     Queensland  Hope Vale (S)
# ..                          ...
# 510                     Mwenezi
# 511                        Seke
# 512                      Shamva
# 513                      Hwedza
# 514                      Buhera
#
#                                               geometry geolocation  level
# 0    MULTIPOLYGON (((-62.42643 -38.75657, -62.42643...        None      2
# 1    POLYGON ((-58.86567 -34.68238, -58.88124 -34.6...        None      2
# 2    MULTIPOLYGON (((145.69512 -16.73106, 145.69528...        None      2
# 3    MULTIPOLYGON (((138.58381 -17.87517, 138.58594...        None      2
# 4    POLYGON ((145.23842 -15.44147, 145.21484 -15.4...        None      2
# ..                                                 ...         ...    ...
# 510  POLYGON ((30.94386 -22.11357, 30.93747 -22.110...        None      2
# 511  POLYGON ((30.76508 -18.50712, 30.76493 -18.504...        None      2
# 512  POLYGON ((31.50866 -17.50133, 31.50852 -17.501...        None      2
# 513  POLYGON ((31.98308 -19.11863, 31.98306 -19.118...        None      2
# 514  POLYGON ((31.18835 -19.23481, 31.22039 -19.231...        None      2
#
# [515 rows x 13 columns]

# %%
new_df

# %%
freq_emdata = new_df['DisNo.'].value_counts()

# Count the frequency of each DisNo. in locations_only_events_admin1
freq_admin1 = events_adm1_loconly_clean['DisNo.'].value_counts()

# Count the frequency of each DisNo. in vents_adm2_loconly_clean
freq_admin2 = events_adm2_loconly_clean['DisNo.'].value_counts()

# Combine the frequencies into a single DataFrame
combined_freq = pd.DataFrame({
    'Emdata': freq_emdata, 
    'Admin1': freq_admin1, 
    'Admin2': freq_admin2
}).fillna(0)

# Calculate the ratio for each DisNo.
combined_freq['Ratio_Admin1'] = combined_freq['Admin1'] / combined_freq['Emdata']
combined_freq['Ratio_Admin2'] = combined_freq['Admin2'] / combined_freq['Emdata']
combined_freq['total_ratio'] =  combined_freq['Ratio_Admin1'] + combined_freq['Ratio_Admin2'] 
# Display the result
print(combined_freq)
# Out:
#                Emdata  Admin1  Admin2  Ratio_Admin1  Ratio_Admin2  total_ratio
# 2020-9609-SOM      17     3.0     1.0      0.176471      0.058824     0.235294
# 2021-0012-BGD       1     0.0     1.0      0.000000      1.000000     1.000000
# 2021-0029-IND       1     0.0     1.0      0.000000      1.000000     1.000000
# 2021-0030-ECU       1     1.0     0.0      1.000000      0.000000     1.000000
# 2021-0032-IDN       1     0.0     0.0      0.000000      0.000000     0.000000
# ...               ...     ...     ...           ...           ...          ...
# 2023-9589-URY       5     5.0     0.0      1.000000      0.000000     1.000000
# 2023-9651-BRA       1     1.0     0.0      1.000000      0.000000     1.000000
# 2023-9706-BOL       5     5.0     0.0      1.000000      0.000000     1.000000
# 2023-9868-USA      10    10.0     0.0      1.000000      0.000000     1.000000
# 2023-9873-FSM       4     0.0     0.0      0.000000      0.000000     0.000000
#
# [835 rows x 6 columns]

# %%
disno_to_remove = combined_freq[combined_freq['total_ratio'] < 0.6].index

# Filter out these DisNo. from events_adm1_loconly_clean and events_adm2_loconly_clean
events_adm1_loconly_clean = events_adm1_loconly_clean[~events_adm1_loconly_clean['DisNo.'].isin(disno_to_remove)].reset_index(drop=True)
events_adm2_loconly_clean = events_adm2_loconly_clean[~events_adm2_loconly_clean['DisNo.'].isin(disno_to_remove)].reset_index(drop=True)

# Display the result
print("Filtered events_adm1_loconly_clean:")
print(events_adm1_loconly_clean)
print("\nFiltered events_adm2_loconly_clean:")
print(events_adm2_loconly_clean)
# Out:
# Filtered events_adm1_loconly_clean:
#             DisNo. iso3                    official_name  ADM0_CODE  \
# 0    2022-0264-AFG  AFG  Islamic Republic of Afghanistan        1.0
# 1    2022-0264-AFG  AFG  Islamic Republic of Afghanistan        1.0
# 2    2022-0264-AFG  AFG  Islamic Republic of Afghanistan        1.0
# 3    2022-0264-AFG  AFG  Islamic Republic of Afghanistan        1.0
# 4    2022-0514-AFG  AFG  Islamic Republic of Afghanistan        1.0
# ..             ...  ...                              ...        ...
# 757  2023-0619-ZAF  ZAF         Republic of South Africa      227.0
# 758  2023-0719-ZWE  ZWE             Republic of Zimbabwe      271.0
# 759  2023-0719-ZWE  ZWE             Republic of Zimbabwe      271.0
# 760  2023-0719-ZWE  ZWE             Republic of Zimbabwe      271.0
# 761  2023-0719-ZWE  ZWE             Republic of Zimbabwe      271.0
#
#         ADM0_NAME  ADM1_CODE           ADM1_NAME            location  \
# 0     Afghanistan      272.0          Badakhshan          Badakhshan
# 1     Afghanistan      273.0             Badghis             Badghis
# 2     Afghanistan      274.0             Baghlan             Baghlan
# 3     Afghanistan      276.0              Bamyan              Bamyan
# 4     Afghanistan      277.0               Farah               Farah
# ..            ...        ...                 ...                 ...
# 757  South Africa     2714.0        Western Cape        Western Cape
# 758      Zimbabwe     3436.0              Harare              Harare
# 759      Zimbabwe     3437.0          Manicaland          Manicaland
# 760      Zimbabwe     3441.0            Masvingo            Masvingo
# 761      Zimbabwe     3443.0  Matabeleland South  Matabeleland South
#
#                                               geometry ADM2_CODE ADM2_NAME  \
# 0    POLYGON ((69.98554 36.78234, 69.98748 36.78352...      None      None
# 1    POLYGON ((62.66683 34.99415, 62.66690 34.99676...      None      None
# 2    POLYGON ((68.00412 35.13949, 68.00416 35.14001...      None      None
# 3    POLYGON ((66.29666 35.13259, 66.29699 35.13380...      None      None
# 4    POLYGON ((60.58315 33.12982, 60.58746 33.13812...      None      None
# ..                                                 ...       ...       ...
# 757  MULTIPOLYGON (((18.32657 -34.05852, 18.32665 -...      None      None
# 758  POLYGON ((30.87746 -17.87537, 30.88088 -17.873...      None      None
# 759  POLYGON ((31.18835 -19.23481, 31.22039 -19.231...      None      None
# 760  POLYGON ((29.73057 -21.02383, 29.73119 -21.024...      None      None
# 761  POLYGON ((26.69159 -19.89356, 26.69162 -19.893...      None      None
#
#     geolocation  level
# 0          None      1
# 1          None      1
# 2          None      1
# 3          None      1
# 4          None      1
# ..          ...    ...
# 757        None      1
# 758        None      1
# 759        None      1
# 760        None      1
# 761        None      1
#
# [762 rows x 13 columns]
#
# Filtered events_adm2_loconly_clean:
#             DisNo. iso3         official_name  ADM0_CODE  ADM0_NAME  \
# 0    2023-0831-ARG  ARG    Argentine Republic       12.0  Argentina
# 1    2023-0831-ARG  ARG    Argentine Republic       12.0  Argentina
# 2    2023-0809-BDI  BDI   Republic of Burundi       43.0    Burundi
# 3    2023-0809-BDI  BDI   Republic of Burundi       43.0    Burundi
# 4    2023-0809-BDI  BDI   Republic of Burundi       43.0    Burundi
# ..             ...  ...                   ...        ...        ...
# 411  2023-0719-ZWE  ZWE  Republic of Zimbabwe      271.0   Zimbabwe
# 412  2023-0719-ZWE  ZWE  Republic of Zimbabwe      271.0   Zimbabwe
# 413  2023-0719-ZWE  ZWE  Republic of Zimbabwe      271.0   Zimbabwe
# 414  2023-0719-ZWE  ZWE  Republic of Zimbabwe      271.0   Zimbabwe
# 415  2023-0719-ZWE  ZWE  Republic of Zimbabwe      271.0   Zimbabwe
#
#      ADM1_CODE               ADM1_NAME_df1  ADM2_CODE     ADM2_NAME  \
# 0        429.0   Bahía Blanca Buenos Aires     4389.0  Bahia Blanca
# 1        429.0  Moreno Cities Buenos Aires     4462.0        Moreno
# 2      40547.0            Buganda Cibitoke    40605.0       Buganda
# 3      40547.0              Murwi Cibitoke    40609.0         Murwi
# 4      40547.0            Rugombo Cibitoke    40610.0       Rugombo
# ..         ...                         ...        ...           ...
# 411     3441.0                     Mwenezi    33086.0       Mwenezi
# 412    69550.0                        Seke    33073.0          Seke
# 413     3438.0                      Shamva    33066.0        Shamva
# 414    69550.0                       Wedza    33068.0        Hwedza
# 415     3437.0                       uhera    33053.0        Buhera
#
#                        location  \
# 0    Buenos Aires  Bahia Blanca
# 1          Buenos Aires  Moreno
# 2             Cibitoke  Buganda
# 3               Cibitoke  Murwi
# 4             Cibitoke  Rugombo
# ..                          ...
# 411                     Mwenezi
# 412                        Seke
# 413                      Shamva
# 414                      Hwedza
# 415                      Buhera
#
#                                               geometry geolocation  level
# 0    MULTIPOLYGON (((-62.42643 -38.75657, -62.42643...        None      2
# 1    POLYGON ((-58.86567 -34.68238, -58.88124 -34.6...        None      2
# 2    POLYGON ((29.13629 -2.88650, 29.13846 -2.88680...        None      2
# 3    POLYGON ((29.13629 -2.88650, 29.13953 -2.88071...        None      2
# 4    POLYGON ((29.21290 -2.78163, 29.21559 -2.78301...        None      2
# ..                                                 ...         ...    ...
# 411  POLYGON ((30.94386 -22.11357, 30.93747 -22.110...        None      2
# 412  POLYGON ((30.76508 -18.50712, 30.76493 -18.504...        None      2
# 413  POLYGON ((31.50866 -17.50133, 31.50852 -17.501...        None      2
# 414  POLYGON ((31.98308 -19.11863, 31.98306 -19.118...        None      2
# 415  POLYGON ((31.18835 -19.23481, 31.22039 -19.231...        None      2
#
# [416 rows x 13 columns]

# %%
geolocated_events = pd.concat([events_adm1_clean, events_adm2_clean,events_adm1_loconly_clean,events_adm2_loconly_clean])
geolocated_events['disaster_number_country'] = geolocated_events['DisNo.']
geolocated_events = geolocated_events.set_index('DisNo.').sort_index()

# %%
geolocated_events[['ADM0_CODE','ADM1_CODE']] = geolocated_events[['ADM0_CODE','ADM1_CODE']].astype(int)

# %%
gaul1_subset = gaul1[['ADM1_CODE','ADM1_NAME']]

# %%
def find_location(x):
    return gaul1_subset[gaul1_subset.ADM1_CODE == x]['ADM1_NAME'].values[0]

# %%
ADM1_NAMES_data = geolocated_events['ADM1_CODE'].apply(lambda x: find_location(x))

# %%
ADM1_NAMES_data
# Out:
# DisNo.
# 2020-0051-IRL         Laois
# 2020-0051-IRL         Sligo
# 2021-0001-BOL          Beni
# 2021-0001-BOL    Cochabamba
# 2021-0001-BOL        La Paz
#                     ...
# 2023-9868-USA      Oklahoma
# 2023-9868-USA      Nebraska
# 2023-9868-USA       Montana
# 2023-9868-USA    Washington
# 2023-9868-USA      Missouri
# Name: ADM1_CODE, Length: 4508, dtype: object

# %%
geolocated_events['ADM1_NAME'] = ADM1_NAMES_data

# %%
geolocated_events = geolocated_events.drop(columns='ADM1_NAME_df1')

# %%
len(np.unique(geolocated_events.index))
# Out:
# 1155

# %%
print(geolocated_events)
# Out:
#               iso3                   official_name  ADM0_CODE  \
# DisNo.
# 2020-0051-IRL  IRL                         Ireland        119
# 2020-0051-IRL  IRL                         Ireland        119
# 2021-0001-BOL  BOL  Plurinational State of Bolivia         33
# 2021-0001-BOL  BOL  Plurinational State of Bolivia         33
# 2021-0001-BOL  BOL  Plurinational State of Bolivia         33
# ...            ...                             ...        ...
# 2023-9868-USA  USA        United States of America        259
# 2023-9868-USA  USA        United States of America        259
# 2023-9868-USA  USA        United States of America        259
# 2023-9868-USA  USA        United States of America        259
# 2023-9868-USA  USA        United States of America        259
#
#                               ADM0_NAME  ADM1_CODE   ADM1_NAME  \
# DisNo.
# 2020-0051-IRL                   Ireland       1592       Laois
# 2020-0051-IRL                   Ireland       1603       Sligo
# 2021-0001-BOL                   Bolivia      40443        Beni
# 2021-0001-BOL                   Bolivia      40445  Cochabamba
# 2021-0001-BOL                   Bolivia      40446      La Paz
# ...                                 ...        ...         ...
# 2023-9868-USA  United States of America       3250    Oklahoma
# 2023-9868-USA  United States of America       3241    Nebraska
# 2023-9868-USA  United States of America       3240     Montana
# 2023-9868-USA  United States of America       3261  Washington
# 2023-9868-USA  United States of America       3239    Missouri
#
#                               location  geolocation  \
# DisNo.
# 2020-0051-IRL            County Laois.        Laois
# 2020-0051-IRL   Geevagh (County Sligo)        Sligo
# 2021-0001-BOL                     Beni         Beni
# 2021-0001-BOL               Cochabamba   Cochabamba
# 2021-0001-BOL       La Paz Departments       La Paz
# ...                                ...          ...
# 2023-9868-USA                 Oklahoma         None
# 2023-9868-USA                 Nebraska         None
# 2023-9868-USA                  Montana         None
# 2023-9868-USA               Washington         None
# 2023-9868-USA                 Missouri         None
#
#                                                         geometry ADM2_CODE  \
# DisNo.
# 2020-0051-IRL  POLYGON ((-7.73620 52.86050, -7.72770 52.86610...      None
# 2020-0051-IRL  MULTIPOLYGON (((-9.13221 54.21058, -9.09768 54...      None
# 2021-0001-BOL  POLYGON ((-67.56518 -14.04564, -67.56469 -14.0...      None
# 2021-0001-BOL  POLYGON ((-67.00473 -16.95181, -67.00468 -16.9...      None
# 2021-0001-BOL  POLYGON ((-69.64076 -17.28202, -69.63731 -17.2...      None
# ...                                                          ...       ...
# 2023-9868-USA  POLYGON ((-103.00246 36.50051, -103.00246 36.5...      None
# 2023-9868-USA  POLYGON ((-104.05352 41.15726, -104.05342 41.1...      None
# 2023-9868-USA  POLYGON ((-116.05000 48.41318, -116.05000 48.4...      None
# 2023-9868-USA  MULTIPOLYGON (((-124.72645 47.99174, -124.7265...      None
# 2023-9868-USA  POLYGON ((-95.77470 40.57357, -95.77355 40.578...      None
#
#               ADM2_NAME  level disaster_number_country
# DisNo.
# 2020-0051-IRL      None      1           2020-0051-IRL
# 2020-0051-IRL      None      1           2020-0051-IRL
# 2021-0001-BOL      None      1           2021-0001-BOL
# 2021-0001-BOL      None      1           2021-0001-BOL
# 2021-0001-BOL      None      1           2021-0001-BOL
# ...                 ...    ...                     ...
# 2023-9868-USA      None      1           2023-9868-USA
# 2023-9868-USA      None      1           2023-9868-USA
# 2023-9868-USA      None      1           2023-9868-USA
# 2023-9868-USA      None      1           2023-9868-USA
# 2023-9868-USA      None      1           2023-9868-USA
#
# [4508 rows x 13 columns]

# %%
geolocated_events.columns
# Out:
# Index(['iso3', 'official_name', 'ADM0_CODE', 'ADM0_NAME', 'ADM1_CODE',
#        'ADM1_NAME', 'location', 'geolocation', 'geometry', 'ADM2_CODE',
#        'ADM2_NAME', 'level', 'ADM1_NAME_df1', 'disaster_number_country'],
#       dtype='object')

# %%
geolocated_events = gpd.GeoDataFrame(geolocated_events)
geolocated_events.to_file('geolocated_events_clean_2021-2023_final.gpkg', driver="GPKG")

# %%
# !ls -lh
# Out:
# total 2.1G
# -rw-rw-r-- 1 dchinthaparthy dchinthaparthy  573K May 18 16:12 02_geolocate_events-2.ipynb
# -rw-rw-r-- 1 dchinthaparthy dchinthaparthy  593K Apr 24 23:12 02_geolocate_events-Copy1.ipynb
# -rw-rw-r-- 1 dchinthaparthy dchinthaparthy  663K May 19 18:29 02_geolocate_events-mod.ipynb
# -rw-rw-r-- 1 dchinthaparthy dchinthaparthy  678K May 19 15:05 02_geolocate_events.ipynb
# -rw-rw-r-- 1 dchinthaparthy dchinthaparthy   442 Feb 28 17:14 README.md
# -rw-rw-r-- 1 dchinthaparthy dchinthaparthy   983 Feb 29 15:28 Untitled.ipynb
# -rw-rw-r-- 1 dchinthaparthy dchinthaparthy  2.0K Apr 24 22:54 Untitled1.ipynb
# -rw-rw-r-- 1 dchinthaparthy dchinthaparthy  3.9K May  5 16:35 agg_data.csv
# -rw-rw-r-- 1 dchinthaparthy dchinthaparthy   930 Feb 28 17:14 aggreg_country_script.py
# -rw-rw-r-- 1 dchinthaparthy dchinthaparthy   21K May  5 20:50 aggregation_functions.py
# -rw-rw-r-- 1 dchinthaparthy dchinthaparthy  866K May  4 16:37 code_analysis.ipynb
# -rw-rw-r-- 1 dchinthaparthy dchinthaparthy  3.0K May  4 16:43 country_counts.csv
# -rw-rw-r-- 1 dchinthaparthy dchinthaparthy  365K Mar 12 14:38 data.ipynb
# -rw-rw-r-- 1 dchinthaparthy dchinthaparthy  796K Apr 24 22:13 data_ref.xlsx
# -rw-rw-r-- 1 dchinthaparthy dchinthaparthy  7.8K Apr 28 19:46 doc_String.ipynb
# -rw-rw-r-- 1 dchinthaparthy dchinthaparthy  3.5M Apr 24 21:51 emdat_public_1960_2022.xlsx
# -rw-rw-r-- 1 dchinthaparthy dchinthaparthy  8.5K Mar 12 15:43 event_shape.csv
# -rw-rw-r-- 1 dchinthaparthy dchinthaparthy  207K May  5 20:47 final_test.ipynb
# -rw-r--r-- 1 dchinthaparthy dchinthaparthy  1.1G Apr 25 00:13 geolocated_events_clean.gpkg
# -rw-r--r-- 1 dchinthaparthy dchinthaparthy  1.2G May 19 18:29 geolocated_events_clean_2021-2023.gpkg
# -rw-rw-r-- 1 dchinthaparthy dchinthaparthy  461K Apr 24 21:30 public_emdat_2021_2023.xlsx
# -rw-rw-r-- 1 dchinthaparthy dchinthaparthy   20K May  4 16:11 re_doc_Strings.ipynb
# -rw-rw-r-- 1 dchinthaparthy dchinthaparthy   14K Feb 28 12:34 requirements.txt
# drwxrwxr-x 4 dchinthaparthy dchinthaparthy     7 Mar 20 11:08 src
# -rw-rw-r-- 1 dchinthaparthy dchinthaparthy   30K Mar 21 14:08 test.ipynb
# -rw-rw-r-- 1 dchinthaparthy dchinthaparthy 1006K Mar  5 16:44 test_aggregation.ipynb

# %%
import os

# Specify the path to the folder you want to check
folder_path = '/net/projects/xaida/intermediate_data/shk_data/'

# Try to create a temporary file in the folder
temp_file_path = os.path.join(folder_path, 'temp_file.txt')
try:
    # Create the temporary file
    with open(temp_file_path, 'w'):
        pass  # Do nothing, just create the file
    print("You have access to the folder.")
except Exception as e:
    print(f"Error: {e}")
    print("You do not have access to the folder or there was an error creating the file.")
finally:
    # Remove the temporary file
    if os.path.exists(temp_file_path):
        os.remove(temp_file_path)
# Out:
# Error: [Errno 13] Permission denied: '/net/projects/xaida/intermediate_data/shk_data/temp_file.txt'
# You do not have access to the folder or there was an error creating the file.

# %%
cp geolocated_events_clean.gpkg /net/scratch/XAIDA/share_folder

# %%
cp geolocated_events_clean_2021-2023_final.gpkg /net/scratch/XAIDA/share_folder

# %%
data = gpd.read_file('geolocated_events_clean.gpkg')

# %%
data[data.iso3 == 'BOL']
# Out:
#              DisNo. iso3                   official_name  ADM0_CODE ADM0_NAME  \
# 5     2021-0001-BOL  BOL  Plurinational State of Bolivia         33   Bolivia
# 6     2021-0001-BOL  BOL  Plurinational State of Bolivia         33   Bolivia
# 7     2021-0001-BOL  BOL  Plurinational State of Bolivia         33   Bolivia
# 8     2021-0001-BOL  BOL  Plurinational State of Bolivia         33   Bolivia
# 62    2021-0027-BOL  BOL  Plurinational State of Bolivia         33   Bolivia
# 74    2021-0035-BOL  BOL  Plurinational State of Bolivia         33   Bolivia
# 75    2021-0035-BOL  BOL  Plurinational State of Bolivia         33   Bolivia
# 76    2021-0035-BOL  BOL  Plurinational State of Bolivia         33   Bolivia
# 77    2021-0035-BOL  BOL  Plurinational State of Bolivia         33   Bolivia
# 183   2021-0138-BOL  BOL  Plurinational State of Bolivia         33   Bolivia
# 302   2021-0233-BOL  BOL  Plurinational State of Bolivia         33   Bolivia
# 632   2021-0407-BOL  BOL  Plurinational State of Bolivia         33   Bolivia
# 1028  2021-0620-BOL  BOL  Plurinational State of Bolivia         33   Bolivia
# 1163  2021-0747-BOL  BOL  Plurinational State of Bolivia         33   Bolivia
# 1249  2021-0834-BOL  BOL  Plurinational State of Bolivia         33   Bolivia
# 1250  2021-0834-BOL  BOL  Plurinational State of Bolivia         33   Bolivia
# 1251  2021-0834-BOL  BOL  Plurinational State of Bolivia         33   Bolivia
# 1252  2021-0834-BOL  BOL  Plurinational State of Bolivia         33   Bolivia
# 1253  2021-0834-BOL  BOL  Plurinational State of Bolivia         33   Bolivia
# 1254  2021-0834-BOL  BOL  Plurinational State of Bolivia         33   Bolivia
# 1366  2022-0064-BOL  BOL  Plurinational State of Bolivia         33   Bolivia
# 1410  2022-0102-BOL  BOL  Plurinational State of Bolivia         33   Bolivia
# 2500  2023-0055-BOL  BOL  Plurinational State of Bolivia         33   Bolivia
# 2501  2023-0055-BOL  BOL  Plurinational State of Bolivia         33   Bolivia
# 2502  2023-0055-BOL  BOL  Plurinational State of Bolivia         33   Bolivia
# 2503  2023-0055-BOL  BOL  Plurinational State of Bolivia         33   Bolivia
# 2504  2023-0055-BOL  BOL  Plurinational State of Bolivia         33   Bolivia
# 2505  2023-0055-BOL  BOL  Plurinational State of Bolivia         33   Bolivia
# 2642  2023-0175-BOL  BOL  Plurinational State of Bolivia         33   Bolivia
# 3254  2023-0760-BOL  BOL  Plurinational State of Bolivia         33   Bolivia
# 3255  2023-0760-BOL  BOL  Plurinational State of Bolivia         33   Bolivia
# 3256  2023-0760-BOL  BOL  Plurinational State of Bolivia         33   Bolivia
# 3279  2023-0783-BOL  BOL  Plurinational State of Bolivia         33   Bolivia
# 3280  2023-0783-BOL  BOL  Plurinational State of Bolivia         33   Bolivia
# 3393  2023-9706-BOL  BOL  Plurinational State of Bolivia         33   Bolivia
# 3394  2023-9706-BOL  BOL  Plurinational State of Bolivia         33   Bolivia
# 3395  2023-9706-BOL  BOL  Plurinational State of Bolivia         33   Bolivia
# 3396  2023-9706-BOL  BOL  Plurinational State of Bolivia         33   Bolivia
# 3397  2023-9706-BOL  BOL  Plurinational State of Bolivia         33   Bolivia
#
#       ADM1_CODE   ADM1_NAME                                      location  \
# 5         40443        Beni                                    Cochabamba
# 6         40445  Cochabamba                                        Tarija
# 7         40446      La Paz                                          Beni
# 8         40450      Tarija                            La Paz Departments
# 62        40444  Chuquisaca            Sucre City (Chuquisaca Department)
# 74        40444  Chuquisaca            Sucre City (Chuquisaca Department)
# 75        40445  Cochabamba            Sucre City (Chuquisaca Department)
# 76        40446      La Paz                                Paz Department
# 77        40448      Potosi                             Potosì Department
# 183       40445  Cochabamba                                    Cochabamba
# 302       40445  Cochabamba                                      Omereque
# 632       40444  Chuquisaca                                    Chuquisaca
# 1028      40445  Cochabamba                                    Cochabamba
# 1163      40446      La Paz         Larecaja Province (La Paz Department)
# 1249      40445  Cochabamba                                    Cochabamba
# 1250      40444  Chuquisaca                                        La Paz
# 1251      40448      Potosi                                        Potosi
# 1252      40450      Tarija                                    Santa Cruz
# 1253      40446      La Paz                                    Chuquisaca
# 1254      40449  Santa Cruz                                        Tarija
# 1366      40445  Cochabamba                                    Cochabamba
# 1410      40450      Tarija         O'Connor Province (Tarija Department)
# 2500      40449  Santa Cruz                                    Cochabamba
# 2501      40448      Potosi   Tipuani municipalities (La Paz); Santa Cruz
# 2502      40445  Cochabamba                                    Chuquisaca
# 2503      40444  Chuquisaca                                        Mapiri
# 2504      40443        Beni                                        Guanay
# 2505      40446      La Paz                                        Guanay
# 2642      40449  Santa Cruz                                    Santa Cruz
# 3254      40449  Santa Cruz                                    Santa Cruz
# 3255      40446      La Paz                                        La Paz
# 3256      40443        Beni                                          Beni
# 3279      40448      Potosi                                        Potosi
# 3280      40444  Chuquisaca                                    Chuquisaca
# 3393      40446      La Paz                                        La Paz
# 3394      40445  Cochabamba                                    Cochabamba
# 3395      40444  Chuquisaca                                    Chuquisaca
# 3396      40447       Oruro                                         Oruro
# 3397      40449  Santa Cruz                                    Santa Cruz
#
#                        geolocation ADM2_CODE             ADM2_NAME  level  \
# 5                           Tarija      None                  None      1
# 6                       Cochabamba      None                  None      1
# 7                             Beni      None                  None      1
# 8                           La Paz      None                  None      1
# 62                . Oropeza (Adm2)     40458               Oropeza      2
# 74                  Oropeza (Adm2)     40458               Oropeza      2
# 75                      Cochabamba      None                  None      1
# 76                          Potosi      None                  None      1
# 77                          La Paz      None                  None      1
# 183                           None      None                  None      1
# 302                      . Campero     40474                Mizque      2
# 632                           None      None                  None      1
# 1028                          None      None                  None      1
# 1163             . Larecaja (Adm2)      6181              Larecaja      2
# 1249                        Potosi      None                  None      1
# 1250                        Tarija      None                  None      1
# 1251                    Cochabamba      None                  None      1
# 1252                    Santa Cruz      None                  None      1
# 1253                    Chuquisaca      None                  None      1
# 1254                        La Paz      None                  None      1
# 1366                          None      None                  None      1
# 1410      . Burnet O'Connor (Adm2)     40541       Burnet O'Connor      2
# 2500                    Santa Cruz      None                  None      1
# 2501                          Beni      None                  None      1
# 2502                    Cochabamba      None                  None      1
# 2503                    Chuquisaca      None                  None      1
# 2504                        Potosi      None                  None      1
# 2505   Gualberto Villarroel (Adm2)     40482  Gualberto Villarroel      2
# 2642                          None      None                  None      1
# 3254                          None      None                  None      1
# 3255                          None      None                  None      1
# 3256                          None      None                  None      1
# 3279                          None      None                  None      1
# 3280                          None      None                  None      1
# 3393                          None      None                  None      1
# 3394                          None      None                  None      1
# 3395                          None      None                  None      1
# 3396                          None      None                  None      1
# 3397                          None      None                  None      1
#
#      disaster_number_country  \
# 5              2021-0001-BOL
# 6              2021-0001-BOL
# 7              2021-0001-BOL
# 8              2021-0001-BOL
# 62             2021-0027-BOL
# 74             2021-0035-BOL
# 75             2021-0035-BOL
# 76             2021-0035-BOL
# 77             2021-0035-BOL
# 183            2021-0138-BOL
# 302            2021-0233-BOL
# 632            2021-0407-BOL
# 1028           2021-0620-BOL
# 1163           2021-0747-BOL
# 1249           2021-0834-BOL
# 1250           2021-0834-BOL
# 1251           2021-0834-BOL
# 1252           2021-0834-BOL
# 1253           2021-0834-BOL
# 1254           2021-0834-BOL
# 1366           2022-0064-BOL
# 1410           2022-0102-BOL
# 2500           2023-0055-BOL
# 2501           2023-0055-BOL
# 2502           2023-0055-BOL
# 2503           2023-0055-BOL
# 2504           2023-0055-BOL
# 2505           2023-0055-BOL
# 2642           2023-0175-BOL
# 3254           2023-0760-BOL
# 3255           2023-0760-BOL
# 3256           2023-0760-BOL
# 3279           2023-0783-BOL
# 3280           2023-0783-BOL
# 3393           2023-9706-BOL
# 3394           2023-9706-BOL
# 3395           2023-9706-BOL
# 3396           2023-9706-BOL
# 3397           2023-9706-BOL
#
#                                                geometry
# 5     POLYGON ((-67.56518 -14.04564, -67.56469 -14.0...
# 6     POLYGON ((-67.00473 -16.95181, -67.00468 -16.9...
# 7     POLYGON ((-69.64076 -17.28202, -69.63731 -17.2...
# 8     POLYGON ((-65.41817 -21.89328, -65.41816 -21.8...
# 62    POLYGON ((-65.69396 -18.35985, -65.69388 -18.3...
# 74    POLYGON ((-65.69396 -18.35985, -65.69388 -18.3...
# 75    POLYGON ((-67.00473 -16.95181, -67.00468 -16.9...
# 76    POLYGON ((-69.64076 -17.28202, -69.63731 -17.2...
# 77    POLYGON ((-68.78247 -20.08777, -68.78247 -20.0...
# 183   POLYGON ((-67.00473 -16.95181, -67.00468 -16.9...
# 302   POLYGON ((-65.73359 -17.66800, -65.73349 -17.6...
# 632   POLYGON ((-65.69396 -18.35985, -65.69388 -18.3...
# 1028  POLYGON ((-67.00473 -16.95181, -67.00468 -16.9...
# 1163  POLYGON ((-68.43621 -15.20437, -68.43583 -15.2...
# 1249  POLYGON ((-67.00473 -16.95181, -67.00468 -16.9...
# 1250  POLYGON ((-65.69396 -18.35985, -65.69388 -18.3...
# 1251  POLYGON ((-68.78247 -20.08777, -68.78247 -20.0...
# 1252  POLYGON ((-65.41817 -21.89328, -65.41816 -21.8...
# 1253  POLYGON ((-69.64076 -17.28202, -69.63731 -17.2...
# 1254  POLYGON ((-64.83822 -16.73392, -64.83808 -16.7...
# 1366  POLYGON ((-67.00473 -16.95181, -67.00468 -16.9...
# 1410  POLYGON ((-64.30270 -21.94694, -64.30281 -21.9...
# 2500  POLYGON ((-64.83822 -16.73392, -64.83808 -16.7...
# 2501  POLYGON ((-68.78247 -20.08777, -68.78247 -20.0...
# 2502  POLYGON ((-67.00473 -16.95181, -67.00468 -16.9...
# 2503  POLYGON ((-65.69396 -18.35985, -65.69388 -18.3...
# 2504  POLYGON ((-67.56518 -14.04564, -67.56469 -14.0...
# 2505  POLYGON ((-68.16876 -17.41838, -68.16858 -17.4...
# 2642  POLYGON ((-64.83822 -16.73392, -64.83808 -16.7...
# 3254  POLYGON ((-64.83822 -16.73392, -64.83808 -16.7...
# 3255  POLYGON ((-69.64076 -17.28202, -69.63731 -17.2...
# 3256  POLYGON ((-67.56518 -14.04564, -67.56469 -14.0...
# 3279  POLYGON ((-68.78247 -20.08777, -68.78247 -20.0...
# 3280  POLYGON ((-65.69396 -18.35985, -65.69388 -18.3...
# 3393  POLYGON ((-69.64076 -17.28202, -69.63731 -17.2...
# 3394  POLYGON ((-67.00473 -16.95181, -67.00468 -16.9...
# 3395  POLYGON ((-65.69396 -18.35985, -65.69388 -18.3...
# 3396  POLYGON ((-69.13856 -18.15672, -69.13733 -18.1...
# 3397  POLYGON ((-64.83822 -16.73392, -64.83808 -16.7...

# %%
data1 = gpd.read_file('geolocated_events_clean_2021-2023.gpkg')

# %%
data1[data1.iso3 == 'BOL']
# Out:
#              DisNo. iso3                   official_name  ADM0_CODE ADM0_NAME  \
# 5     2021-0001-BOL  BOL  Plurinational State of Bolivia         33   Bolivia
# 6     2021-0001-BOL  BOL  Plurinational State of Bolivia         33   Bolivia
# 7     2021-0001-BOL  BOL  Plurinational State of Bolivia         33   Bolivia
# 8     2021-0001-BOL  BOL  Plurinational State of Bolivia         33   Bolivia
# 77    2021-0027-BOL  BOL  Plurinational State of Bolivia         33   Bolivia
# 89    2021-0035-BOL  BOL  Plurinational State of Bolivia         33   Bolivia
# 90    2021-0035-BOL  BOL  Plurinational State of Bolivia         33   Bolivia
# 91    2021-0035-BOL  BOL  Plurinational State of Bolivia         33   Bolivia
# 92    2021-0035-BOL  BOL  Plurinational State of Bolivia         33   Bolivia
# 212   2021-0109-BOL  BOL  Plurinational State of Bolivia         33   Bolivia
# 246   2021-0138-BOL  BOL  Plurinational State of Bolivia         33   Bolivia
# 439   2021-0233-BOL  BOL  Plurinational State of Bolivia         33   Bolivia
# 440   2021-0233-BOL  BOL  Plurinational State of Bolivia         33   Bolivia
# 844   2021-0407-BOL  BOL  Plurinational State of Bolivia         33   Bolivia
# 1362  2021-0620-BOL  BOL  Plurinational State of Bolivia         33   Bolivia
# 1598  2021-0747-BOL  BOL  Plurinational State of Bolivia         33   Bolivia
# 1800  2021-0834-BOL  BOL  Plurinational State of Bolivia         33   Bolivia
# 1801  2021-0834-BOL  BOL  Plurinational State of Bolivia         33   Bolivia
# 1802  2021-0834-BOL  BOL  Plurinational State of Bolivia         33   Bolivia
# 1803  2021-0834-BOL  BOL  Plurinational State of Bolivia         33   Bolivia
# 1804  2021-0834-BOL  BOL  Plurinational State of Bolivia         33   Bolivia
# 1805  2021-0834-BOL  BOL  Plurinational State of Bolivia         33   Bolivia
# 1952  2022-0064-BOL  BOL  Plurinational State of Bolivia         33   Bolivia
# 2008  2022-0102-BOL  BOL  Plurinational State of Bolivia         33   Bolivia
# 3413  2023-0055-BOL  BOL  Plurinational State of Bolivia         33   Bolivia
# 3414  2023-0055-BOL  BOL  Plurinational State of Bolivia         33   Bolivia
# 3415  2023-0055-BOL  BOL  Plurinational State of Bolivia         33   Bolivia
# 3416  2023-0055-BOL  BOL  Plurinational State of Bolivia         33   Bolivia
# 3417  2023-0055-BOL  BOL  Plurinational State of Bolivia         33   Bolivia
# 3418  2023-0055-BOL  BOL  Plurinational State of Bolivia         33   Bolivia
# 3581  2023-0175-BOL  BOL  Plurinational State of Bolivia         33   Bolivia
# 3586  2023-0178-BOL  BOL  Plurinational State of Bolivia         33   Bolivia
# 4273  2023-0760-BOL  BOL  Plurinational State of Bolivia         33   Bolivia
# 4274  2023-0760-BOL  BOL  Plurinational State of Bolivia         33   Bolivia
# 4275  2023-0760-BOL  BOL  Plurinational State of Bolivia         33   Bolivia
# 4298  2023-0783-BOL  BOL  Plurinational State of Bolivia         33   Bolivia
# 4299  2023-0783-BOL  BOL  Plurinational State of Bolivia         33   Bolivia
# 4417  2023-9706-BOL  BOL  Plurinational State of Bolivia         33   Bolivia
# 4418  2023-9706-BOL  BOL  Plurinational State of Bolivia         33   Bolivia
# 4419  2023-9706-BOL  BOL  Plurinational State of Bolivia         33   Bolivia
# 4420  2023-9706-BOL  BOL  Plurinational State of Bolivia         33   Bolivia
# 4421  2023-9706-BOL  BOL  Plurinational State of Bolivia         33   Bolivia
#
#       ADM1_CODE   ADM1_NAME  \
# 5         40443        Beni
# 6         40445  Cochabamba
# 7         40446      La Paz
# 8         40450      Tarija
# 77        40444  Chuquisaca
# 89        40444  Chuquisaca
# 90        40445  Cochabamba
# 91        40446      La Paz
# 92        40448      Potosi
# 212       40449  Santa Cruz
# 246       40445  Cochabamba
# 439       40445  Cochabamba
# 440       40445  Cochabamba
# 844       40444  Chuquisaca
# 1362      40445  Cochabamba
# 1598      40446      La Paz
# 1800      40448      Potosi
# 1801      40450      Tarija
# 1802      40449  Santa Cruz
# 1803      40446      La Paz
# 1804      40445  Cochabamba
# 1805      40444  Chuquisaca
# 1952      40445  Cochabamba
# 2008      40450      Tarija
# 3413      40449  Santa Cruz
# 3414      40448      Potosi
# 3415      40445  Cochabamba
# 3416      40446      La Paz
# 3417      40443        Beni
# 3418      40444  Chuquisaca
# 3581      40449  Santa Cruz
# 3586        648       Pando
# 4273      40446      La Paz
# 4274      40449  Santa Cruz
# 4275      40443        Beni
# 4298      40444  Chuquisaca
# 4299      40448      Potosi
# 4417      40444  Chuquisaca
# 4418      40445  Cochabamba
# 4419      40449  Santa Cruz
# 4420      40446      La Paz
# 4421      40447       Oruro
#
#                                                location  \
# 5                                                  Beni
# 6                                            Cochabamba
# 7                                    La Paz Departments
# 8                                                Tarija
# 77                   Sucre City (Chuquisaca Department)
# 89                                Cochabamba Department
# 90                                Cochabamba Department
# 91                                       Paz Department
# 92                                    Potosì Department
# 212                                    Beni Departments
# 246                                          Cochabamba
# 439                                            Omereque
# 440    Raqaypampa municipalities (Cochabamba Departm...
# 844                                          Chuquisaca
# 1362                                         Cochabamba
# 1598              Larecaja Province (La Paz Department)
# 1800                                             Potosi
# 1801                                             Tarija
# 1802                                         Santa Cruz
# 1803                                             La Paz
# 1804                                         Cochabamba
# 1805                                         Chuquisaca
# 1952                                         Cochabamba
# 2008              O'Connor Province (Tarija Department)
# 3413                                             Mapiri
# 3414                                             Guanay
# 3415                                         Cochabamba
# 3416                                   Beni Departments
# 3417                                   Beni Departments
# 3418                                         Chuquisaca
# 3581                                         Santa Cruz
# 3586                     Cobija City (Pando Department)
# 4273                                             La Paz
# 4274                                         Santa Cruz
# 4275                                               Beni
# 4298                                         Chuquisaca
# 4299                                             Potosi
# 4417                                         Chuquisaca
# 4418                                         Cochabamba
# 4419                                         Santa Cruz
# 4420                                             La Paz
# 4421                                              Oruro
#
#                 geolocation ADM2_CODE             ADM2_NAME  level  \
# 5                      Beni      None                  None      1
# 6                Cochabamba      None                  None      1
# 7                    La Paz      None                  None      1
# 8                    Tarija      None                  None      1
# 77                  Oropeza     40458               Oropeza      2
# 89                  Oropeza     40458               Oropeza      2
# 90               Cochabamba      None                  None      1
# 91                   La Paz      None                  None      1
# 92                   Potosi      None                  None      1
# 212              Santa Cruz      None                  None      1
# 246                    None      None                  None      1
# 439                 Campero     40467               Campero      2
# 440                  Mizque     40474                Mizque      2
# 844                    None      None                  None      1
# 1362                   None      None                  None      1
# 1598               Larecaja      6181              Larecaja      2
# 1800                 Potosi      None                  None      1
# 1801                 Tarija      None                  None      1
# 1802             Santa Cruz      None                  None      1
# 1803                 La Paz      None                  None      1
# 1804             Cochabamba      None                  None      1
# 1805             Chuquisaca      None                  None      1
# 1952                   None      None                  None      1
# 2008        Burnet O'Connor     40541       Burnet O'Connor      2
# 3413             Santa Cruz      None                  None      1
# 3414                 Potosi      None                  None      1
# 3415             Cochabamba      None                  None      1
# 3416   Gualberto Villarroel     40482  Gualberto Villarroel      2
# 3417                   Beni      None                  None      1
# 3418             Chuquisaca      None                  None      1
# 3581                   None      None                  None      1
# 3586                  Pando      None                  None      1
# 4273                   None      None                  None      1
# 4274                   None      None                  None      1
# 4275                   None      None                  None      1
# 4298                   None      None                  None      1
# 4299                   None      None                  None      1
# 4417                   None      None                  None      1
# 4418                   None      None                  None      1
# 4419                   None      None                  None      1
# 4420                   None      None                  None      1
# 4421                   None      None                  None      1
#
#      disaster_number_country  \
# 5              2021-0001-BOL
# 6              2021-0001-BOL
# 7              2021-0001-BOL
# 8              2021-0001-BOL
# 77             2021-0027-BOL
# 89             2021-0035-BOL
# 90             2021-0035-BOL
# 91             2021-0035-BOL
# 92             2021-0035-BOL
# 212            2021-0109-BOL
# 246            2021-0138-BOL
# 439            2021-0233-BOL
# 440            2021-0233-BOL
# 844            2021-0407-BOL
# 1362           2021-0620-BOL
# 1598           2021-0747-BOL
# 1800           2021-0834-BOL
# 1801           2021-0834-BOL
# 1802           2021-0834-BOL
# 1803           2021-0834-BOL
# 1804           2021-0834-BOL
# 1805           2021-0834-BOL
# 1952           2022-0064-BOL
# 2008           2022-0102-BOL
# 3413           2023-0055-BOL
# 3414           2023-0055-BOL
# 3415           2023-0055-BOL
# 3416           2023-0055-BOL
# 3417           2023-0055-BOL
# 3418           2023-0055-BOL
# 3581           2023-0175-BOL
# 3586           2023-0178-BOL
# 4273           2023-0760-BOL
# 4274           2023-0760-BOL
# 4275           2023-0760-BOL
# 4298           2023-0783-BOL
# 4299           2023-0783-BOL
# 4417           2023-9706-BOL
# 4418           2023-9706-BOL
# 4419           2023-9706-BOL
# 4420           2023-9706-BOL
# 4421           2023-9706-BOL
#
#                                                geometry
# 5     POLYGON ((-67.56518 -14.04564, -67.56469 -14.0...
# 6     POLYGON ((-67.00473 -16.95181, -67.00468 -16.9...
# 7     POLYGON ((-69.64076 -17.28202, -69.63731 -17.2...
# 8     POLYGON ((-65.41817 -21.89328, -65.41816 -21.8...
# 77    POLYGON ((-65.69396 -18.35985, -65.69388 -18.3...
# 89    POLYGON ((-65.69396 -18.35985, -65.69388 -18.3...
# 90    POLYGON ((-67.00473 -16.95181, -67.00468 -16.9...
# 91    POLYGON ((-69.64076 -17.28202, -69.63731 -17.2...
# 92    POLYGON ((-68.78247 -20.08777, -68.78247 -20.0...
# 212   POLYGON ((-64.83822 -16.73392, -64.83808 -16.7...
# 246   POLYGON ((-67.00473 -16.95181, -67.00468 -16.9...
# 439   POLYGON ((-65.35386 -18.40213, -65.35352 -18.4...
# 440   POLYGON ((-65.73359 -17.66800, -65.73349 -17.6...
# 844   POLYGON ((-65.69396 -18.35985, -65.69388 -18.3...
# 1362  POLYGON ((-67.00473 -16.95181, -67.00468 -16.9...
# 1598  POLYGON ((-68.43621 -15.20437, -68.43583 -15.2...
# 1800  POLYGON ((-68.78247 -20.08777, -68.78247 -20.0...
# 1801  POLYGON ((-65.41817 -21.89328, -65.41816 -21.8...
# 1802  POLYGON ((-64.83822 -16.73392, -64.83808 -16.7...
# 1803  POLYGON ((-69.64076 -17.28202, -69.63731 -17.2...
# 1804  POLYGON ((-67.00473 -16.95181, -67.00468 -16.9...
# 1805  POLYGON ((-65.69396 -18.35985, -65.69388 -18.3...
# 1952  POLYGON ((-67.00473 -16.95181, -67.00468 -16.9...
# 2008  POLYGON ((-64.30270 -21.94694, -64.30281 -21.9...
# 3413  POLYGON ((-64.83822 -16.73392, -64.83808 -16.7...
# 3414  POLYGON ((-68.78247 -20.08777, -68.78247 -20.0...
# 3415  POLYGON ((-67.00473 -16.95181, -67.00468 -16.9...
# 3416  POLYGON ((-68.16876 -17.41838, -68.16858 -17.4...
# 3417  POLYGON ((-67.56518 -14.04564, -67.56469 -14.0...
# 3418  POLYGON ((-65.69396 -18.35985, -65.69388 -18.3...
# 3581  POLYGON ((-64.83822 -16.73392, -64.83808 -16.7...
# 3586  POLYGON ((-69.56644 -10.95666, -69.56496 -10.9...
# 4273  POLYGON ((-69.64076 -17.28202, -69.63731 -17.2...
# 4274  POLYGON ((-64.83822 -16.73392, -64.83808 -16.7...
# 4275  POLYGON ((-67.56518 -14.04564, -67.56469 -14.0...
# 4298  POLYGON ((-65.69396 -18.35985, -65.69388 -18.3...
# 4299  POLYGON ((-68.78247 -20.08777, -68.78247 -20.0...
# 4417  POLYGON ((-65.69396 -18.35985, -65.69388 -18.3...
# 4418  POLYGON ((-67.00473 -16.95181, -67.00468 -16.9...
# 4419  POLYGON ((-64.83822 -16.73392, -64.83808 -16.7...
# 4420  POLYGON ((-69.64076 -17.28202, -69.63731 -17.2...
# 4421  POLYGON ((-69.13856 -18.15672, -69.13733 -18.1...
